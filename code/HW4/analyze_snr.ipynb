# %%
import numpy as np
import csv
from collections import defaultdict

# %%
def read_snr_csv(path):
    data = defaultdict(lambda: defaultdict(list))

    with open(path, newline='') as csvfile:
        csvreader = csv.reader(csvfile, delimiter='\\')

        # Process each row in the CSV
        for row in csvreader:
            reader_ID, chapter, rest = row[0], row[1], row[2]
            _, value_1, value_2 = rest.split(',')

            # Add values to the dictionary
            data[reader_ID][chapter].append((float(value_1), float(value_2)))
    return data

def compute_statistics(data):
    """
    Compute five-number summaries and means for value_1 and value_2.

    Parameters:
    data (dict): Nested dictionary containing (value_1, value_2) tuples.

    Returns:
    dict: A dictionary containing statistics for value_1 and value_2.
    """
    value_1_list = []
    value_2_list = []

    # Extract values from dictionary
    for reader_ID in data.values():
        for chapter in reader_ID.values():
            for value_1, value_2 in chapter:
                value_1_list.append(value_1)
                value_2_list.append(value_2)

    # Convert to numpy arrays
    value_1_arr = np.array(value_1_list)
    value_2_arr = np.array(value_2_list)

    # Compute five-number summary and mean
    def five_number_summary(arr):
        return {
            "min": np.min(arr),
            "Q1": np.percentile(arr, 25),
            "median": np.median(arr),
            "Q3": np.percentile(arr, 75),
            "max": np.max(arr),
            "mean": np.mean(arr)
        }

    return {
        "value_1": five_number_summary(value_1_arr),
        "value_2": five_number_summary(value_2_arr)
    }

def print_statistics(stats):
    """
    Print the five-number summaries and means rounded to five decimal places.

    Parameters:
    stats (dict): Dictionary containing statistics for value_1 and value_2.
    """
    for key, summary in stats.items():
        print(f"\nStatistics for {key}:")
        for stat_name, value in summary.items():
            print(f"  {stat_name}: {round(value, 4)}")

def percent_difference(initial, final):
    return (final - initial)/initial

# %%
data = read_snr_csv("../../data/output/snr_data_all.csv")

for reader_ID in data:
    print(f"Reader ID: {reader_ID}")
    print("Chapters:", list(data[reader_ID].keys()))
    print()  # Add a blank line for better readability
# Out:
# Reader ID: 19
# Chapters: ['198', '227']
#
# Reader ID: 26
# Chapters: ['495', '496']
#
# Reader ID: 27
# Chapters: ['123349', '124992']
#
# Reader ID: 32
# Chapters: ['21625', '21631', '21634', '4137']
#
# Reader ID: 39
# Chapters: ['121914', '121915', '121916']
#
# Reader ID: 40
# Chapters: ['121026', '222']
#
# Reader ID: 60
# Chapters: ['121082']
#
# Reader ID: 78
# Chapters: ['368', '369']
#
# Reader ID: 83
# Chapters: ['11691', '3054', '9960']
#
# Reader ID: 87
# Chapters: ['121553']
#
# Reader ID: 89
# Chapters: ['218', '219']
#
# Reader ID: 103
# Chapters: ['1240', '1241']
#
# Reader ID: 118
# Chapters: ['121721', '124588', '47824']
#
# Reader ID: 125
# Chapters: ['121124', '121342']
#
# Reader ID: 150
# Chapters: ['126107', '126112', '132655']
#
# Reader ID: 163
# Chapters: ['121908', '122947']
#
# Reader ID: 196
# Chapters: ['122150', '122152', '122159']
#
# Reader ID: 198
# Chapters: ['126831', '129977', '209']
#
# Reader ID: 200
# Chapters: ['124139', '124140', '126784']
#
# Reader ID: 201
# Chapters: ['122255', '127786']
#
# Reader ID: 211
# Chapters: ['122425', '122442']
#
# Reader ID: 226
# Chapters: ['122538', '131532', '131533']
#
# Reader ID: 229
# Chapters: ['130880']
#
# Reader ID: 233
# Chapters: ['134440', '155990']
#
# Reader ID: 248
# Chapters: ['130644', '130652', '130697']
#
# Reader ID: 250
# Chapters: ['140277', '142276', '142286']
#
# Reader ID: 254
# Chapters: ['12312', '127705', '145458', '27760']
#
# Reader ID: 289
# Chapters: ['121652', '121665']
#
# Reader ID: 298
# Chapters: ['126790', '126791']
#
# Reader ID: 302
# Chapters: ['123504', '123516', '123523']
#
# Reader ID: 307
# Chapters: ['127535', '127539', '127540']
#
# Reader ID: 311
# Chapters: ['124404']
#
# Reader ID: 322
# Chapters: ['124146', '124147']
#
# Reader ID: 328
# Chapters: ['129766']
#
# Reader ID: 332
# Chapters: ['128985']
#
# Reader ID: 374
# Chapters: ['180298', '180299']
#
# Reader ID: 403
# Chapters: ['126855', '128339', '216']
#
# Reader ID: 405
# Chapters: ['130894', '130895']
#
# Reader ID: 412
# Chapters: ['126975']
#
# Reader ID: 426
# Chapters: ['122819', '122821', '122822']
#
# Reader ID: 441
# Chapters: ['128982', '128988', '130108']
#
# Reader ID: 445
# Chapters: ['123857', '123860']
#
# Reader ID: 446
# Chapters: ['123501', '123502']
#
# Reader ID: 458
# Chapters: ['126290', '126294', '126305']
#
# Reader ID: 460
# Chapters: ['172357', '172359']
#
# Reader ID: 481
# Chapters: ['123719', '123720']
#
# Reader ID: 587
# Chapters: ['41611', '41619', '54108']
#
# Reader ID: 625
# Chapters: ['132112', '132118']
#
# Reader ID: 669
# Chapters: ['129061', '129074']
#
# Reader ID: 696
# Chapters: ['92939', '93314']
#
# Reader ID: 730
# Chapters: ['358', '359', '360']
#
# Reader ID: 831
# Chapters: ['130739', '130746']
#
# Reader ID: 839
# Chapters: ['130898']
#
# Reader ID: 887
# Chapters: ['123289', '123290', '123291']
#
# Reader ID: 909
# Chapters: ['131041', '131044', '131045']
#
# Reader ID: 911
# Chapters: ['128684', '130578']
#
# Reader ID: 1034
# Chapters: ['121119']
#
# Reader ID: 1040
# Chapters: ['133433']
#
# Reader ID: 1069
# Chapters: ['133699', '133709']
#
# Reader ID: 1081
# Chapters: ['125237', '128618']
#
# Reader ID: 1088
# Chapters: ['129236', '134315', '134318']
#
# Reader ID: 1098
# Chapters: ['133695']
#
# Reader ID: 1116
# Chapters: ['132847', '132851', '137572']
#
# Reader ID: 1183
# Chapters: ['124566', '128659', '133255', '133256']
#
# Reader ID: 1235
# Chapters: ['135883', '135884', '135887']
#
# Reader ID: 1246
# Chapters: ['124548', '124550', '135815']
#
# Reader ID: 1263
# Chapters: ['138246', '139804', '141777']
#
# Reader ID: 1334
# Chapters: ['135589']
#
# Reader ID: 1355
# Chapters: ['39947']
#
# Reader ID: 1363
# Chapters: ['135842', '139304']
#
# Reader ID: 1447
# Chapters: ['130550', '130551', '130552', '17506']
#
# Reader ID: 1455
# Chapters: ['134435', '138263']
#
# Reader ID: 1502
# Chapters: ['122615', '122619']
#
# Reader ID: 1553
# Chapters: ['140047', '140048']
#
# Reader ID: 1578
# Chapters: ['140045', '140049', '6379']
#
# Reader ID: 1594
# Chapters: ['135914']
#
# Reader ID: 1624
# Chapters: ['142933', '168623']
#
# Reader ID: 1723
# Chapters: ['141149']
#
# Reader ID: 1737
# Chapters: ['142396', '142397', '146161', '148989']
#
# Reader ID: 1743
# Chapters: ['142912', '142913', '142914']
#
# Reader ID: 1841
# Chapters: ['150351', '159771', '179183']
#
# Reader ID: 1867
# Chapters: ['148436', '154071', '154075']
#
# Reader ID: 1898
# Chapters: ['145702', '145715', '145720', '145724']
#
# Reader ID: 1926
# Chapters: ['143879', '147979', '147987']
#
# Reader ID: 1963
# Chapters: ['142393', '142776', '147036']
#
# Reader ID: 1970
# Chapters: ['10594', '26100', '28415']
#
# Reader ID: 1992
# Chapters: ['141719']
#
# Reader ID: 2002
# Chapters: ['139469']
#
# Reader ID: 2007
# Chapters: ['132570', '149877']
#
# Reader ID: 2092
# Chapters: ['145706', '145709']
#
# Reader ID: 2136
# Chapters: ['5140', '5143', '5147']
#
# Reader ID: 2159
# Chapters: ['179154', '179156', '179157']
#
# Reader ID: 2182
# Chapters: ['150130', '181173', '181183']
#
# Reader ID: 2196
# Chapters: ['170151', '170379', '174172']
#
# Reader ID: 2289
# Chapters: ['152253', '152254', '152257', '152258']
#
# Reader ID: 2384
# Chapters: ['152900']
#
# Reader ID: 2391
# Chapters: ['145015']
#
# Reader ID: 2416
# Chapters: ['152137', '152139']
#
# Reader ID: 2436
# Chapters: ['2476', '2477', '2481']
#
# Reader ID: 2514
# Chapters: ['149482']
#
# Reader ID: 2518
# Chapters: ['154825', '154826']
#
# Reader ID: 2691
# Chapters: ['156745', '156750', '156755']
#
# Reader ID: 2764
# Chapters: ['36616', '36617', '36619']
#
# Reader ID: 2817
# Chapters: ['142371', '142380']
#
# Reader ID: 2836
# Chapters: ['5354', '5355']
#
# Reader ID: 2843
# Chapters: ['152918']
#
# Reader ID: 2893
# Chapters: ['139310', '139322']
#
# Reader ID: 2910
# Chapters: ['131096']
#
# Reader ID: 2911
# Chapters: ['12359', '15045', '15084', '7601']
#
# Reader ID: 2952
# Chapters: ['407', '408', '410']
#
# Reader ID: 2989
# Chapters: ['138028', '138035']
#
# Reader ID: 3112
# Chapters: ['9554', '9555']
#
# Reader ID: 3168
# Chapters: ['173564', '173565']
#
# Reader ID: 3214
# Chapters: ['167602', '167606', '167607']
#
# Reader ID: 3235
# Chapters: ['11599', '28433', '28452']
#
# Reader ID: 3240
# Chapters: ['131231', '131232']
#
# Reader ID: 3242
# Chapters: ['67153', '67168', '8112']
#
# Reader ID: 3259
# Chapters: ['158083']
#
# Reader ID: 3374
# Chapters: ['298025', '298026', '298032']
#
# Reader ID: 3436
# Chapters: ['172162', '172171']
#
# Reader ID: 3440
# Chapters: ['171006', '171009']
#
# Reader ID: 3486
# Chapters: ['166424', '166446']
#
# Reader ID: 3526
# Chapters: ['175658', '176651', '176653']
#
# Reader ID: 3607
# Chapters: ['135982', '29116']
#
# Reader ID: 3664
# Chapters: ['11714', '178355', '178366']
#
# Reader ID: 3699
# Chapters: ['175950', '19401', '19402', '47246']
#
# Reader ID: 3723
# Chapters: ['171115', '171631']
#
# Reader ID: 3807
# Chapters: ['4923', '4955']
#
# Reader ID: 3830
# Chapters: ['12529', '12530', '12531', '12535']
#
# Reader ID: 3857
# Chapters: ['180923', '182315', '182317']
#
# Reader ID: 3879
# Chapters: ['173592', '174923']
#
# Reader ID: 3947
# Chapters: ['13260', '13262']
#
# Reader ID: 3982
# Chapters: ['178459', '182255']
#
# Reader ID: 3983
# Chapters: ['5331', '5371']
#
# Reader ID: 4014
# Chapters: ['186175', '186176', '186179', '186183']
#
# Reader ID: 4018
# Chapters: ['103416', '107312', '107338']
#
# Reader ID: 4051
# Chapters: ['10927', '11217', '11218']
#
# Reader ID: 4088
# Chapters: ['158077', '158079']
#
# Reader ID: 4137
# Chapters: ['11701', '11702']
#
# Reader ID: 4160
# Chapters: ['11549', '11550', '14187']
#
# Reader ID: 4195
# Chapters: ['17507', '186236', '186237', '186238']
#
# Reader ID: 4214
# Chapters: ['7146']
#
# Reader ID: 4267
# Chapters: ['287369', '72637', '78186']
#
# Reader ID: 4297
# Chapters: ['13006', '13009']
#
# Reader ID: 4340
# Chapters: ['15220']
#
# Reader ID: 4362
# Chapters: ['15663']
#
# Reader ID: 4397
# Chapters: ['15666', '15668', '15678']
#
# Reader ID: 4406
# Chapters: ['16882', '16883']
#
# Reader ID: 4441
# Chapters: ['76250', '76262', '76263']
#
# Reader ID: 4481
# Chapters: ['17498', '17499']
#
# Reader ID: 4640
# Chapters: ['19187', '19188', '19189']
#
# Reader ID: 4680
# Chapters: ['16026', '16041', '16042']
#
# Reader ID: 4788
# Chapters: ['294466', '91208', '94904']
#
# Reader ID: 4813
# Chapters: ['248638', '248641']
#
# Reader ID: 4830
# Chapters: ['25898', '25904']
#
# Reader ID: 4853
# Chapters: ['27670', '27671', '29413']
#
# Reader ID: 4859
# Chapters: ['22176', '26870', '29340']
#
# Reader ID: 4898
# Chapters: ['20016', '28461']
#
# Reader ID: 5022
# Chapters: ['29405', '29411']
#
# Reader ID: 5049
# Chapters: ['25947']
#
# Reader ID: 5104
# Chapters: ['33406', '33407']
#
# Reader ID: 5163
# Chapters: ['18515', '39921']
#
# Reader ID: 5192
# Chapters: ['19396', '19397']
#
# Reader ID: 5322
# Chapters: ['7678', '7679', '7680']
#
# Reader ID: 5339
# Chapters: ['14133', '14134']
#
# Reader ID: 5390
# Chapters: ['24512', '30096', '30102']
#
# Reader ID: 5393
# Chapters: ['19218', '19219']
#
# Reader ID: 5456
# Chapters: ['24741', '58161', '62014', '62043']
#
# Reader ID: 5463
# Chapters: ['39173', '39174']
#
# Reader ID: 5514
# Chapters: ['19192', '19193']
#
# Reader ID: 5561
# Chapters: ['39621', '41615', '41616']
#
# Reader ID: 5652
# Chapters: ['19215', '39938']
#
# Reader ID: 5678
# Chapters: ['43301', '43302', '43303']
#
# Reader ID: 5688
# Chapters: ['15787', '41232']
#
# Reader ID: 5703
# Chapters: ['47198', '47212']
#
# Reader ID: 5750
# Chapters: ['100289', '35690']
#
# Reader ID: 5778
# Chapters: ['12761', '54535']
#
# Reader ID: 5789
# Chapters: ['57158', '57195', '70653']
#
# Reader ID: 5808
# Chapters: ['48608', '54425']
#
# Reader ID: 5867
# Chapters: ['48852']
#
# Reader ID: 6000
# Chapters: ['55211', '86686']
#
# Reader ID: 6019
# Chapters: ['3185']
#
# Reader ID: 6064
# Chapters: ['300880', '56165', '56168']
#
# Reader ID: 6078
# Chapters: ['54007', '54013']
#
# Reader ID: 6081
# Chapters: ['41997', '41998', '42010']
#
# Reader ID: 6147
# Chapters: ['34605', '34606', '34607']
#
# Reader ID: 6181
# Chapters: ['216552']
#
# Reader ID: 6209
# Chapters: ['34599', '34600', '34601']
#
# Reader ID: 6272
# Chapters: ['70168', '70171', '70191']
#
# Reader ID: 6367
# Chapters: ['65536', '74004']
#
# Reader ID: 6385
# Chapters: ['220959', '34655', '34669']
#
# Reader ID: 6415
# Chapters: ['100596', '111615', '116629']
#
# Reader ID: 6437
# Chapters: ['66172', '66173']
#
# Reader ID: 6454
# Chapters: ['107462', '120342', '93938']
#
# Reader ID: 6476
# Chapters: ['57446', '96661']
#
# Reader ID: 6529
# Chapters: ['62554', '62556']
#
# Reader ID: 6531
# Chapters: ['61334']
#
# Reader ID: 6563
# Chapters: ['285357', '63821']
#
# Reader ID: 6818
# Chapters: ['68772', '76332']
#
# Reader ID: 6836
# Chapters: ['61803', '61804', '76549']
#
# Reader ID: 6848
# Chapters: ['252322', '252323', '76049']
#
# Reader ID: 6880
# Chapters: ['216547']
#
# Reader ID: 6925
# Chapters: ['80680']
#
# Reader ID: 7059
# Chapters: ['77897', '77900', '88364']
#
# Reader ID: 7067
# Chapters: ['76047', '76048']
#
# Reader ID: 7078
# Chapters: ['271888']
#
# Reader ID: 7113
# Chapters: ['86041']
#
# Reader ID: 7148
# Chapters: ['59157', '7763', '82991']
#
# Reader ID: 7178
# Chapters: ['34644', '34645']
#
# Reader ID: 7190
# Chapters: ['90542', '90543']
#
# Reader ID: 7226
# Chapters: ['86964', '86965']
#
# Reader ID: 7264
# Chapters: ['92310', '92314', '92316']
#
# Reader ID: 7278
# Chapters: ['104730', '246956', '91083']
#
# Reader ID: 7302
# Chapters: ['86814', '86815']
#
# Reader ID: 7312
# Chapters: ['92432']
#
# Reader ID: 7367
# Chapters: ['86737']
#
# Reader ID: 7402
# Chapters: ['59171', '90848']
#
# Reader ID: 7447
# Chapters: ['91186', '91187']
#
# Reader ID: 7505
# Chapters: ['258958', '258964', '83618']
#
# Reader ID: 7511
# Chapters: ['102419', '102420']
#
# Reader ID: 7517
# Chapters: ['100429', '100437', '100442']
#
# Reader ID: 7635
# Chapters: ['105409', '105661']
#
# Reader ID: 7780
# Chapters: ['274562']
#
# Reader ID: 7794
# Chapters: ['295947', '295948', '295955']
#
# Reader ID: 7800
# Chapters: ['283478', '283492', '283493']
#
# Reader ID: 7859
# Chapters: ['102518', '102519', '102521']
#
# Reader ID: 8014
# Chapters: ['112586', '112602', '280382']
#
# Reader ID: 8051
# Chapters: ['118101', '119902', '295385']
#
# Reader ID: 8063
# Chapters: ['274112', '274115', '274116', '274117']
#
# Reader ID: 8088
# Chapters: ['284756']
#
# Reader ID: 8095
# Chapters: ['274345', '274346', '274348']
#
# Reader ID: 8098
# Chapters: ['275181', '278252', '278278']
#
# Reader ID: 8108
# Chapters: ['274318', '280354', '280359']
#
# Reader ID: 8123
# Chapters: ['275193', '275209', '275216']
#
# Reader ID: 8226
# Chapters: ['274369', '274371']
#
# Reader ID: 8238
# Chapters: ['274553', '283452']
#
# Reader ID: 8312
# Chapters: ['279790', '279791']
#
# Reader ID: 8324
# Chapters: ['286681', '286682', '286683']
#
# Reader ID: 8419
# Chapters: ['286667', '286676', '293469', '293473']
#
# Reader ID: 8425
# Chapters: ['246962', '287387', '291444', '292520']
#
# Reader ID: 8465
# Chapters: ['246940', '246942', '246943', '246947']
#
# Reader ID: 8468
# Chapters: ['286673', '294887', '295198']
#
# Reader ID: 8580
# Chapters: ['287363', '287364']
#
# Reader ID: 8609
# Chapters: ['262281', '283227']
#
# Reader ID: 8629
# Chapters: ['261139', '261140']
#
# Reader ID: 8630
# Chapters: ['305212', '305213']
#
# Reader ID: 8747
# Chapters: ['293952']
#
# Reader ID: 8770
# Chapters: ['295462', '295463', '295465']
#
# Reader ID: 8797
# Chapters: ['294123']
#
# Reader ID: 8838
# Chapters: ['298545', '298546']
#
# Reader ID: 8975
# Chapters: ['270782']

# %%
statistics = compute_statistics(data)
print_statistics(statistics)
# Out:
# Statistics for value_1:
#   min: 0.954
#   Q1: 11.802
#   median: 15.8058
#   Q3: 18.518
#   max: 37.3284
#   mean: 15.1214
#
# Statistics for value_2:
#   min: 0.5972
#   Q1: 8.7658
#   median: 12.239
#   Q3: 14.8351
#   max: 29.0571
#   mean: 11.8289

# %%
for reader in data:
    print(f"Reader: {reader}")
    for chapter in data[reader].keys():
        percent_diff = np.array([percent_difference(initial,final) for initial,final in data[reader][chapter]])
        intial_snr  = np.array([initial for initial, _ in data[reader][chapter]])
        cleaned_snr = np.array([cleaned for _, cleaned in data[reader][chapter]])
        print(f"    Chapter: {chapter}")
        print(f"        Avg percent diff  : {np.mean(percent_diff)}")
        print(f"        Avg SNR pre clean : {np.mean(intial_snr)}")
        print(f"        Avg SNR post clean: {np.mean(cleaned_snr)}")
# Out:
# Reader: 19
#     Chapter: 198
#         Avg percent diff  : -0.1854437249282706
#         Avg SNR pre clean : 15.971093243770767
#         Avg SNR post clean: 13.02017893693522
#     Chapter: 227
#         Avg percent diff  : -0.17818077971338103
#         Avg SNR pre clean : 15.924313419098267
#         Avg SNR post clean: 13.090875647205129
# Reader: 26
#     Chapter: 495
#         Avg percent diff  : -0.25557748517027
#         Avg SNR pre clean : 7.70127130912547
#         Avg SNR post clean: 5.733370631414561
#     Chapter: 496
#         Avg percent diff  : -0.24686527780556278
#         Avg SNR pre clean : 8.217966984486033
#         Avg SNR post clean: 6.194490355169729
# Reader: 27
#     Chapter: 123349
#         Avg percent diff  : -0.2302424468975055
#         Avg SNR pre clean : 9.213555031516938
#         Avg SNR post clean: 7.10992757389114
#     Chapter: 124992
#         Avg percent diff  : -0.180234829030317
#         Avg SNR pre clean : 9.749135784097517
#         Avg SNR post clean: 8.034740384307701
# Reader: 32
#     Chapter: 21625
#         Avg percent diff  : -0.31956963424268875
#         Avg SNR pre clean : 8.819540237881581
#         Avg SNR post clean: 6.027363180749806
#     Chapter: 21631
#         Avg percent diff  : -0.22596823590638868
#         Avg SNR pre clean : 8.706664797497321
#         Avg SNR post clean: 6.7394303168916565
#     Chapter: 21634
#         Avg percent diff  : -0.2460531773395216
#         Avg SNR pre clean : 9.012678637892922
#         Avg SNR post clean: 6.7901017365745675
#     Chapter: 4137
#         Avg percent diff  : -0.18613923125051057
#         Avg SNR pre clean : 18.21816547488266
#         Avg SNR post clean: 14.847045794417141
# Reader: 39
#     Chapter: 121914
#         Avg percent diff  : -0.39049829520529283
#         Avg SNR pre clean : 10.961010432783363
#         Avg SNR post clean: 6.766625849910807
#     Chapter: 121915
#         Avg percent diff  : -0.4013078753549961
#         Avg SNR pre clean : 10.584921543285182
#         Avg SNR post clean: 6.384077038823907
#     Chapter: 121916
#         Avg percent diff  : -0.42125811619255604
#         Avg SNR pre clean : 10.500694475277728
#         Avg SNR post clean: 6.201640185195192
# Reader: 40
#     Chapter: 121026
#         Avg percent diff  : -0.1767088371682744
#         Avg SNR pre clean : 21.293997185546385
#         Avg SNR post clean: 17.54226742320493
#     Chapter: 222
#         Avg percent diff  : -0.17306619900873887
#         Avg SNR pre clean : 18.223985162345322
#         Avg SNR post clean: 15.078384000611099
# Reader: 60
#     Chapter: 121082
#         Avg percent diff  : -0.19834910352357432
#         Avg SNR pre clean : 14.61218010351736
#         Avg SNR post clean: 11.712925844766
# Reader: 78
#     Chapter: 368
#         Avg percent diff  : -0.2271196050733236
#         Avg SNR pre clean : 16.066697120823207
#         Avg SNR post clean: 12.481478275299562
#     Chapter: 369
#         Avg percent diff  : -0.2439586493353988
#         Avg SNR pre clean : 15.903146393841102
#         Avg SNR post clean: 12.115003614538058
# Reader: 83
#     Chapter: 11691
#         Avg percent diff  : -0.09270542092348708
#         Avg SNR pre clean : 16.4841885655278
#         Avg SNR post clean: 14.9526228664592
#     Chapter: 3054
#         Avg percent diff  : -0.08877617548069516
#         Avg SNR pre clean : 16.262592225341923
#         Avg SNR post clean: 14.819387253952613
#     Chapter: 9960
#         Avg percent diff  : -0.11496630501354871
#         Avg SNR pre clean : 16.236935690954695
#         Avg SNR post clean: 14.3791258671541
# Reader: 87
#     Chapter: 121553
#         Avg percent diff  : -0.21285386601933964
#         Avg SNR pre clean : 14.801670443028225
#         Avg SNR post clean: 11.670763689708371
# Reader: 89
#     Chapter: 218
#         Avg percent diff  : -0.2864764066626991
#         Avg SNR pre clean : 17.163773103614943
#         Avg SNR post clean: 12.285388009003217
#     Chapter: 219
#         Avg percent diff  : -0.2607123629243839
#         Avg SNR pre clean : 17.737153011198487
#         Avg SNR post clean: 13.16653373585489
# Reader: 103
#     Chapter: 1240
#         Avg percent diff  : -0.21408387831380615
#         Avg SNR pre clean : 10.599191393342192
#         Avg SNR post clean: 8.332151511282822
#     Chapter: 1241
#         Avg percent diff  : -0.24760625887872817
#         Avg SNR pre clean : 11.2361043387821
#         Avg SNR post clean: 8.4659322006137
# Reader: 118
#     Chapter: 121721
#         Avg percent diff  : -0.21750807503243227
#         Avg SNR pre clean : 15.40784187427811
#         Avg SNR post clean: 12.094820696082511
#     Chapter: 124588
#         Avg percent diff  : -0.2094945281107616
#         Avg SNR pre clean : 20.07990145268605
#         Avg SNR post clean: 15.895847504648561
#     Chapter: 47824
#         Avg percent diff  : -0.1750950807799558
#         Avg SNR pre clean : 17.068472445522033
#         Avg SNR post clean: 14.122555317987372
# Reader: 125
#     Chapter: 121124
#         Avg percent diff  : -0.20776570352403095
#         Avg SNR pre clean : 8.608661990734037
#         Avg SNR post clean: 6.862678887233325
#     Chapter: 121342
#         Avg percent diff  : -0.37492019056091763
#         Avg SNR pre clean : 7.134142378563955
#         Avg SNR post clean: 4.513468183566873
# Reader: 150
#     Chapter: 126107
#         Avg percent diff  : -0.40001529940627534
#         Avg SNR pre clean : 10.221706085735464
#         Avg SNR post clean: 6.149203982816709
#     Chapter: 126112
#         Avg percent diff  : -0.39171449387055385
#         Avg SNR pre clean : 11.037337221735736
#         Avg SNR post clean: 6.720472057082155
#     Chapter: 132655
#         Avg percent diff  : -0.2509003170913354
#         Avg SNR pre clean : 7.769189146385764
#         Avg SNR post clean: 5.852745616080492
# Reader: 163
#     Chapter: 121908
#         Avg percent diff  : -0.2983372526013435
#         Avg SNR pre clean : 14.9875830828522
#         Avg SNR post clean: 10.540631046190954
#     Chapter: 122947
#         Avg percent diff  : -0.22954687814503125
#         Avg SNR pre clean : 17.44937408656325
#         Avg SNR post clean: 13.497752177133187
# Reader: 196
#     Chapter: 122150
#         Avg percent diff  : -0.204995290286609
#         Avg SNR pre clean : 13.68018903543728
#         Avg SNR post clean: 10.880812544643057
#     Chapter: 122152
#         Avg percent diff  : -0.20184703350059394
#         Avg SNR pre clean : 14.699868595092857
#         Avg SNR post clean: 11.749856668518149
#     Chapter: 122159
#         Avg percent diff  : -0.1925725160855458
#         Avg SNR pre clean : 16.85052816788072
#         Avg SNR post clean: 13.629749680164911
# Reader: 198
#     Chapter: 126831
#         Avg percent diff  : -0.17233828559972247
#         Avg SNR pre clean : 18.495730272870933
#         Avg SNR post clean: 15.304329923427392
#     Chapter: 129977
#         Avg percent diff  : -0.18329186589154267
#         Avg SNR pre clean : 17.528311713898177
#         Avg SNR post clean: 14.317663103747984
#     Chapter: 209
#         Avg percent diff  : -0.24100172387475802
#         Avg SNR pre clean : 12.025246023931802
#         Avg SNR post clean: 9.15830030813325
# Reader: 200
#     Chapter: 124139
#         Avg percent diff  : -0.19498308303135306
#         Avg SNR pre clean : 19.139373170359484
#         Avg SNR post clean: 15.42708047657521
#     Chapter: 124140
#         Avg percent diff  : -0.19991928714264448
#         Avg SNR pre clean : 16.679157930092977
#         Avg SNR post clean: 13.367776877636189
#     Chapter: 126784
#         Avg percent diff  : -0.18803615310369495
#         Avg SNR pre clean : 18.5933049578182
#         Avg SNR post clean: 15.11852621732227
# Reader: 201
#     Chapter: 122255
#         Avg percent diff  : -0.1891724080995069
#         Avg SNR pre clean : 11.178380989706737
#         Avg SNR post clean: 9.122510026350684
#     Chapter: 127786
#         Avg percent diff  : -0.24007126285707986
#         Avg SNR pre clean : 16.905119450790753
#         Avg SNR post clean: 12.891194561683971
# Reader: 211
#     Chapter: 122425
#         Avg percent diff  : -0.3033868757148601
#         Avg SNR pre clean : 12.798022663572402
#         Avg SNR post clean: 8.96117727678482
#     Chapter: 122442
#         Avg percent diff  : -0.29159503814309784
#         Avg SNR pre clean : 12.032966160527804
#         Avg SNR post clean: 8.584223630161844
# Reader: 226
#     Chapter: 122538
#         Avg percent diff  : -0.2542361884549015
#         Avg SNR pre clean : 8.922955803981774
#         Avg SNR post clean: 6.673615220978205
#     Chapter: 131532
#         Avg percent diff  : -0.2970403235805374
#         Avg SNR pre clean : 9.737086583696072
#         Avg SNR post clean: 6.887551385234219
#     Chapter: 131533
#         Avg percent diff  : -0.30998565147043916
#         Avg SNR pre clean : 8.62358664487322
#         Avg SNR post clean: 5.982270083080198
# Reader: 229
#     Chapter: 130880
#         Avg percent diff  : -0.14253715862730085
#         Avg SNR pre clean : 20.57787287017998
#         Avg SNR post clean: 17.653607101191408
# Reader: 233
#     Chapter: 134440
#         Avg percent diff  : -0.23546887825664428
#         Avg SNR pre clean : 17.733601171465438
#         Avg SNR post clean: 13.616638926255952
#     Chapter: 155990
#         Avg percent diff  : -0.11713306341412441
#         Avg SNR pre clean : 14.547701518441645
#         Avg SNR post clean: 12.844961899681545
# Reader: 248
#     Chapter: 130644
#         Avg percent diff  : -0.3153185295787289
#         Avg SNR pre clean : 6.442877896752313
#         Avg SNR post clean: 4.46511285389996
#     Chapter: 130652
#         Avg percent diff  : -0.377117954202701
#         Avg SNR pre clean : 6.641929542715441
#         Avg SNR post clean: 4.1773432241367185
#     Chapter: 130697
#         Avg percent diff  : -0.4431200388843662
#         Avg SNR pre clean : 7.58445641913075
#         Avg SNR post clean: 4.228712143598154
# Reader: 250
#     Chapter: 140277
#         Avg percent diff  : -0.24789285892111004
#         Avg SNR pre clean : 15.787266429358036
#         Avg SNR post clean: 11.922664953486942
#     Chapter: 142276
#         Avg percent diff  : -0.3575256380968249
#         Avg SNR pre clean : 11.909824983165658
#         Avg SNR post clean: 7.767178820429284
#     Chapter: 142286
#         Avg percent diff  : -0.20303397269544962
#         Avg SNR pre clean : 18.73585504504952
#         Avg SNR post clean: 14.957019677685983
# Reader: 254
#     Chapter: 12312
#         Avg percent diff  : -0.30029380158878544
#         Avg SNR pre clean : 15.761243117378438
#         Avg SNR post clean: 11.119236130870094
#     Chapter: 127705
#         Avg percent diff  : -0.2790573912666562
#         Avg SNR pre clean : 11.902441785277269
#         Avg SNR post clean: 8.648199571622394
#     Chapter: 145458
#         Avg percent diff  : -0.22434810454446186
#         Avg SNR pre clean : 18.300118557298607
#         Avg SNR post clean: 14.223165412894438
#     Chapter: 27760
#         Avg percent diff  : -0.24226122327001945
#         Avg SNR pre clean : 15.60909867365051
#         Avg SNR post clean: 11.861306467788813
# Reader: 289
#     Chapter: 121652
#         Avg percent diff  : -0.300396432250272
#         Avg SNR pre clean : 4.3096679303058005
#         Avg SNR post clean: 2.983947812685418
#     Chapter: 121665
#         Avg percent diff  : -0.2730519011863459
#         Avg SNR pre clean : 4.145468285488107
#         Avg SNR post clean: 2.9905107522552847
# Reader: 298
#     Chapter: 126790
#         Avg percent diff  : -0.17998034536683452
#         Avg SNR pre clean : 12.010786003406118
#         Avg SNR post clean: 9.849654770228652
#     Chapter: 126791
#         Avg percent diff  : -0.15758896199515465
#         Avg SNR pre clean : 11.565884814002937
#         Avg SNR post clean: 9.744929079913547
# Reader: 302
#     Chapter: 123504
#         Avg percent diff  : -0.44890751708841287
#         Avg SNR pre clean : 8.584089736033944
#         Avg SNR post clean: 4.765010488974959
#     Chapter: 123516
#         Avg percent diff  : -0.39578663272465187
#         Avg SNR pre clean : 10.703225920199472
#         Avg SNR post clean: 6.57096886699658
#     Chapter: 123523
#         Avg percent diff  : -0.494851081514805
#         Avg SNR pre clean : 7.217665079044538
#         Avg SNR post clean: 3.6848131727595783
# Reader: 307
#     Chapter: 127535
#         Avg percent diff  : -0.22755094632156522
#         Avg SNR pre clean : 11.897159547993681
#         Avg SNR post clean: 9.182547551372277
#     Chapter: 127539
#         Avg percent diff  : -0.2578694119761865
#         Avg SNR pre clean : 13.885112727092249
#         Avg SNR post clean: 10.326008138725767
#     Chapter: 127540
#         Avg percent diff  : -0.25543707861909637
#         Avg SNR pre clean : 14.646620946730788
#         Avg SNR post clean: 10.921315296983824
# Reader: 311
#     Chapter: 124404
#         Avg percent diff  : -0.2598685365115564
#         Avg SNR pre clean : 10.121837610671783
#         Avg SNR post clean: 7.537088715095441
# Reader: 322
#     Chapter: 124146
#         Avg percent diff  : -0.2550081975274983
#         Avg SNR pre clean : 10.185938653182522
#         Avg SNR post clean: 7.69572884538622
#     Chapter: 124147
#         Avg percent diff  : -0.2929089386097814
#         Avg SNR pre clean : 9.67772594605901
#         Avg SNR post clean: 6.8862481781567695
# Reader: 328
#     Chapter: 129766
#         Avg percent diff  : -0.34977216003989775
#         Avg SNR pre clean : 15.677497723189909
#         Avg SNR post clean: 10.280272962776122
# Reader: 332
#     Chapter: 128985
#         Avg percent diff  : -0.19882641728067763
#         Avg SNR pre clean : 10.290429053043804
#         Avg SNR post clean: 8.245664083040394
# Reader: 374
#     Chapter: 180298
#         Avg percent diff  : -0.22172083976913137
#         Avg SNR pre clean : 17.335820311594798
#         Avg SNR post clean: 13.516178244535265
#     Chapter: 180299
#         Avg percent diff  : -0.20278305447301254
#         Avg SNR pre clean : 17.268008977958914
#         Avg SNR post clean: 13.80729951156452
# Reader: 403
#     Chapter: 126855
#         Avg percent diff  : -0.23405783717129022
#         Avg SNR pre clean : 17.023034058745694
#         Avg SNR post clean: 13.065912371621096
#     Chapter: 128339
#         Avg percent diff  : -0.2484878267984341
#         Avg SNR pre clean : 17.227017007380727
#         Avg SNR post clean: 12.962148554293282
#     Chapter: 216
#         Avg percent diff  : -0.2737539365281948
#         Avg SNR pre clean : 17.20995941910429
#         Avg SNR post clean: 12.52186379131399
# Reader: 405
#     Chapter: 130894
#         Avg percent diff  : -0.21952765964741067
#         Avg SNR pre clean : 12.52438806569689
#         Avg SNR post clean: 9.795139156419824
#     Chapter: 130895
#         Avg percent diff  : -0.20475646769252467
#         Avg SNR pre clean : 12.546133522459893
#         Avg SNR post clean: 10.002402482414658
# Reader: 412
#     Chapter: 126975
#         Avg percent diff  : -0.14078303857121227
#         Avg SNR pre clean : 29.786649790342363
#         Avg SNR post clean: 25.597418155121087
# Reader: 426
#     Chapter: 122819
#         Avg percent diff  : -0.26258040208261824
#         Avg SNR pre clean : 16.718008343162676
#         Avg SNR post clean: 12.343332408201038
#     Chapter: 122821
#         Avg percent diff  : -0.19847038668121245
#         Avg SNR pre clean : 21.204197102298746
#         Avg SNR post clean: 17.001183193965772
#     Chapter: 122822
#         Avg percent diff  : -0.2393082703313015
#         Avg SNR pre clean : 20.319725351611957
#         Avg SNR post clean: 15.51438382348184
# Reader: 441
#     Chapter: 128982
#         Avg percent diff  : -0.44033951221284096
#         Avg SNR pre clean : 13.439193784858338
#         Avg SNR post clean: 7.586579431166182
#     Chapter: 128988
#         Avg percent diff  : -0.42706629578062766
#         Avg SNR pre clean : 13.873186743413903
#         Avg SNR post clean: 7.997661283118011
#     Chapter: 130108
#         Avg percent diff  : -0.39555403098759667
#         Avg SNR pre clean : 13.636249020602847
#         Avg SNR post clean: 8.443047015282087
# Reader: 445
#     Chapter: 123857
#         Avg percent diff  : -0.29727565104913056
#         Avg SNR pre clean : 31.719009781970534
#         Avg SNR post clean: 22.325512706223122
#     Chapter: 123860
#         Avg percent diff  : -0.31692410371347307
#         Avg SNR pre clean : 33.22535911117664
#         Avg SNR post clean: 22.74565771407562
# Reader: 446
#     Chapter: 123501
#         Avg percent diff  : -0.1260731193200907
#         Avg SNR pre clean : 16.1251437087652
#         Avg SNR post clean: 14.093366576691539
#     Chapter: 123502
#         Avg percent diff  : -0.1397819589748356
#         Avg SNR pre clean : 13.26203734143773
#         Avg SNR post clean: 11.400617377395799
# Reader: 458
#     Chapter: 126290
#         Avg percent diff  : -0.2245942933557151
#         Avg SNR pre clean : 17.601132425596354
#         Avg SNR post clean: 13.669446779339818
#     Chapter: 126294
#         Avg percent diff  : -0.15144715320606947
#         Avg SNR pre clean : 19.878999819264088
#         Avg SNR post clean: 16.94116516611344
#     Chapter: 126305
#         Avg percent diff  : -0.19628566509143464
#         Avg SNR pre clean : 18.69502268341963
#         Avg SNR post clean: 15.071583365439178
# Reader: 460
#     Chapter: 172357
#         Avg percent diff  : -0.1679187674249201
#         Avg SNR pre clean : 18.01034227348776
#         Avg SNR post clean: 15.010838060052318
#     Chapter: 172359
#         Avg percent diff  : -0.16243930477243992
#         Avg SNR pre clean : 17.55902942591173
#         Avg SNR post clean: 14.734934553988728
# Reader: 481
#     Chapter: 123719
#         Avg percent diff  : -0.11165377020876385
#         Avg SNR pre clean : 19.25595661352403
#         Avg SNR post clean: 17.118975992406614
#     Chapter: 123720
#         Avg percent diff  : -0.12030178247677781
#         Avg SNR pre clean : 18.410880730252437
#         Avg SNR post clean: 16.200005243409482
# Reader: 587
#     Chapter: 41611
#         Avg percent diff  : -0.2703041085803338
#         Avg SNR pre clean : 5.187968440333916
#         Avg SNR post clean: 3.7955607634075355
#     Chapter: 41619
#         Avg percent diff  : -0.3176127057011636
#         Avg SNR pre clean : 4.800858368838003
#         Avg SNR post clean: 3.3051805121225644
#     Chapter: 54108
#         Avg percent diff  : -0.3600745867333217
#         Avg SNR pre clean : 3.9123380134509023
#         Avg SNR post clean: 2.526460636771042
# Reader: 625
#     Chapter: 132112
#         Avg percent diff  : -0.12241440532910387
#         Avg SNR pre clean : 22.86292074285755
#         Avg SNR post clean: 20.0693285268554
#     Chapter: 132118
#         Avg percent diff  : -0.11854344586880662
#         Avg SNR pre clean : 22.612451983516195
#         Avg SNR post clean: 19.93685620509738
# Reader: 669
#     Chapter: 129061
#         Avg percent diff  : -0.24660854271038674
#         Avg SNR pre clean : 15.84692325472515
#         Avg SNR post clean: 11.952038383684302
#     Chapter: 129074
#         Avg percent diff  : -0.2730615283084296
#         Avg SNR pre clean : 16.19084115913452
#         Avg SNR post clean: 11.824081291230883
# Reader: 696
#     Chapter: 92939
#         Avg percent diff  : -0.163793970372684
#         Avg SNR pre clean : 15.655524645734067
#         Avg SNR post clean: 13.088702468773434
#     Chapter: 93314
#         Avg percent diff  : -0.17265145294929865
#         Avg SNR pre clean : 17.63191666156182
#         Avg SNR post clean: 14.591650053376844
# Reader: 730
#     Chapter: 358
#         Avg percent diff  : -0.30030336779921796
#         Avg SNR pre clean : 19.015295335059438
#         Avg SNR post clean: 13.37292967429255
#     Chapter: 359
#         Avg percent diff  : -0.3148974100207647
#         Avg SNR pre clean : 17.931081401296534
#         Avg SNR post clean: 12.347325578952631
#     Chapter: 360
#         Avg percent diff  : -0.3223194282162189
#         Avg SNR pre clean : 18.35155148179098
#         Avg SNR post clean: 12.473942641496915
# Reader: 831
#     Chapter: 130739
#         Avg percent diff  : -0.18976582432654643
#         Avg SNR pre clean : 22.95371930728622
#         Avg SNR post clean: 18.627497862876584
#     Chapter: 130746
#         Avg percent diff  : -0.21110058447474245
#         Avg SNR pre clean : 20.802359596344857
#         Avg SNR post clean: 16.437073241607962
# Reader: 839
#     Chapter: 130898
#         Avg percent diff  : -0.2188193473811728
#         Avg SNR pre clean : 17.51308988144599
#         Avg SNR post clean: 13.682461148858089
# Reader: 887
#     Chapter: 123289
#         Avg percent diff  : -0.15406818930487817
#         Avg SNR pre clean : 14.883741571718849
#         Avg SNR post clean: 12.601369933513581
#     Chapter: 123290
#         Avg percent diff  : -0.1579610999441799
#         Avg SNR pre clean : 14.710617549595366
#         Avg SNR post clean: 12.403976150883363
#     Chapter: 123291
#         Avg percent diff  : -0.17146788225733603
#         Avg SNR pre clean : 14.58070188998942
#         Avg SNR post clean: 12.095684349633736
# Reader: 909
#     Chapter: 131041
#         Avg percent diff  : -0.19608184189610983
#         Avg SNR pre clean : 18.54550285075363
#         Avg SNR post clean: 14.921606666460573
#     Chapter: 131044
#         Avg percent diff  : -0.21990568835081079
#         Avg SNR pre clean : 18.75988913425123
#         Avg SNR post clean: 14.641246105530525
#     Chapter: 131045
#         Avg percent diff  : -0.2171372206300462
#         Avg SNR pre clean : 19.068988252304585
#         Avg SNR post clean: 14.940110556415716
# Reader: 911
#     Chapter: 128684
#         Avg percent diff  : -0.19493792878603916
#         Avg SNR pre clean : 11.191902106417873
#         Avg SNR post clean: 9.031203555233953
#     Chapter: 130578
#         Avg percent diff  : -0.21530208044704927
#         Avg SNR pre clean : 12.282552032448226
#         Avg SNR post clean: 9.666033701781178
# Reader: 1034
#     Chapter: 121119
#         Avg percent diff  : -0.13221848927087884
#         Avg SNR pre clean : 19.95448759093753
#         Avg SNR post clean: 17.32646146695728
# Reader: 1040
#     Chapter: 133433
#         Avg percent diff  : -0.1705238644723795
#         Avg SNR pre clean : 15.558318715689607
#         Avg SNR post clean: 12.932772321825679
# Reader: 1069
#     Chapter: 133699
#         Avg percent diff  : -0.27937311514490976
#         Avg SNR pre clean : 13.695115802390314
#         Avg SNR post clean: 9.903905846272435
#     Chapter: 133709
#         Avg percent diff  : -0.2671293104595782
#         Avg SNR pre clean : 13.993736545529364
#         Avg SNR post clean: 10.27367649591534
# Reader: 1081
#     Chapter: 125237
#         Avg percent diff  : -0.2381394138939514
#         Avg SNR pre clean : 11.966826234155054
#         Avg SNR post clean: 9.128435815226666
#     Chapter: 128618
#         Avg percent diff  : -0.23150942249059098
#         Avg SNR pre clean : 15.650508214632435
#         Avg SNR post clean: 12.053822099242486
# Reader: 1088
#     Chapter: 129236
#         Avg percent diff  : -0.18824127681481123
#         Avg SNR pre clean : 19.724846564955154
#         Avg SNR post clean: 16.023541216838694
#     Chapter: 134315
#         Avg percent diff  : -0.18877402596347598
#         Avg SNR pre clean : 19.830224977600672
#         Avg SNR post clean: 16.103373299326453
#     Chapter: 134318
#         Avg percent diff  : -0.15048866512505768
#         Avg SNR pre clean : 19.90059258903199
#         Avg SNR post clean: 16.92212598607406
# Reader: 1098
#     Chapter: 133695
#         Avg percent diff  : -0.29895719950090016
#         Avg SNR pre clean : 14.841918326894675
#         Avg SNR post clean: 10.45403781168003
# Reader: 1116
#     Chapter: 132847
#         Avg percent diff  : -0.16139151494538426
#         Avg SNR pre clean : 5.697654466640704
#         Avg SNR post clean: 4.773580432753132
#     Chapter: 132851
#         Avg percent diff  : -0.1586482105653376
#         Avg SNR pre clean : 6.7281715418085914
#         Avg SNR post clean: 5.67176466353205
#     Chapter: 137572
#         Avg percent diff  : -0.1378225834665612
#         Avg SNR pre clean : 5.998444408363859
#         Avg SNR post clean: 5.17375383084683
# Reader: 1183
#     Chapter: 124566
#         Avg percent diff  : -0.25365954726206397
#         Avg SNR pre clean : 6.2769232886509485
#         Avg SNR post clean: 4.793820157667924
#     Chapter: 128659
#         Avg percent diff  : -0.2875413394514792
#         Avg SNR pre clean : 5.574181016740153
#         Avg SNR post clean: 3.9951005552450014
#     Chapter: 133255
#         Avg percent diff  : -0.2720949610899671
#         Avg SNR pre clean : 5.74217966524668
#         Avg SNR post clean: 4.20940979187613
#     Chapter: 133256
#         Avg percent diff  : -0.15860913226396492
#         Avg SNR pre clean : 6.733810149409049
#         Avg SNR post clean: 5.666580053247204
# Reader: 1235
#     Chapter: 135883
#         Avg percent diff  : -0.18045409784177674
#         Avg SNR pre clean : 17.60839958160767
#         Avg SNR post clean: 14.44963781115331
#     Chapter: 135884
#         Avg percent diff  : -0.12455858271959705
#         Avg SNR pre clean : 17.97261578580575
#         Avg SNR post clean: 15.737851492344042
#     Chapter: 135887
#         Avg percent diff  : -0.1812752140405638
#         Avg SNR pre clean : 16.95595638365429
#         Avg SNR post clean: 13.89072635403935
# Reader: 1246
#     Chapter: 124548
#         Avg percent diff  : -0.30027023567783256
#         Avg SNR pre clean : 9.111013298998875
#         Avg SNR post clean: 6.451389177690772
#     Chapter: 124550
#         Avg percent diff  : -0.21691152790634732
#         Avg SNR pre clean : 15.645797840924226
#         Avg SNR post clean: 12.27311440841971
#     Chapter: 135815
#         Avg percent diff  : -0.21996788286291502
#         Avg SNR pre clean : 12.597057236289393
#         Avg SNR post clean: 9.861351002310899
# Reader: 1263
#     Chapter: 138246
#         Avg percent diff  : -0.15811815264750706
#         Avg SNR pre clean : 15.714262707870427
#         Avg SNR post clean: 13.235731554052297
#     Chapter: 139804
#         Avg percent diff  : -0.22055060165601287
#         Avg SNR pre clean : 13.939165120192035
#         Avg SNR post clean: 10.876168951309761
#     Chapter: 141777
#         Avg percent diff  : -0.15987925197354413
#         Avg SNR pre clean : 12.74068196887173
#         Avg SNR post clean: 10.722110440313408
# Reader: 1334
#     Chapter: 135589
#         Avg percent diff  : -0.2566914222987769
#         Avg SNR pre clean : 9.83321966121064
#         Avg SNR post clean: 7.3469343922132575
# Reader: 1355
#     Chapter: 39947
#         Avg percent diff  : -0.21990571081843294
#         Avg SNR pre clean : 16.453197484067186
#         Avg SNR post clean: 12.847332412782473
# Reader: 1363
#     Chapter: 135842
#         Avg percent diff  : -0.2911204979912996
#         Avg SNR pre clean : 25.336452769618862
#         Avg SNR post clean: 17.95180383481468
#     Chapter: 139304
#         Avg percent diff  : -0.18579555429325514
#         Avg SNR pre clean : 15.638321111448825
#         Avg SNR post clean: 12.740668808662793
# Reader: 1447
#     Chapter: 130550
#         Avg percent diff  : -0.3241307657314165
#         Avg SNR pre clean : 14.84361990008331
#         Avg SNR post clean: 10.118903172991226
#     Chapter: 130551
#         Avg percent diff  : -0.4300495489392214
#         Avg SNR pre clean : 19.340267552544333
#         Avg SNR post clean: 11.098629988706762
#     Chapter: 130552
#         Avg percent diff  : -0.4178144051050751
#         Avg SNR pre clean : 22.474056164203095
#         Avg SNR post clean: 13.15039283245541
#     Chapter: 17506
#         Avg percent diff  : -0.3090486537192871
#         Avg SNR pre clean : 13.454999792190403
#         Avg SNR post clean: 9.32285982969295
# Reader: 1455
#     Chapter: 134435
#         Avg percent diff  : -0.41635611761067515
#         Avg SNR pre clean : 6.798464390834166
#         Avg SNR post clean: 4.020927329016225
#     Chapter: 138263
#         Avg percent diff  : -0.30088892470499595
#         Avg SNR pre clean : 9.25283735368934
#         Avg SNR post clean: 6.559929366253172
# Reader: 1502
#     Chapter: 122615
#         Avg percent diff  : -0.21738514542121876
#         Avg SNR pre clean : 22.135786463230154
#         Avg SNR post clean: 17.337626629195334
#     Chapter: 122619
#         Avg percent diff  : -0.18622996885087154
#         Avg SNR pre clean : 22.69917337751947
#         Avg SNR post clean: 18.492980846692685
# Reader: 1553
#     Chapter: 140047
#         Avg percent diff  : -0.3673958172389012
#         Avg SNR pre clean : 8.995678578419655
#         Avg SNR post clean: 5.734292609526725
#     Chapter: 140048
#         Avg percent diff  : -0.3350905547164945
#         Avg SNR pre clean : 9.963457581964132
#         Avg SNR post clean: 6.688709269233664
# Reader: 1578
#     Chapter: 140045
#         Avg percent diff  : -0.1922402520555914
#         Avg SNR pre clean : 17.906068108692867
#         Avg SNR post clean: 14.465563217694854
#     Chapter: 140049
#         Avg percent diff  : -0.19474549248919346
#         Avg SNR pre clean : 16.27919235163093
#         Avg SNR post clean: 13.109446101435738
#     Chapter: 6379
#         Avg percent diff  : -0.15587273565599652
#         Avg SNR pre clean : 15.02770666183879
#         Avg SNR post clean: 12.697323345209341
# Reader: 1594
#     Chapter: 135914
#         Avg percent diff  : -0.14728614885898006
#         Avg SNR pre clean : 10.780800838111627
#         Avg SNR post clean: 9.228784025652745
# Reader: 1624
#     Chapter: 142933
#         Avg percent diff  : -0.2987996804699955
#         Avg SNR pre clean : 12.554150196001078
#         Avg SNR post clean: 8.832723681235692
#     Chapter: 168623
#         Avg percent diff  : -0.38291616409702356
#         Avg SNR pre clean : 12.025168468068056
#         Avg SNR post clean: 7.489048612438979
# Reader: 1723
#     Chapter: 141149
#         Avg percent diff  : -0.3631928525757429
#         Avg SNR pre clean : 6.057294465156572
#         Avg SNR post clean: 3.8974769364367856
# Reader: 1737
#     Chapter: 142396
#         Avg percent diff  : -0.47505380459382013
#         Avg SNR pre clean : 4.750396091512102
#         Avg SNR post clean: 2.5059617428061016
#     Chapter: 142397
#         Avg percent diff  : -0.4199957669404966
#         Avg SNR pre clean : 4.435994793138741
#         Avg SNR post clean: 2.6102986085042135
#     Chapter: 146161
#         Avg percent diff  : -0.2497428559834023
#         Avg SNR pre clean : 3.4756042602027923
#         Avg SNR post clean: 2.633053321546693
#     Chapter: 148989
#         Avg percent diff  : -0.3903200697315065
#         Avg SNR pre clean : 2.7067007277105115
#         Avg SNR post clean: 1.6829612501538607
# Reader: 1743
#     Chapter: 142912
#         Avg percent diff  : -0.19327434456043885
#         Avg SNR pre clean : 12.786884822112967
#         Avg SNR post clean: 10.364279995427683
#     Chapter: 142913
#         Avg percent diff  : -0.20222553733753407
#         Avg SNR pre clean : 16.1249121361272
#         Avg SNR post clean: 12.890639359778692
#     Chapter: 142914
#         Avg percent diff  : -0.20213230942402913
#         Avg SNR pre clean : 7.604102053067744
#         Avg SNR post clean: 6.099909514200581
# Reader: 1841
#     Chapter: 150351
#         Avg percent diff  : -0.3373119321015801
#         Avg SNR pre clean : 6.3454660567044
#         Avg SNR post clean: 4.224198778697209
#     Chapter: 159771
#         Avg percent diff  : -0.31939439272851217
#         Avg SNR pre clean : 7.194161331334556
#         Avg SNR post clean: 4.924613472478127
#     Chapter: 179183
#         Avg percent diff  : -0.33688584701553825
#         Avg SNR pre clean : 14.057117477505795
#         Avg SNR post clean: 9.341063208538266
# Reader: 1867
#     Chapter: 148436
#         Avg percent diff  : -0.1672490918224442
#         Avg SNR pre clean : 9.359307187732151
#         Avg SNR post clean: 7.815810357285203
#     Chapter: 154071
#         Avg percent diff  : -0.2008635684492681
#         Avg SNR pre clean : 9.967522762978309
#         Avg SNR post clean: 7.989665908520308
#     Chapter: 154075
#         Avg percent diff  : -0.18986575201727135
#         Avg SNR pre clean : 9.496509081854358
#         Avg SNR post clean: 7.701494640255119
# Reader: 1898
#     Chapter: 145702
#         Avg percent diff  : -0.38903474506402114
#         Avg SNR pre clean : 6.003520334334676
#         Avg SNR post clean: 3.785447097229826
#     Chapter: 145715
#         Avg percent diff  : -0.36084365772035554
#         Avg SNR pre clean : 5.612780802876127
#         Avg SNR post clean: 3.6475997043155113
#     Chapter: 145720
#         Avg percent diff  : -0.14554101701119934
#         Avg SNR pre clean : 16.347195313984447
#         Avg SNR post clean: 13.982262829899232
#     Chapter: 145724
#         Avg percent diff  : -0.34870713198281184
#         Avg SNR pre clean : 6.189027501404132
#         Avg SNR post clean: 4.108300353687944
# Reader: 1926
#     Chapter: 143879
#         Avg percent diff  : -0.25836571968886357
#         Avg SNR pre clean : 9.0053505360179
#         Avg SNR post clean: 6.776634498151075
#     Chapter: 147979
#         Avg percent diff  : -0.20520370524554415
#         Avg SNR pre clean : 10.305713187419984
#         Avg SNR post clean: 8.244730065592742
#     Chapter: 147987
#         Avg percent diff  : -0.2405019849446723
#         Avg SNR pre clean : 9.721918272939023
#         Avg SNR post clean: 7.423117816353026
# Reader: 1963
#     Chapter: 142393
#         Avg percent diff  : -0.15452513724057426
#         Avg SNR pre clean : 9.463886395476106
#         Avg SNR post clean: 8.027327695354447
#     Chapter: 142776
#         Avg percent diff  : -0.20477385982694313
#         Avg SNR pre clean : 8.963737185865321
#         Avg SNR post clean: 7.164851404277556
#     Chapter: 147036
#         Avg percent diff  : -0.19895538587408923
#         Avg SNR pre clean : 10.462366087394635
#         Avg SNR post clean: 8.41548282326848
# Reader: 1970
#     Chapter: 10594
#         Avg percent diff  : -0.28695693201822653
#         Avg SNR pre clean : 16.620819332664368
#         Avg SNR post clean: 11.893071736834226
#     Chapter: 26100
#         Avg percent diff  : -0.2656841012508133
#         Avg SNR pre clean : 17.583703799941656
#         Avg SNR post clean: 12.95768475406976
#     Chapter: 28415
#         Avg percent diff  : -0.274894438630045
#         Avg SNR pre clean : 17.39608941420958
#         Avg SNR post clean: 12.668898789248562
# Reader: 1992
#     Chapter: 141719
#         Avg percent diff  : -0.2963528884136673
#         Avg SNR pre clean : 16.8995112732467
#         Avg SNR post clean: 11.91000220609188
# Reader: 2002
#     Chapter: 139469
#         Avg percent diff  : -0.2995225834131025
#         Avg SNR pre clean : 16.211011561141977
#         Avg SNR post clean: 11.46721131788413
# Reader: 2007
#     Chapter: 132570
#         Avg percent diff  : -0.21094401373627808
#         Avg SNR pre clean : 11.593934525685523
#         Avg SNR post clean: 9.20985749626754
#     Chapter: 149877
#         Avg percent diff  : -0.23630062401482782
#         Avg SNR pre clean : 12.319897474378001
#         Avg SNR post clean: 9.463947488425633
# Reader: 2092
#     Chapter: 145706
#         Avg percent diff  : -0.17940056530362275
#         Avg SNR pre clean : 20.941721469672974
#         Avg SNR post clean: 17.20473941135575
#     Chapter: 145709
#         Avg percent diff  : -0.22734708888778374
#         Avg SNR pre clean : 18.86140231556917
#         Avg SNR post clean: 14.589391581044119
# Reader: 2136
#     Chapter: 5140
#         Avg percent diff  : -0.24791212584031116
#         Avg SNR pre clean : 18.591275063147787
#         Avg SNR post clean: 13.988485101551593
#     Chapter: 5143
#         Avg percent diff  : -0.22434462771063451
#         Avg SNR pre clean : 20.13808027350861
#         Avg SNR post clean: 15.655191392082475
#     Chapter: 5147
#         Avg percent diff  : -0.2199553969473562
#         Avg SNR pre clean : 20.5055300562439
#         Avg SNR post clean: 16.020906002976254
# Reader: 2159
#     Chapter: 179154
#         Avg percent diff  : -0.23480121970330342
#         Avg SNR pre clean : 11.709994067504397
#         Avg SNR post clean: 8.979866355673307
#     Chapter: 179156
#         Avg percent diff  : -0.2124768195825031
#         Avg SNR pre clean : 12.251614744056441
#         Avg SNR post clean: 9.6607088146448
#     Chapter: 179157
#         Avg percent diff  : -0.220393831016104
#         Avg SNR pre clean : 12.189394735841187
#         Avg SNR post clean: 9.525931461875869
# Reader: 2182
#     Chapter: 150130
#         Avg percent diff  : -0.30748960606231696
#         Avg SNR pre clean : 13.00560425430395
#         Avg SNR post clean: 9.042707618990718
#     Chapter: 181173
#         Avg percent diff  : -0.16422267263752138
#         Avg SNR pre clean : 15.672360271663132
#         Avg SNR post clean: 13.118498704453721
#     Chapter: 181183
#         Avg percent diff  : -0.16478586725083427
#         Avg SNR pre clean : 17.62539663465382
#         Avg SNR post clean: 14.75932494960005
# Reader: 2196
#     Chapter: 170151
#         Avg percent diff  : -0.22348603317545937
#         Avg SNR pre clean : 14.538538351190024
#         Avg SNR post clean: 11.319103844622472
#     Chapter: 170379
#         Avg percent diff  : -0.16071163838314445
#         Avg SNR pre clean : 15.316152167232781
#         Avg SNR post clean: 12.875157431471148
#     Chapter: 174172
#         Avg percent diff  : -0.30095907453584453
#         Avg SNR pre clean : 12.335587165922037
#         Avg SNR post clean: 8.682474462678895
# Reader: 2289
#     Chapter: 152253
#         Avg percent diff  : -0.3873208057698575
#         Avg SNR pre clean : 6.816645099058541
#         Avg SNR post clean: 4.238222106688668
#     Chapter: 152254
#         Avg percent diff  : -0.37096277175604236
#         Avg SNR pre clean : 7.596147920683204
#         Avg SNR post clean: 4.809146068155584
#     Chapter: 152257
#         Avg percent diff  : -0.4288775940609527
#         Avg SNR pre clean : 6.123958481891863
#         Avg SNR post clean: 3.5120323453166296
#     Chapter: 152258
#         Avg percent diff  : -0.42204029678550525
#         Avg SNR pre clean : 5.720904879119355
#         Avg SNR post clean: 3.3716512612137346
# Reader: 2384
#     Chapter: 152900
#         Avg percent diff  : -0.21378098975541676
#         Avg SNR pre clean : 14.240853060068126
#         Avg SNR post clean: 11.209479665712854
# Reader: 2391
#     Chapter: 145015
#         Avg percent diff  : -0.18891714091952974
#         Avg SNR pre clean : 17.40658603452388
#         Avg SNR post clean: 14.142531112454565
# Reader: 2416
#     Chapter: 152137
#         Avg percent diff  : -0.24077244647979013
#         Avg SNR pre clean : 11.743731984495804
#         Avg SNR post clean: 8.96970431587276
#     Chapter: 152139
#         Avg percent diff  : -0.18397339111688527
#         Avg SNR pre clean : 12.32601785266489
#         Avg SNR post clean: 10.086141981248902
# Reader: 2436
#     Chapter: 2476
#         Avg percent diff  : -0.20874753566756488
#         Avg SNR pre clean : 15.242522196963112
#         Avg SNR post clean: 12.070616999523658
#     Chapter: 2477
#         Avg percent diff  : -0.2393889045769936
#         Avg SNR pre clean : 14.716425034442034
#         Avg SNR post clean: 11.23262597592771
#     Chapter: 2481
#         Avg percent diff  : -0.13415766845502936
#         Avg SNR pre clean : 15.127138329834693
#         Avg SNR post clean: 13.085212693114673
# Reader: 2514
#     Chapter: 149482
#         Avg percent diff  : -0.19672258540923104
#         Avg SNR pre clean : 19.32250062770666
#         Avg SNR post clean: 15.526368932291097
# Reader: 2518
#     Chapter: 154825
#         Avg percent diff  : -0.2614706614460634
#         Avg SNR pre clean : 17.68384657468807
#         Avg SNR post clean: 13.120142427940928
#     Chapter: 154826
#         Avg percent diff  : -0.2431649762450475
#         Avg SNR pre clean : 16.943810241356786
#         Avg SNR post clean: 12.851150459022017
# Reader: 2691
#     Chapter: 156745
#         Avg percent diff  : -0.1498074780484441
#         Avg SNR pre clean : 20.436260783466935
#         Avg SNR post clean: 17.390244857251446
#     Chapter: 156750
#         Avg percent diff  : -0.1601241376628423
#         Avg SNR pre clean : 21.682729025048253
#         Avg SNR post clean: 18.22450123013186
#     Chapter: 156755
#         Avg percent diff  : -0.16390187243045076
#         Avg SNR pre clean : 20.93672816954902
#         Avg SNR post clean: 17.50468248278627
# Reader: 2764
#     Chapter: 36616
#         Avg percent diff  : -0.2397118489813102
#         Avg SNR pre clean : 6.220384052617121
#         Avg SNR post clean: 4.741200372121893
#     Chapter: 36617
#         Avg percent diff  : -0.26070497923472696
#         Avg SNR pre clean : 6.844567013641529
#         Avg SNR post clean: 5.060338959939384
#     Chapter: 36619
#         Avg percent diff  : -0.30299398398823874
#         Avg SNR pre clean : 6.647706222637944
#         Avg SNR post clean: 4.644517855179403
# Reader: 2817
#     Chapter: 142371
#         Avg percent diff  : -0.23649489826533027
#         Avg SNR pre clean : 13.398621440799527
#         Avg SNR post clean: 10.23818058067066
#     Chapter: 142380
#         Avg percent diff  : -0.25526046643073297
#         Avg SNR pre clean : 14.88999985100064
#         Avg SNR post clean: 11.10306595129213
# Reader: 2836
#     Chapter: 5354
#         Avg percent diff  : -0.29577533559875996
#         Avg SNR pre clean : 9.940420846921144
#         Avg SNR post clean: 7.016537065001884
#     Chapter: 5355
#         Avg percent diff  : -0.2518370937696462
#         Avg SNR pre clean : 10.925472704635448
#         Avg SNR post clean: 8.193723620755845
# Reader: 2843
#     Chapter: 152918
#         Avg percent diff  : -0.1524428153390972
#         Avg SNR pre clean : 15.53406966209166
#         Avg SNR post clean: 13.178963134775215
# Reader: 2893
#     Chapter: 139310
#         Avg percent diff  : -0.24580442331923916
#         Avg SNR pre clean : 15.583477621650351
#         Avg SNR post clean: 11.774948081558167
#     Chapter: 139322
#         Avg percent diff  : -0.2649181563716368
#         Avg SNR pre clean : 15.67244297267142
#         Avg SNR post clean: 11.541347279350198
# Reader: 2910
#     Chapter: 131096
#         Avg percent diff  : -0.23728637913691344
#         Avg SNR pre clean : 14.006269651470246
#         Avg SNR post clean: 10.739126562477729
# Reader: 2911
#     Chapter: 12359
#         Avg percent diff  : -0.17673618180329836
#         Avg SNR pre clean : 19.51416287958669
#         Avg SNR post clean: 16.07158810535757
#     Chapter: 15045
#         Avg percent diff  : -0.171175744619145
#         Avg SNR pre clean : 19.995235828541563
#         Avg SNR post clean: 16.583328482257645
#     Chapter: 15084
#         Avg percent diff  : -0.17833394335555988
#         Avg SNR pre clean : 20.768987783125088
#         Avg SNR post clean: 17.068747643332053
#     Chapter: 7601
#         Avg percent diff  : -0.20064810260848703
#         Avg SNR pre clean : 20.755435796528104
#         Avg SNR post clean: 16.60489241819212
# Reader: 2952
#     Chapter: 407
#         Avg percent diff  : -0.1519093565358131
#         Avg SNR pre clean : 11.761495316190253
#         Avg SNR post clean: 9.981744001978921
#     Chapter: 408
#         Avg percent diff  : -0.13760198201462742
#         Avg SNR pre clean : 9.944759186646134
#         Avg SNR post clean: 8.584550063073527
#     Chapter: 410
#         Avg percent diff  : -0.15011702746179142
#         Avg SNR pre clean : 11.507283143259192
#         Avg SNR post clean: 9.818488957501026
# Reader: 2989
#     Chapter: 138028
#         Avg percent diff  : -0.12150299393605868
#         Avg SNR pre clean : 16.803031661797238
#         Avg SNR post clean: 14.764709439724365
#     Chapter: 138035
#         Avg percent diff  : -0.1298287829221852
#         Avg SNR pre clean : 15.947648409786892
#         Avg SNR post clean: 13.882347967215598
# Reader: 3112
#     Chapter: 9554
#         Avg percent diff  : -0.313171306985273
#         Avg SNR pre clean : 14.75269121499457
#         Avg SNR post clean: 10.176876583372499
#     Chapter: 9555
#         Avg percent diff  : -0.36023792299176155
#         Avg SNR pre clean : 13.948447291824792
#         Avg SNR post clean: 8.990670155425299
# Reader: 3168
#     Chapter: 173564
#         Avg percent diff  : -0.18477054969361706
#         Avg SNR pre clean : 7.858250823868844
#         Avg SNR post clean: 6.422541805340968
#     Chapter: 173565
#         Avg percent diff  : -0.15990542499514188
#         Avg SNR pre clean : 7.577698814002217
#         Avg SNR post clean: 6.388564151803934
# Reader: 3214
#     Chapter: 167602
#         Avg percent diff  : -0.1277595903658532
#         Avg SNR pre clean : 13.91458900225802
#         Avg SNR post clean: 12.122181029015605
#     Chapter: 167606
#         Avg percent diff  : -0.18332898269696696
#         Avg SNR pre clean : 7.588142625456555
#         Avg SNR post clean: 6.198519095952402
#     Chapter: 167607
#         Avg percent diff  : -0.20233469646394384
#         Avg SNR pre clean : 7.841686991068338
#         Avg SNR post clean: 6.263847161916458
# Reader: 3235
#     Chapter: 11599
#         Avg percent diff  : -0.2568358127682688
#         Avg SNR pre clean : 18.563660755651018
#         Avg SNR post clean: 13.796203035179746
#     Chapter: 28433
#         Avg percent diff  : -0.19673682372528908
#         Avg SNR pre clean : 20.120599532794145
#         Avg SNR post clean: 16.164726404357577
#     Chapter: 28452
#         Avg percent diff  : -0.19308149556019677
#         Avg SNR pre clean : 20.763046346496786
#         Avg SNR post clean: 16.755728925107977
# Reader: 3240
#     Chapter: 131231
#         Avg percent diff  : -0.22684274429940052
#         Avg SNR pre clean : 19.06591889754407
#         Avg SNR post clean: 14.791695954254033
#     Chapter: 131232
#         Avg percent diff  : -0.2266706213939136
#         Avg SNR pre clean : 18.98626490321058
#         Avg SNR post clean: 14.718263325547074
# Reader: 3242
#     Chapter: 67153
#         Avg percent diff  : -0.14290508536390667
#         Avg SNR pre clean : 17.709842251928652
#         Avg SNR post clean: 15.183500412105197
#     Chapter: 67168
#         Avg percent diff  : -0.16166635476195185
#         Avg SNR pre clean : 20.802586762190725
#         Avg SNR post clean: 17.44279631856694
#     Chapter: 8112
#         Avg percent diff  : -0.15855935191836232
#         Avg SNR pre clean : 19.966362243668502
#         Avg SNR post clean: 16.81353091993037
# Reader: 3259
#     Chapter: 158083
#         Avg percent diff  : -0.20426011763677715
#         Avg SNR pre clean : 16.52199728398916
#         Avg SNR post clean: 13.106662096466913
# Reader: 3374
#     Chapter: 298025
#         Avg percent diff  : -0.24411548053931775
#         Avg SNR pre clean : 7.03683928542724
#         Avg SNR post clean: 5.345090159652656
#     Chapter: 298026
#         Avg percent diff  : -0.2289668272582405
#         Avg SNR pre clean : 7.945245368015514
#         Avg SNR post clean: 6.174551003335171
#     Chapter: 298032
#         Avg percent diff  : -0.2874674713518941
#         Avg SNR pre clean : 10.048434702813292
#         Avg SNR post clean: 7.177340551464759
# Reader: 3436
#     Chapter: 172162
#         Avg percent diff  : -0.24724818939973747
#         Avg SNR pre clean : 16.77472515369838
#         Avg SNR post clean: 12.65414991022465
#     Chapter: 172171
#         Avg percent diff  : -0.31979577205634785
#         Avg SNR pre clean : 18.207269684551388
#         Avg SNR post clean: 12.501099158346959
# Reader: 3440
#     Chapter: 171006
#         Avg percent diff  : -0.23968851825537646
#         Avg SNR pre clean : 13.070724514590712
#         Avg SNR post clean: 10.015702904583334
#     Chapter: 171009
#         Avg percent diff  : -0.16710298419480366
#         Avg SNR pre clean : 14.08653279086037
#         Avg SNR post clean: 11.74542318328727
# Reader: 3486
#     Chapter: 166424
#         Avg percent diff  : -0.17528308757684208
#         Avg SNR pre clean : 12.318954894721093
#         Avg SNR post clean: 10.169374503428259
#     Chapter: 166446
#         Avg percent diff  : -0.2134540892987255
#         Avg SNR pre clean : 12.782862922591397
#         Avg SNR post clean: 10.071661725673797
# Reader: 3526
#     Chapter: 175658
#         Avg percent diff  : -0.27093767705585986
#         Avg SNR pre clean : 6.842583448147391
#         Avg SNR post clean: 5.012957451551583
#     Chapter: 176651
#         Avg percent diff  : -0.40838906929869856
#         Avg SNR pre clean : 3.730919760825933
#         Avg SNR post clean: 2.2181775138637048
#     Chapter: 176653
#         Avg percent diff  : -0.2599036594433551
#         Avg SNR pre clean : 8.891940421002085
#         Avg SNR post clean: 6.607779097520145
# Reader: 3607
#     Chapter: 135982
#         Avg percent diff  : -0.14264985880146222
#         Avg SNR pre clean : 17.000749111995052
#         Avg SNR post clean: 14.588827780008545
#     Chapter: 29116
#         Avg percent diff  : -0.11187825163812894
#         Avg SNR pre clean : 10.506878998415182
#         Avg SNR post clean: 9.33122515144137
# Reader: 3664
#     Chapter: 11714
#         Avg percent diff  : -0.1820230844407288
#         Avg SNR pre clean : 16.908289494659
#         Avg SNR post clean: 13.845603293806628
#     Chapter: 178355
#         Avg percent diff  : -0.14308120436901955
#         Avg SNR pre clean : 16.976285889703874
#         Avg SNR post clean: 14.555662471205284
#     Chapter: 178366
# ...
#         Avg percent diff  : -0.18914488399678075
#         Avg SNR pre clean : 17.44950530023553
#         Avg SNR post clean: 14.155530330875703
#     Chapter: 92316
#         Avg percent diff  : -0.2037252102216839
#         Avg SNR pre clean : 18.314283507022306
#         Avg SNR post clean: 14.588559625692646
# Reader: 7278
#     Chapter: 104730
#         Avg percent diff  : -0.2457175702382951
#         Avg SNR pre clean : 15.737798360475695
#         Avg SNR post clean: 11.912537888619058
#     Chapter: 246956
#         Avg percent diff  : -0.3285121041815411
#         Avg SNR pre clean : 12.494685072678674
#         Avg SNR post clean: 8.450230755289418
#     Chapter: 91083
#         Avg percent diff  : -0.147005743011901
#         Avg SNR pre clean : 23.48947574383938
#         Avg SNR post clean: 20.054293907793433
# Reader: 7302
#     Chapter: 86814
#         Avg percent diff  : -0.31331533729584327
#         Avg SNR pre clean : 16.0383982475552
#         Avg SNR post clean: 11.095469479471532
#     Chapter: 86815
#         Avg percent diff  : -0.33632910793096693
#         Avg SNR pre clean : 14.929380500417317
#         Avg SNR post clean: 9.986532152127225
# Reader: 7312
#     Chapter: 92432
#         Avg percent diff  : -0.2636974583063817
#         Avg SNR pre clean : 14.832534349339822
#         Avg SNR post clean: 10.96651597488765
# Reader: 7367
#     Chapter: 86737
#         Avg percent diff  : -0.2591600055074891
#         Avg SNR pre clean : 6.789067996835037
#         Avg SNR post clean: 5.08196816089696
# Reader: 7402
#     Chapter: 59171
#         Avg percent diff  : -0.15793636925610627
#         Avg SNR pre clean : 17.74235111834699
#         Avg SNR post clean: 14.962036684828268
#     Chapter: 90848
#         Avg percent diff  : -0.1747511732739608
#         Avg SNR pre clean : 16.86986324332065
#         Avg SNR post clean: 13.962616824784373
# Reader: 7447
#     Chapter: 91186
#         Avg percent diff  : -0.23348093900493838
#         Avg SNR pre clean : 21.15329518162572
#         Avg SNR post clean: 16.251081507962265
#     Chapter: 91187
#         Avg percent diff  : -0.2309871452675544
#         Avg SNR pre clean : 23.479169639045846
#         Avg SNR post clean: 18.085924582560942
# Reader: 7505
#     Chapter: 258958
#         Avg percent diff  : -0.28505137302161887
#         Avg SNR pre clean : 15.566941610898583
#         Avg SNR post clean: 11.167235310813385
#     Chapter: 258964
#         Avg percent diff  : -0.2865182615278249
#         Avg SNR pre clean : 15.401752376613446
#         Avg SNR post clean: 11.053292616402764
#     Chapter: 83618
#         Avg percent diff  : -0.2665582580148418
#         Avg SNR pre clean : 15.773402340610422
#         Avg SNR post clean: 11.622470787284154
# Reader: 7511
#     Chapter: 102419
#         Avg percent diff  : -0.1845347632547791
#         Avg SNR pre clean : 19.465513436628964
#         Avg SNR post clean: 15.895655285892191
#     Chapter: 102420
#         Avg percent diff  : -0.1800979277045414
#         Avg SNR pre clean : 18.489119924558498
#         Avg SNR post clean: 15.168844402694672
# Reader: 7517
#     Chapter: 100429
#         Avg percent diff  : -0.3403973323902823
#         Avg SNR pre clean : 15.461470637833742
#         Avg SNR post clean: 10.252532757538015
#     Chapter: 100437
#         Avg percent diff  : -0.3383956247398473
#         Avg SNR pre clean : 15.900373940009535
#         Avg SNR post clean: 10.602861167978984
#     Chapter: 100442
#         Avg percent diff  : -0.34859274757759906
#         Avg SNR pre clean : 14.489069032403837
#         Avg SNR post clean: 9.466374050555387
# Reader: 7635
#     Chapter: 105409
#         Avg percent diff  : -0.2927041307300959
#         Avg SNR pre clean : 8.620416117397939
#         Avg SNR post clean: 6.115943481513654
#     Chapter: 105661
#         Avg percent diff  : -0.28406587379254644
#         Avg SNR pre clean : 9.835614852882093
#         Avg SNR post clean: 7.052569695852396
# Reader: 7780
#     Chapter: 274562
#         Avg percent diff  : -0.191773622347119
#         Avg SNR pre clean : 19.593702092472718
#         Avg SNR post clean: 15.856003411955005
# Reader: 7794
#     Chapter: 295947
#         Avg percent diff  : -0.39709870290654603
#         Avg SNR pre clean : 11.62229082130462
#         Avg SNR post clean: 7.025348882489986
#     Chapter: 295948
#         Avg percent diff  : -0.39987134284250864
#         Avg SNR pre clean : 12.178485649608877
#         Avg SNR post clean: 7.342076036997089
#     Chapter: 295955
#         Avg percent diff  : -0.4099420537424159
#         Avg SNR pre clean : 10.587052711997424
#         Avg SNR post clean: 6.270218649397767
# Reader: 7800
#     Chapter: 283478
#         Avg percent diff  : -0.201234774782885
#         Avg SNR pre clean : 19.30506878247195
#         Avg SNR post clean: 15.45144551798881
#     Chapter: 283492
#         Avg percent diff  : -0.17149817656397326
#         Avg SNR pre clean : 17.909844080800276
#         Avg SNR post clean: 14.840579922854435
#     Chapter: 283493
#         Avg percent diff  : -0.1777486039723193
#         Avg SNR pre clean : 18.864859712588494
#         Avg SNR post clean: 15.520536533442014
# Reader: 7859
#     Chapter: 102518
#         Avg percent diff  : -0.2640608041379473
#         Avg SNR pre clean : 17.408698943650265
#         Avg SNR post clean: 12.847739635137607
#     Chapter: 102519
#         Avg percent diff  : -0.28209190505565024
#         Avg SNR pre clean : 17.436052709725345
#         Avg SNR post clean: 12.56469139491976
#     Chapter: 102521
#         Avg percent diff  : -0.2267427161349385
#         Avg SNR pre clean : 20.26176118344312
#         Avg SNR post clean: 15.688939220438357
# Reader: 8014
#     Chapter: 112586
#         Avg percent diff  : -0.203892608430539
#         Avg SNR pre clean : 19.75222962238224
#         Avg SNR post clean: 15.75164044448599
#     Chapter: 112602
#         Avg percent diff  : -0.29140384331573577
#         Avg SNR pre clean : 16.788912622245352
#         Avg SNR post clean: 12.000597355367043
#     Chapter: 280382
#         Avg percent diff  : -0.2706040098337075
#         Avg SNR pre clean : 19.171663748980436
#         Avg SNR post clean: 14.134045323363804
# Reader: 8051
#     Chapter: 118101
#         Avg percent diff  : -0.11670493530111961
#         Avg SNR pre clean : 23.12873427280957
#         Avg SNR post clean: 20.440680097784508
#     Chapter: 119902
#         Avg percent diff  : -0.15006790858788474
#         Avg SNR pre clean : 22.713881119471182
#         Avg SNR post clean: 19.307602616895785
#     Chapter: 295385
#         Avg percent diff  : -0.1746223584012145
#         Avg SNR pre clean : 16.994121254137642
#         Avg SNR post clean: 14.022309169989267
# Reader: 8063
#     Chapter: 274112
#         Avg percent diff  : -0.2773883324047577
#         Avg SNR pre clean : 19.453380154340394
#         Avg SNR post clean: 14.076364434888076
#     Chapter: 274115
#         Avg percent diff  : -0.24903593791053083
#         Avg SNR pre clean : 17.277387025314184
#         Avg SNR post clean: 13.017917539823525
#     Chapter: 274116
#         Avg percent diff  : -0.2388214560203792
#         Avg SNR pre clean : 18.615966999193944
#         Avg SNR post clean: 14.200047630749816
#     Chapter: 274117
#         Avg percent diff  : -0.2500531824546271
#         Avg SNR pre clean : 17.647052308534267
#         Avg SNR post clean: 13.263501757530086
# Reader: 8088
#     Chapter: 284756
#         Avg percent diff  : -0.25700373087357237
#         Avg SNR pre clean : 6.260938110225578
#         Avg SNR post clean: 4.649383161052358
# Reader: 8095
#     Chapter: 274345
#         Avg percent diff  : -0.36251918836391916
#         Avg SNR pre clean : 11.295759198118903
#         Avg SNR post clean: 7.2454154972145695
#     Chapter: 274346
#         Avg percent diff  : -0.3458840782058885
#         Avg SNR pre clean : 12.371994820627068
#         Avg SNR post clean: 8.111167364130397
#     Chapter: 274348
#         Avg percent diff  : -0.3348772227068607
#         Avg SNR pre clean : 13.634480715302045
#         Avg SNR post clean: 9.086876384660961
# Reader: 8098
#     Chapter: 275181
#         Avg percent diff  : -0.19685423233922733
#         Avg SNR pre clean : 22.70150883080308
#         Avg SNR post clean: 18.243048225324593
#     Chapter: 278252
#         Avg percent diff  : -0.1822581646435437
#         Avg SNR pre clean : 23.436064570150076
#         Avg SNR post clean: 19.18109999158163
#     Chapter: 278278
#         Avg percent diff  : -0.21999428029291523
#         Avg SNR pre clean : 21.437273696239338
#         Avg SNR post clean: 16.749448447204998
# Reader: 8108
#     Chapter: 274318
#         Avg percent diff  : -0.23024593253245462
#         Avg SNR pre clean : 15.568679518502941
#         Avg SNR post clean: 11.990428033921294
#     Chapter: 280354
#         Avg percent diff  : -0.2081335502133989
#         Avg SNR pre clean : 16.32866446955175
#         Avg SNR post clean: 12.967763154526978
#     Chapter: 280359
#         Avg percent diff  : -0.19137636826294513
#         Avg SNR pre clean : 15.999361582818052
#         Avg SNR post clean: 12.940509587908835
# Reader: 8123
#     Chapter: 275193
#         Avg percent diff  : -0.22658378896242656
#         Avg SNR pre clean : 18.543980962071355
#         Avg SNR post clean: 14.371259271256957
#     Chapter: 275209
#         Avg percent diff  : -0.22990034298835482
#         Avg SNR pre clean : 19.881694401470245
#         Avg SNR post clean: 15.335567408780317
#     Chapter: 275216
#         Avg percent diff  : -0.22370600420882605
#         Avg SNR pre clean : 19.54691242533874
#         Avg SNR post clean: 15.201723382366442
# Reader: 8226
#     Chapter: 274369
#         Avg percent diff  : -0.2517096329929755
#         Avg SNR pre clean : 16.013744870878952
#         Avg SNR post clean: 12.01023269938793
#     Chapter: 274371
#         Avg percent diff  : -0.23457297730242668
#         Avg SNR pre clean : 15.782754557208492
#         Avg SNR post clean: 12.101994168429826
# Reader: 8238
#     Chapter: 274553
#         Avg percent diff  : -0.19005825304487584
#         Avg SNR pre clean : 10.356026748196872
#         Avg SNR post clean: 8.383944349575492
#     Chapter: 283452
#         Avg percent diff  : -0.1732591646874518
#         Avg SNR pre clean : 8.8570860845172
#         Avg SNR post clean: 7.321203510320228
# Reader: 8312
#     Chapter: 279790
#         Avg percent diff  : -0.1340489359641014
#         Avg SNR pre clean : 25.965126069058876
#         Avg SNR post clean: 22.49382591764691
#     Chapter: 279791
#         Avg percent diff  : -0.10506990038887114
#         Avg SNR pre clean : 26.31933334301489
#         Avg SNR post clean: 23.557923801043668
# Reader: 8324
#     Chapter: 286681
#         Avg percent diff  : -0.23430226569906576
#         Avg SNR pre clean : 13.608861890252674
#         Avg SNR post clean: 10.437560316839095
#     Chapter: 286682
#         Avg percent diff  : -0.3020458924323309
#         Avg SNR pre clean : 13.458356064476735
#         Avg SNR post clean: 9.459216429088773
#     Chapter: 286683
#         Avg percent diff  : -0.2590505100489963
#         Avg SNR pre clean : 13.364471443948936
#         Avg SNR post clean: 9.918651714488712
# Reader: 8419
#     Chapter: 286667
#         Avg percent diff  : -0.28234890584874917
#         Avg SNR pre clean : 6.799343168681985
#         Avg SNR post clean: 4.888808195120284
#     Chapter: 286676
#         Avg percent diff  : -0.27120084304553993
#         Avg SNR pre clean : 7.114087084234911
#         Avg SNR post clean: 5.21459191252775
#     Chapter: 293469
#         Avg percent diff  : -0.284341172874458
#         Avg SNR pre clean : 7.228773165186079
#         Avg SNR post clean: 5.227091794409876
#     Chapter: 293473
#         Avg percent diff  : -0.3202461384769175
#         Avg SNR pre clean : 6.010976051207239
#         Avg SNR post clean: 4.113163066736515
# Reader: 8425
#     Chapter: 246962
#         Avg percent diff  : -0.28928161095064164
#         Avg SNR pre clean : 18.31669679388148
#         Avg SNR post clean: 13.03198507168727
#     Chapter: 287387
#         Avg percent diff  : -0.2698944592036385
#         Avg SNR pre clean : 20.19144101125885
#         Avg SNR post clean: 14.80497158436739
#     Chapter: 291444
#         Avg percent diff  : -0.2669185542241443
#         Avg SNR pre clean : 19.52070672527837
#         Avg SNR post clean: 14.328304340067287
#     Chapter: 292520
#         Avg percent diff  : -0.30893628539515594
#         Avg SNR pre clean : 17.550501556382173
#         Avg SNR post clean: 12.152603905827577
# Reader: 8465
#     Chapter: 246940
#         Avg percent diff  : -0.35932248910993414
#         Avg SNR pre clean : 15.606401248965435
#         Avg SNR post clean: 10.076457028754426
#     Chapter: 246942
#         Avg percent diff  : -0.29625886388602973
#         Avg SNR pre clean : 15.487996988351464
#         Avg SNR post clean: 10.917127945686868
#     Chapter: 246943
#         Avg percent diff  : -0.3187095885269027
#         Avg SNR pre clean : 15.267927624634526
#         Avg SNR post clean: 10.53304143833551
#     Chapter: 246947
#         Avg percent diff  : -0.3277176298987752
#         Avg SNR pre clean : 16.34173013565456
#         Avg SNR post clean: 11.048397107254809
# Reader: 8468
#     Chapter: 286673
#         Avg percent diff  : -0.2023471440387683
#         Avg SNR pre clean : 18.86119043755076
#         Avg SNR post clean: 15.057405291725658
#     Chapter: 294887
#         Avg percent diff  : -0.22698271330461672
#         Avg SNR pre clean : 19.587161845768744
#         Avg SNR post clean: 15.144143730227807
#     Chapter: 295198
#         Avg percent diff  : -0.18855699652837
#         Avg SNR pre clean : 17.639004860350955
#         Avg SNR post clean: 14.315125661051486
# Reader: 8580
#     Chapter: 287363
#         Avg percent diff  : -0.19675539061066616
#         Avg SNR pre clean : 13.424310789154339
#         Avg SNR post clean: 10.800561059719426
#     Chapter: 287364
#         Avg percent diff  : -0.2302090335294271
#         Avg SNR pre clean : 13.45077799275782
#         Avg SNR post clean: 10.374107347262132
# Reader: 8609
#     Chapter: 262281
#         Avg percent diff  : -0.08841758878449547
#         Avg SNR pre clean : 5.946826287296907
#         Avg SNR post clean: 5.432789404146063
#     Chapter: 283227
#         Avg percent diff  : -0.09418833312244601
#         Avg SNR pre clean : 6.8231564666365365
#         Avg SNR post clean: 6.19316479667353
# Reader: 8629
#     Chapter: 261139
#         Avg percent diff  : -0.2775888591899757
#         Avg SNR pre clean : 13.970095157156582
#         Avg SNR post clean: 10.172780371233749
#     Chapter: 261140
#         Avg percent diff  : -0.2757110374954144
#         Avg SNR pre clean : 14.062041810154735
#         Avg SNR post clean: 10.210445376470146
# Reader: 8630
#     Chapter: 305212
#         Avg percent diff  : -0.204894006154246
#         Avg SNR pre clean : 18.004613122197416
#         Avg SNR post clean: 14.334955275161407
#     Chapter: 305213
#         Avg percent diff  : -0.2257469933757323
#         Avg SNR pre clean : 18.07941838828088
#         Avg SNR post clean: 14.019022829356548
# Reader: 8747
#     Chapter: 293952
#         Avg percent diff  : -0.36562439084321596
#         Avg SNR pre clean : 9.853884558304276
#         Avg SNR post clean: 6.297871201299054
# Reader: 8770
#     Chapter: 295462
#         Avg percent diff  : -0.2019607319737479
#         Avg SNR pre clean : 17.405038536894875
#         Avg SNR post clean: 13.909062489394396
#     Chapter: 295463
#         Avg percent diff  : -0.18624383708943285
#         Avg SNR pre clean : 17.729844884408294
#         Avg SNR post clean: 14.436838306447104
#     Chapter: 295465
#         Avg percent diff  : -0.21211645399223916
#         Avg SNR pre clean : 17.658648733417312
#         Avg SNR post clean: 13.939146748409987
# Reader: 8797
#     Chapter: 294123
#         Avg percent diff  : -0.19252916715498045
#         Avg SNR pre clean : 15.800842542295225
#         Avg SNR post clean: 12.773382428276587
# Reader: 8838
#     Chapter: 298545
#         Avg percent diff  : -0.14363793182476642
#         Avg SNR pre clean : 22.220992472801864
#         Avg SNR post clean: 19.05016453824591
#     Chapter: 298546
#         Avg percent diff  : -0.1425340820421308
#         Avg SNR pre clean : 22.009446152862584
#         Avg SNR post clean: 18.896863496353436
# Reader: 8975
#     Chapter: 270782
#         Avg percent diff  : -0.2987735662472631
#         Avg SNR pre clean : 6.794733383441075
#         Avg SNR post clean: 4.775076905735341

# %%
all_values = []
uncleaned_all = []
cleaned_all = []
for reader in data:
    for chapter in data[reader].keys():
        all_values.extend(data[reader][chapter])
        uncleaned_all.extend([initial for initial, _ in data[reader][chapter]])
        cleaned_all.extend([cleaned for _, cleaned in data[reader][chapter]])

percent_diff_all = np.array([percent_difference(initial,final) for initial, final in all_values])
print(np.mean(percent_diff_all))
print(np.mean(np.array(uncleaned_all)))
print(np.mean(np.array(cleaned_all)))
# Out:
# -0.22893026591735602
# 15.121404755474519
# 11.828909489423223

# %%
all_values = []
uncleaned_all = []
cleaned_all = []
for reader in data:
    for chapter in data[reader].keys():
        all_values.extend(data[reader][chapter])
        uncleaned_all.extend([initial for initial, _ in data[reader][chapter]])
        cleaned_all.extend([cleaned for _, cleaned in data[reader][chapter]])


difference_list = np.array([unclean - clean for unclean, clean in all_values])
percent_diff_all = np.array([percent_difference(initial,final) for initial, final in all_values])

# print(np.mean(difference_list))

# print(np.std(difference_list))
print(np.std(percent_diff_all))
# Out:
# 0.08277431654896233
