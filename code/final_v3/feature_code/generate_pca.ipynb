# %%
import pickle
import numpy as np

from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
features = "mfcc_13_no_pitch_1000_rand_all_speakers"

with open(f"../../../data/extracted_features_v2/{features}.pickle", "rb") as file:
   mfcc_stats_dict = pickle.load(file)

print(len(mfcc_stats_dict.keys()))

for reader in mfcc_stats_dict.keys():
    print(f"reader: {reader} | # samples {len(mfcc_stats_dict[reader])}")
# Out:
# 245
# reader: 103 | # samples 1000
# reader: 1034 | # samples 1000
# reader: 1069 | # samples 1000
# reader: 1081 | # samples 1000
# reader: 1088 | # samples 1000
# reader: 1098 | # samples 1000
# reader: 1116 | # samples 1000
# reader: 118 | # samples 1000
# reader: 1235 | # samples 1000
# reader: 1246 | # samples 1000
# reader: 125 | # samples 1000
# reader: 1263 | # samples 1000
# reader: 1334 | # samples 1000
# reader: 1355 | # samples 1000
# reader: 1363 | # samples 1000
# reader: 1447 | # samples 1000
# reader: 1455 | # samples 1000
# reader: 150 | # samples 1000
# reader: 1502 | # samples 1000
# reader: 1553 | # samples 1000
# reader: 1578 | # samples 1000
# reader: 1594 | # samples 1000
# reader: 1624 | # samples 1000
# reader: 163 | # samples 1000
# reader: 1723 | # samples 1000
# reader: 1737 | # samples 1000
# reader: 1743 | # samples 1000
# reader: 1841 | # samples 1000
# reader: 1867 | # samples 1000
# reader: 1898 | # samples 1000
# reader: 19 | # samples 1000
# reader: 1926 | # samples 1000
# reader: 196 | # samples 1000
# reader: 1963 | # samples 1000
# reader: 1970 | # samples 1000
# reader: 198 | # samples 1000
# reader: 200 | # samples 1000
# reader: 2002 | # samples 1000
# reader: 2007 | # samples 1000
# reader: 201 | # samples 1000
# reader: 2092 | # samples 1000
# reader: 211 | # samples 1000
# reader: 2136 | # samples 1000
# reader: 2159 | # samples 1000
# reader: 2182 | # samples 1000
# reader: 2196 | # samples 1000
# reader: 226 | # samples 1000
# reader: 2289 | # samples 1000
# reader: 229 | # samples 1000
# reader: 233 | # samples 1000
# reader: 2384 | # samples 1000
# reader: 2391 | # samples 1000
# reader: 2416 | # samples 998
# reader: 2436 | # samples 1000
# reader: 248 | # samples 1000
# reader: 250 | # samples 1000
# reader: 2514 | # samples 1000
# reader: 2518 | # samples 1000
# reader: 254 | # samples 999
# reader: 26 | # samples 1000
# reader: 2691 | # samples 1000
# reader: 27 | # samples 1000
# reader: 2764 | # samples 1000
# reader: 2817 | # samples 1000
# reader: 2836 | # samples 1000
# reader: 2843 | # samples 1000
# reader: 289 | # samples 1000
# reader: 2893 | # samples 1000
# reader: 2910 | # samples 1000
# reader: 2911 | # samples 1000
# reader: 2952 | # samples 1000
# reader: 298 | # samples 1000
# reader: 2989 | # samples 1000
# reader: 302 | # samples 1000
# reader: 307 | # samples 1000
# reader: 311 | # samples 1000
# reader: 3112 | # samples 1000
# reader: 3168 | # samples 1000
# reader: 32 | # samples 1000
# reader: 3214 | # samples 1000
# reader: 322 | # samples 1000
# reader: 3235 | # samples 996
# reader: 3240 | # samples 1000
# reader: 3242 | # samples 1000
# reader: 3259 | # samples 1000
# reader: 328 | # samples 1000
# reader: 332 | # samples 1000
# reader: 3374 | # samples 1000
# reader: 3436 | # samples 1000
# reader: 3440 | # samples 1000
# reader: 3486 | # samples 1000
# reader: 3526 | # samples 1000
# reader: 3607 | # samples 1000
# reader: 3664 | # samples 1000
# reader: 3699 | # samples 1000
# reader: 3723 | # samples 1000
# reader: 374 | # samples 1000
# reader: 3807 | # samples 1000
# reader: 3830 | # samples 1000
# reader: 3857 | # samples 1000
# reader: 3879 | # samples 1000
# reader: 39 | # samples 1000
# reader: 3947 | # samples 1000
# reader: 3982 | # samples 1000
# reader: 3983 | # samples 1000
# reader: 40 | # samples 1000
# reader: 4014 | # samples 1000
# reader: 4018 | # samples 1000
# reader: 403 | # samples 1000
# reader: 405 | # samples 1000
# reader: 4051 | # samples 1000
# reader: 4088 | # samples 1000
# reader: 412 | # samples 1000
# reader: 4137 | # samples 1000
# reader: 4160 | # samples 1000
# reader: 4195 | # samples 1000
# reader: 4214 | # samples 1000
# reader: 426 | # samples 1000
# reader: 4267 | # samples 1000
# reader: 4297 | # samples 1000
# reader: 4340 | # samples 1000
# reader: 4362 | # samples 1000
# reader: 4397 | # samples 1000
# reader: 4406 | # samples 1000
# reader: 441 | # samples 1000
# reader: 4441 | # samples 1000
# reader: 446 | # samples 1000
# reader: 4481 | # samples 1000
# reader: 458 | # samples 1000
# reader: 460 | # samples 1000
# reader: 4640 | # samples 1000
# reader: 4680 | # samples 1000
# reader: 4788 | # samples 1000
# reader: 481 | # samples 1000
# reader: 4813 | # samples 1000
# reader: 4830 | # samples 1000
# reader: 4853 | # samples 1000
# reader: 4859 | # samples 1000
# reader: 4898 | # samples 1000
# reader: 5022 | # samples 1000
# reader: 5049 | # samples 1000
# reader: 5104 | # samples 1000
# reader: 5163 | # samples 1000
# reader: 5192 | # samples 1000
# reader: 5322 | # samples 1000
# reader: 5339 | # samples 1000
# reader: 5390 | # samples 1000
# reader: 5393 | # samples 1000
# reader: 5456 | # samples 1000
# reader: 5463 | # samples 1000
# reader: 5514 | # samples 1000
# reader: 5561 | # samples 1000
# reader: 5652 | # samples 1000
# reader: 5678 | # samples 1000
# reader: 5688 | # samples 1000
# reader: 5703 | # samples 1000
# reader: 5750 | # samples 1000
# reader: 5778 | # samples 1000
# reader: 5789 | # samples 1000
# reader: 5808 | # samples 1000
# reader: 5867 | # samples 1000
# reader: 587 | # samples 1000
# reader: 60 | # samples 1000
# reader: 6000 | # samples 1000
# reader: 6019 | # samples 1000
# reader: 6064 | # samples 1000
# reader: 6078 | # samples 1000
# reader: 6081 | # samples 1000
# reader: 6147 | # samples 1000
# reader: 6181 | # samples 1000
# reader: 6209 | # samples 1000
# reader: 625 | # samples 1000
# reader: 6272 | # samples 1000
# reader: 6367 | # samples 1000
# reader: 6385 | # samples 1000
# reader: 6415 | # samples 1000
# reader: 6437 | # samples 1000
# reader: 6454 | # samples 1000
# reader: 6476 | # samples 1000
# reader: 6529 | # samples 1000
# reader: 6531 | # samples 1000
# reader: 6563 | # samples 1000
# reader: 669 | # samples 1000
# reader: 6818 | # samples 1000
# reader: 6836 | # samples 1000
# reader: 6848 | # samples 1000
# reader: 6880 | # samples 1000
# reader: 6925 | # samples 1000
# reader: 696 | # samples 1000
# reader: 7059 | # samples 1000
# reader: 7067 | # samples 1000
# reader: 7078 | # samples 1000
# reader: 7113 | # samples 1000
# reader: 7148 | # samples 1000
# reader: 7178 | # samples 1000
# reader: 7190 | # samples 1000
# reader: 7226 | # samples 1000
# reader: 7264 | # samples 1000
# reader: 7278 | # samples 1000
# reader: 730 | # samples 1000
# reader: 7302 | # samples 1000
# reader: 7367 | # samples 1000
# reader: 7402 | # samples 1000
# reader: 7447 | # samples 1000
# reader: 7505 | # samples 1000
# reader: 7511 | # samples 1000
# reader: 7517 | # samples 1000
# reader: 7635 | # samples 1000
# reader: 7780 | # samples 1000
# reader: 7794 | # samples 1000
# reader: 78 | # samples 1000
# reader: 7800 | # samples 1000
# reader: 7859 | # samples 1000
# reader: 8051 | # samples 1000
# reader: 8063 | # samples 1000
# reader: 8088 | # samples 1000
# reader: 8095 | # samples 1000
# reader: 8098 | # samples 1000
# reader: 8108 | # samples 1000
# reader: 8123 | # samples 1000
# reader: 8226 | # samples 1000
# reader: 8238 | # samples 1000
# reader: 83 | # samples 1000
# reader: 831 | # samples 1000
# reader: 8312 | # samples 1000
# reader: 8324 | # samples 1000
# reader: 839 | # samples 1000
# reader: 8419 | # samples 1000
# reader: 8425 | # samples 1000
# reader: 8465 | # samples 1000
# reader: 8468 | # samples 1000
# reader: 8580 | # samples 1000
# reader: 8609 | # samples 1000
# reader: 8629 | # samples 1000
# reader: 8630 | # samples 1000
# reader: 87 | # samples 1000
# reader: 8747 | # samples 1000
# reader: 8770 | # samples 1000
# reader: 8797 | # samples 1000
# reader: 8838 | # samples 1000
# reader: 887 | # samples 1000
# reader: 89 | # samples 1000
# reader: 8975 | # samples 1000
# reader: 909 | # samples 1000
# reader: 911 | # samples 1000

# %%
def scale_features(data_dict):
    """
    Scales the data in a dictionary using StandardScaler.
    
    Parameters:
        data_dict (dict): Dictionary where each key is a subject, and the value is a 2D array 
                          (samples x features).
                          
    Returns:
        dict: A new dictionary with scaled data, maintaining the same structure as the input.
    """
    # Combine all data into a single array
    all_samples = np.vstack(list(data_dict.values()))  # Shape: (total_samples, num_features)

    # Scale the data
    scaler = StandardScaler()
    scaled_data = scaler.fit_transform(all_samples)  # Shape: (total_samples, num_features)

    # Split scaled data back into original structure
    split_indices = np.cumsum([len(samples) for samples in data_dict.values()])[:-1]
    scaled_subjects = np.split(scaled_data, split_indices)

    # Reconstruct the dictionary with scaled data
    scaled_data_dict = {key: scaled_subjects[i] for i, key in enumerate(data_dict.keys())}

    return scaled_data_dict

def scale_and_optimize_pca(data_dict, variance_threshold=0.95):
    """
    Scales the data in a dictionary using StandardScaler, determines the optimal 
    number of PCA components based on the explained variance threshold, 
    applies PCA, and returns the transformed data in the same dictionary structure.

    Parameters:
        data_dict (dict): Dictionary where each key is a subject, and the value is a 2D array 
                          (samples x features).
        variance_threshold (float): The minimum cumulative explained variance (0 to 1) 
                                    to determine the number of PCA components.
                          
    Returns:
        tuple:
            dict: A new dictionary with PCA-transformed data, maintaining the same structure as the input.
            int: The number of PCA components selected.
    """
    # Combine all data into a single array
    all_samples = np.vstack(list(data_dict.values()))  # Shape: (total_samples, num_features)

    # Scale the data
    scaler = StandardScaler()
    standardized_data = scaler.fit_transform(all_samples)  # Shape: (total_samples, num_features)

    # Fit PCA on standardized data to find optimal number of components
    pca = PCA()
    pca.fit(standardized_data)
    cumsum = np.cumsum(pca.explained_variance_ratio_)
    n_components = np.argmax(cumsum >= variance_threshold) + 1

    # Apply PCA with the optimal number of components
    pca = PCA(n_components=n_components)
    pca_data = pca.fit_transform(standardized_data)  # Shape: (total_samples, n_components)

    # Split PCA-transformed data back into original structure
    split_indices = np.cumsum([len(samples) for samples in data_dict.values()])[:-1]
    pca_subjects = np.split(pca_data, split_indices)

    # Reconstruct the dictionary with PCA-transformed data
    pca_data_dict = {key: pca_subjects[i] for i, key in enumerate(data_dict.keys())}

    return pca_data_dict, n_components

# %%
pca_transformed_data, optimal_components = scale_and_optimize_pca(mfcc_stats_dict)

for key in pca_transformed_data.keys():
    print(f"key: {key} shape: {pca_transformed_data[key].shape}")
# Out:
# key: 103 shape: (1000, 46)
# key: 1034 shape: (1000, 46)
# key: 1069 shape: (1000, 46)
# key: 1081 shape: (1000, 46)
# key: 1088 shape: (1000, 46)
# key: 1098 shape: (1000, 46)
# key: 1116 shape: (1000, 46)
# key: 118 shape: (1000, 46)
# key: 1235 shape: (1000, 46)
# key: 1246 shape: (1000, 46)
# key: 125 shape: (1000, 46)
# key: 1263 shape: (1000, 46)
# key: 1334 shape: (1000, 46)
# key: 1355 shape: (1000, 46)
# key: 1363 shape: (1000, 46)
# key: 1447 shape: (1000, 46)
# key: 1455 shape: (1000, 46)
# key: 150 shape: (1000, 46)
# key: 1502 shape: (1000, 46)
# key: 1553 shape: (1000, 46)
# key: 1578 shape: (1000, 46)
# key: 1594 shape: (1000, 46)
# key: 1624 shape: (1000, 46)
# key: 163 shape: (1000, 46)
# key: 1723 shape: (1000, 46)
# key: 1737 shape: (1000, 46)
# key: 1743 shape: (1000, 46)
# key: 1841 shape: (1000, 46)
# key: 1867 shape: (1000, 46)
# key: 1898 shape: (1000, 46)
# key: 19 shape: (1000, 46)
# key: 1926 shape: (1000, 46)
# key: 196 shape: (1000, 46)
# key: 1963 shape: (1000, 46)
# key: 1970 shape: (1000, 46)
# key: 198 shape: (1000, 46)
# key: 200 shape: (1000, 46)
# key: 2002 shape: (1000, 46)
# key: 2007 shape: (1000, 46)
# key: 201 shape: (1000, 46)
# key: 2092 shape: (1000, 46)
# key: 211 shape: (1000, 46)
# key: 2136 shape: (1000, 46)
# key: 2159 shape: (1000, 46)
# key: 2182 shape: (1000, 46)
# key: 2196 shape: (1000, 46)
# key: 226 shape: (1000, 46)
# key: 2289 shape: (1000, 46)
# key: 229 shape: (1000, 46)
# key: 233 shape: (1000, 46)
# key: 2384 shape: (1000, 46)
# key: 2391 shape: (1000, 46)
# key: 2416 shape: (998, 46)
# key: 2436 shape: (1000, 46)
# key: 248 shape: (1000, 46)
# key: 250 shape: (1000, 46)
# key: 2514 shape: (1000, 46)
# key: 2518 shape: (1000, 46)
# key: 254 shape: (999, 46)
# key: 26 shape: (1000, 46)
# key: 2691 shape: (1000, 46)
# key: 27 shape: (1000, 46)
# key: 2764 shape: (1000, 46)
# key: 2817 shape: (1000, 46)
# key: 2836 shape: (1000, 46)
# key: 2843 shape: (1000, 46)
# key: 289 shape: (1000, 46)
# key: 2893 shape: (1000, 46)
# key: 2910 shape: (1000, 46)
# key: 2911 shape: (1000, 46)
# key: 2952 shape: (1000, 46)
# key: 298 shape: (1000, 46)
# key: 2989 shape: (1000, 46)
# key: 302 shape: (1000, 46)
# key: 307 shape: (1000, 46)
# key: 311 shape: (1000, 46)
# key: 3112 shape: (1000, 46)
# key: 3168 shape: (1000, 46)
# key: 32 shape: (1000, 46)
# key: 3214 shape: (1000, 46)
# key: 322 shape: (1000, 46)
# key: 3235 shape: (996, 46)
# key: 3240 shape: (1000, 46)
# key: 3242 shape: (1000, 46)
# key: 3259 shape: (1000, 46)
# key: 328 shape: (1000, 46)
# key: 332 shape: (1000, 46)
# key: 3374 shape: (1000, 46)
# key: 3436 shape: (1000, 46)
# key: 3440 shape: (1000, 46)
# key: 3486 shape: (1000, 46)
# key: 3526 shape: (1000, 46)
# key: 3607 shape: (1000, 46)
# key: 3664 shape: (1000, 46)
# key: 3699 shape: (1000, 46)
# key: 3723 shape: (1000, 46)
# key: 374 shape: (1000, 46)
# key: 3807 shape: (1000, 46)
# key: 3830 shape: (1000, 46)
# key: 3857 shape: (1000, 46)
# key: 3879 shape: (1000, 46)
# key: 39 shape: (1000, 46)
# key: 3947 shape: (1000, 46)
# key: 3982 shape: (1000, 46)
# key: 3983 shape: (1000, 46)
# key: 40 shape: (1000, 46)
# key: 4014 shape: (1000, 46)
# key: 4018 shape: (1000, 46)
# key: 403 shape: (1000, 46)
# key: 405 shape: (1000, 46)
# key: 4051 shape: (1000, 46)
# key: 4088 shape: (1000, 46)
# key: 412 shape: (1000, 46)
# key: 4137 shape: (1000, 46)
# key: 4160 shape: (1000, 46)
# key: 4195 shape: (1000, 46)
# key: 4214 shape: (1000, 46)
# key: 426 shape: (1000, 46)
# key: 4267 shape: (1000, 46)
# key: 4297 shape: (1000, 46)
# key: 4340 shape: (1000, 46)
# key: 4362 shape: (1000, 46)
# key: 4397 shape: (1000, 46)
# key: 4406 shape: (1000, 46)
# key: 441 shape: (1000, 46)
# key: 4441 shape: (1000, 46)
# key: 446 shape: (1000, 46)
# key: 4481 shape: (1000, 46)
# key: 458 shape: (1000, 46)
# key: 460 shape: (1000, 46)
# key: 4640 shape: (1000, 46)
# key: 4680 shape: (1000, 46)
# key: 4788 shape: (1000, 46)
# key: 481 shape: (1000, 46)
# key: 4813 shape: (1000, 46)
# key: 4830 shape: (1000, 46)
# key: 4853 shape: (1000, 46)
# key: 4859 shape: (1000, 46)
# key: 4898 shape: (1000, 46)
# key: 5022 shape: (1000, 46)
# key: 5049 shape: (1000, 46)
# key: 5104 shape: (1000, 46)
# key: 5163 shape: (1000, 46)
# key: 5192 shape: (1000, 46)
# key: 5322 shape: (1000, 46)
# key: 5339 shape: (1000, 46)
# key: 5390 shape: (1000, 46)
# key: 5393 shape: (1000, 46)
# key: 5456 shape: (1000, 46)
# key: 5463 shape: (1000, 46)
# key: 5514 shape: (1000, 46)
# key: 5561 shape: (1000, 46)
# key: 5652 shape: (1000, 46)
# key: 5678 shape: (1000, 46)
# key: 5688 shape: (1000, 46)
# key: 5703 shape: (1000, 46)
# key: 5750 shape: (1000, 46)
# key: 5778 shape: (1000, 46)
# key: 5789 shape: (1000, 46)
# key: 5808 shape: (1000, 46)
# key: 5867 shape: (1000, 46)
# key: 587 shape: (1000, 46)
# key: 60 shape: (1000, 46)
# key: 6000 shape: (1000, 46)
# key: 6019 shape: (1000, 46)
# key: 6064 shape: (1000, 46)
# key: 6078 shape: (1000, 46)
# key: 6081 shape: (1000, 46)
# key: 6147 shape: (1000, 46)
# key: 6181 shape: (1000, 46)
# key: 6209 shape: (1000, 46)
# key: 625 shape: (1000, 46)
# key: 6272 shape: (1000, 46)
# key: 6367 shape: (1000, 46)
# key: 6385 shape: (1000, 46)
# key: 6415 shape: (1000, 46)
# key: 6437 shape: (1000, 46)
# key: 6454 shape: (1000, 46)
# key: 6476 shape: (1000, 46)
# key: 6529 shape: (1000, 46)
# key: 6531 shape: (1000, 46)
# key: 6563 shape: (1000, 46)
# key: 669 shape: (1000, 46)
# key: 6818 shape: (1000, 46)
# key: 6836 shape: (1000, 46)
# key: 6848 shape: (1000, 46)
# key: 6880 shape: (1000, 46)
# key: 6925 shape: (1000, 46)
# key: 696 shape: (1000, 46)
# key: 7059 shape: (1000, 46)
# key: 7067 shape: (1000, 46)
# key: 7078 shape: (1000, 46)
# key: 7113 shape: (1000, 46)
# key: 7148 shape: (1000, 46)
# key: 7178 shape: (1000, 46)
# key: 7190 shape: (1000, 46)
# key: 7226 shape: (1000, 46)
# key: 7264 shape: (1000, 46)
# key: 7278 shape: (1000, 46)
# key: 730 shape: (1000, 46)
# key: 7302 shape: (1000, 46)
# key: 7367 shape: (1000, 46)
# key: 7402 shape: (1000, 46)
# key: 7447 shape: (1000, 46)
# key: 7505 shape: (1000, 46)
# key: 7511 shape: (1000, 46)
# key: 7517 shape: (1000, 46)
# key: 7635 shape: (1000, 46)
# key: 7780 shape: (1000, 46)
# key: 7794 shape: (1000, 46)
# key: 78 shape: (1000, 46)
# key: 7800 shape: (1000, 46)
# key: 7859 shape: (1000, 46)
# key: 8051 shape: (1000, 46)
# key: 8063 shape: (1000, 46)
# key: 8088 shape: (1000, 46)
# key: 8095 shape: (1000, 46)
# key: 8098 shape: (1000, 46)
# key: 8108 shape: (1000, 46)
# key: 8123 shape: (1000, 46)
# key: 8226 shape: (1000, 46)
# key: 8238 shape: (1000, 46)
# key: 83 shape: (1000, 46)
# key: 831 shape: (1000, 46)
# key: 8312 shape: (1000, 46)
# key: 8324 shape: (1000, 46)
# key: 839 shape: (1000, 46)
# key: 8419 shape: (1000, 46)
# key: 8425 shape: (1000, 46)
# key: 8465 shape: (1000, 46)
# key: 8468 shape: (1000, 46)
# key: 8580 shape: (1000, 46)
# key: 8609 shape: (1000, 46)
# key: 8629 shape: (1000, 46)
# key: 8630 shape: (1000, 46)
# key: 87 shape: (1000, 46)
# key: 8747 shape: (1000, 46)
# key: 8770 shape: (1000, 46)
# key: 8797 shape: (1000, 46)
# key: 8838 shape: (1000, 46)
# key: 887 shape: (1000, 46)
# key: 89 shape: (1000, 46)
# key: 8975 shape: (1000, 46)
# key: 909 shape: (1000, 46)
# key: 911 shape: (1000, 46)

# %%
with open(f"../../../data/extracted_features_v2/pca_{features}.pickle", "wb") as file:
    pickle.dump(pca_transformed_data, file)
