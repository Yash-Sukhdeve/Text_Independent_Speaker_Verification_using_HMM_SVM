# %%
import librosa
import os
import pickle
import numpy as np
from scipy.stats import kurtosis,skew,mode
from pydub import AudioSegment
import time
import random

# %%
def get_file_paths_by_subfolder(root_path):
    result = {}
    # Loop through each subfolder in the root path
    for subfolder in os.listdir(root_path):
        subfolder_path = os.path.join(root_path, subfolder)
        
        # Check if it is indeed a folder
        if os.path.isdir(subfolder_path):
            file_paths = []
            
            # Loop through each subsubfolder in the subfolder
            for subsubfolder in os.listdir(subfolder_path):
                subsubfolder_path = os.path.join(subfolder_path, subsubfolder)
                
                # Check if it is indeed a folder
                if os.path.isdir(subsubfolder_path):
                    # Add file paths to the list
                    for file_name in os.listdir(subsubfolder_path):
                        file_path = os.path.join(subsubfolder_path, file_name)
                        
                        # Ensure it is a file
                        if os.path.isfile(file_path):
                            file_paths.append(file_path)
            
            # Add to result dictionary
            result[subfolder] = file_paths

    return result

def get_audio_paths(root_path):
    results = {}
    
    for audio_path in os.listdir(root_path):
        # Get the full path by joining root_path and audio_path
        full_path = os.path.join(root_path, audio_path)
        
        # Only add files (not directories)
        if os.path.isfile(full_path):
            filename = os.path.basename(audio_path)
            file_name_wo_ext, _ = os.path.splitext(filename)
            results[file_name_wo_ext] = full_path

    return results

def combine_wav_files(file_dict, output_path="../../../data/cleaned_combined"):
    for key in file_dict.keys():
        combined_audio = AudioSegment.empty()

        for file_path in file_dict[key]:
            audio = AudioSegment.from_wav(file_path)
            combined_audio += audio
        
        combined_audio.export(f"{output_path}/{key}.wav", format="wav")

# %%
def save_audio_segment(segment, sample_rate, output_file_path):
    # Convert the numpy array back to AudioSegment
    audio_segment = AudioSegment(
        segment.tobytes(),
        frame_rate=sample_rate,
        sample_width=segment.dtype.itemsize,
        channels=1  # Mono channel
    )
    
    # Export the segment as a WAV file
    audio_segment.export(output_file_path, format="wav")

def segment_audio(audio_file_path):
    # Load the audio file
    audio = AudioSegment.from_file(audio_file_path)
    
    # Set duration for each segment in milliseconds and get the sample rate
    segment_duration_ms = 1 * 1000  # 1 seconds in milliseconds
    sample_rate = audio.frame_rate
    samples_per_segment = segment_duration_ms * sample_rate // 1000  # Calculate samples per 4 seconds

    # Convert the entire audio to a numpy array
    audio_array = np.array(audio.get_array_of_samples())

    # Normalize the audio to the range [-1.0, 1.0]
    audio_array = audio_array.astype(np.float32)  # Convert to float32
    audio_array /= np.max(np.abs(audio_array))  # Normalize to [-1, 1]

    # Calculate the number of 4-second segments and trim any extra samples
    num_segments = len(audio_array) // samples_per_segment
    trimmed_audio_array = audio_array[:num_segments * samples_per_segment]

    # Reshape the array into 4-second segments
    segments = trimmed_audio_array.reshape(num_segments, samples_per_segment)
    
    return segments, sample_rate  # Return both segments and the sample rate

def segment_audio_wrapper(file_dict):
    segment_dict = {}

    for key in file_dict.keys():
        segment_dict[key], _ = segment_audio(file_dict[key])
        
    return segment_dict

# %%
def extract_features(audio_segments, sample_rate=16000):
    
    def generate_random_indices(num_of_values, range_value, seed=42):
        if num_of_values > range_value + 1:
            raise ValueError("Cannot generate more unique numbers than the specified range.")
        
        random.seed(seed)  # Set the seed for reproducibility
        return random.sample(range(0, range_value), num_of_values)

    indices_to_search = generate_random_indices(1000, len(audio_segments))
    
    feature_list = []
    for index, audio_index  in enumerate(indices_to_search):
        segment = audio_segments[audio_index]

        mfcc_data = librosa.feature.mfcc(y=segment, sr=sample_rate, n_mfcc=20)
        
        # Calculating various statistic measures on the MFCC coefficients
        mean_mfcc = np.mean(mfcc_data, axis=1)
        median_mfcc = np.median(mfcc_data, axis=1)
        std_mfcc = np.std(mfcc_data, axis=1)
        skew_mfcc = skew(mfcc_data, axis=1)
        kurt_mfcc = kurtosis(mfcc_data, axis=1)
        maximum_mfcc = np.amax(mfcc_data, axis=1)
        minimum_mfcc = np.amin(mfcc_data, axis=1)
        
        # Pitch extraction
        # f0, voiced_flag, voiced_probs = librosa.pyin(
        #     segment, fmin=librosa.note_to_hz('C2'), fmax=librosa.note_to_hz('C7')
        # )
        
        # Handle NaNs in pitch
        # if np.all(np.isnan(f0)):
        #     mean_pitch, median_pitch = 0, 0  # Set default if no pitch is detected
        # else:
        #     mean_pitch = np.nanmean(f0)  # Mean pitch, ignoring NaNs
        #     median_pitch = np.nanmedian(f0)  # Median pitch, ignoring NaNs

        segment_features = np.concatenate((
            mean_mfcc, median_mfcc, std_mfcc, skew_mfcc, kurt_mfcc, maximum_mfcc, minimum_mfcc
        ))

        # segment_features = np.concatenate((
        #     mean_mfcc, median_mfcc, std_mfcc, skew_mfcc, kurt_mfcc, maximum_mfcc, minimum_mfcc,
        #     [mean_pitch, median_pitch]  # Add pitch statistics to the feature list
        # ))

        if not np.any(np.isnan(segment_features)):
            feature_list.append(segment_features)

    return(feature_list)

def extract_features_wrapper(segment_dict, save_to):
    feature_dict = {}

    for key in segment_dict.keys():
        extracted_features = extract_features(segment_dict[key]) 
        feature_dict[key] = extracted_features

    with open(f"../../../data/extracted_features_v2/{save_to}.pickle", "wb") as file:
        pickle.dump(feature_dict, file)

# %%
def extract_format_frequencies(audio_segments, sample_rate=16000):
    
    format_time_list = []
    feature_list = []
    sample_limit = 300
    for index, segment in enumerate(audio_segments[0:sample_limit]):

        format_start_time = time.time()
        spectral_centroid = np.mean(librosa.feature.spectral_centroid(y=segment, sr=sample_rate))
        spectral_bandwidth = np.mean(librosa.feature.spectral_bandwidth(y=segment, sr=sample_rate))
        spectral_flatness = np.mean(librosa.feature.spectral_flatness(y=segment))
        spectral_rolloff = np.mean(librosa.feature.spectral_rolloff(y=segment, sr=sample_rate))
        format_time = time.time() - format_start_time
        
        segment_features = np.array([
            spectral_centroid.item() if isinstance(spectral_centroid, np.ndarray) else spectral_centroid,
            spectral_bandwidth.item() if isinstance(spectral_bandwidth, np.ndarray) else spectral_bandwidth,
            spectral_flatness.item() if isinstance(spectral_flatness, np.ndarray) else spectral_flatness,
            spectral_rolloff.item() if isinstance(spectral_rolloff, np.ndarray) else spectral_rolloff
        ])

        feature_list.append(segment_features)

        if index == int(sample_limit * .1):
            print("10 percent")
        elif index == int(sample_limit * .2):
            print("20 percent")
        elif index == int(sample_limit * .3):
            print("30 percent")
        elif index == int(sample_limit * .4):
            print("40 percent")
        elif index == int(sample_limit * .5):
            print("50 percent")
        elif index == int(sample_limit * .6):
            print("60 percent")
        elif index == int(sample_limit * .7):
            print("70 percent")
        elif index == int(sample_limit * .8):
            print("80 percent")
        elif index == int(sample_limit * .9):
            print("90 percent")

        format_time_list.append(format_time)
    
    print("Format extraction time:", sum(format_time_list))
    return feature_list

def extract_format_frequencies_wrapper(segment_dict):
    feature_dict = {}

    for key in segment_dict.keys():
        extracted_features = extract_format_frequencies(segment_dict[key]) 
        feature_dict[key] = extracted_features

        with open(f"../../../data/extracted_features_v2/seperate/features_20_{key}.pickle", "wb") as file:
            pickle.dump(extracted_features, file)
    
    with open(f"../../../data/extracted_features_v2/format_frequencies.pickle", "wb") as file:
        pickle.dump(feature_dict, file)

# %%
def extract_lfcc_features(audio_segments, sample_rate=16000):
    
    lfcc_time_list = []
    feature_time_list = []

    feature_list = []
    sample_limit = 300
    for index, segment in enumerate(audio_segments[0:sample_limit]):

        lfcc_start_time = time.time()
        
        # Linear Frequency Cepstral Coefficients (LFCC) extraction
        # Compute the linear frequency spectrogram
        linear_spectrogram = librosa.stft(segment)
        mag, phase = librosa.magphase(linear_spectrogram)
        
        # Apply log scaling
        log_magnitude = np.log1p(mag)
        
        # Apply Discrete Cosine Transform (DCT) to get LFCC coefficients
        lfcc_data = librosa.feature.mfcc(S=log_magnitude, sr=sample_rate, n_mfcc=20)
        
        lfcc_time = time.time() - lfcc_start_time

        feature_start_time = time.time()
        # Calculating various statistic measures on the LFCC coefficients
        mean_lfcc = np.mean(lfcc_data, axis=1)
        median_lfcc = np.median(lfcc_data, axis=1)
        std_lfcc = np.std(lfcc_data, axis=1)
        skew_lfcc = skew(lfcc_data, axis=1)
        kurt_lfcc = kurtosis(lfcc_data, axis=1)
        maximum_lfcc = np.amax(lfcc_data, axis=1)
        minimum_lfcc = np.amin(lfcc_data, axis=1)
        
        feature_time = time.time() - feature_start_time

        segment_features = np.concatenate((
            mean_lfcc, median_lfcc, std_lfcc, skew_lfcc, kurt_lfcc, maximum_lfcc, minimum_lfcc
        ))

        lfcc_time_list.append(lfcc_time)
        feature_time_list.append(feature_time)

        feature_list.append(segment_features)

        # Progress tracking
        if index == sample_limit * .1:
            print("10 percent")
        elif index == sample_limit * .2:
            print("20 percent")
        elif index == sample_limit * .3:
            print("30 percent")
        elif index == sample_limit * .4:
            print("40 percent")
        elif index == sample_limit * .5:
            print("50 percent")
        elif index == sample_limit * .6:
            print("60 percent")
        elif index == sample_limit * .7:
            print("70 percent")
        elif index == sample_limit * .8:
            print("80 percent")
        elif index == sample_limit * .9:
            print("90 percent")

    return feature_list

def extract_lfcc_features_wrapper(segment_dict):
    feature_dict = {}

    for key in segment_dict.keys():
        extracted_features = extract_lfcc_features(segment_dict[key]) 
        feature_dict[key] = extracted_features


    with open(f"../../../data/extracted_features_v2/lfcc_features.pickle", "wb") as file:
        pickle.dump(feature_dict, file)

# %%
file_dictionary = get_file_paths_by_subfolder(r"C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned")

# %%
# DO NOT RUN AGAIN 
combine_wav_files(file_dictionary)

# %%
audio_paths = get_audio_paths(r"C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2")

print(len(audio_paths.keys()))
for key in audio_paths.keys():
    print(audio_paths[key])
# Out:
# 251
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\103.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\1034.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\1040.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\1069.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\1081.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\1088.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\1098.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\1116.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\118.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\1183.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\1235.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\1246.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\125.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\1263.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\1334.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\1355.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\1363.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\1447.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\1455.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\150.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\1502.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\1553.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\1578.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\1594.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\1624.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\163.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\1723.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\1737.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\1743.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\1841.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\1867.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\1898.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\19.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\1926.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\196.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\1963.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\1970.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\198.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\1992.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\200.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\2002.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\2007.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\201.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\2092.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\211.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\2136.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\2159.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\2182.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\2196.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\226.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\2289.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\229.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\233.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\2384.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\2391.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\2416.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\2436.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\248.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\250.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\2514.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\2518.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\254.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\26.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\2691.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\27.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\2764.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\2817.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\2836.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\2843.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\289.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\2893.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\2910.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\2911.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\2952.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\298.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\2989.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\302.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\307.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\311.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\3112.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\3168.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\32.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\3214.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\322.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\3235.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\3240.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\3242.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\3259.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\328.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\332.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\3374.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\3436.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\3440.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\3486.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\3526.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\3607.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\3664.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\3699.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\3723.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\374.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\3807.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\3830.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\3857.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\3879.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\39.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\3947.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\3982.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\3983.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\40.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\4014.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\4018.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\403.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\405.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\4051.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\4088.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\412.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\4137.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\4160.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\4195.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\4214.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\426.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\4267.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\4297.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\4340.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\4362.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\4397.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\4406.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\441.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\4441.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\445.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\446.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\4481.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\458.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\460.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\4640.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\4680.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\4788.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\481.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\4813.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\4830.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\4853.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\4859.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\4898.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\5022.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\5049.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\5104.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\5163.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\5192.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\5322.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\5339.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\5390.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\5393.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\5456.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\5463.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\5514.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\5561.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\5652.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\5678.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\5688.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\5703.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\5750.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\5778.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\5789.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\5808.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\5867.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\587.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\60.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\6000.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\6019.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\6064.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\6078.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\6081.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\6147.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\6181.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\6209.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\625.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\6272.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\6367.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\6385.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\6415.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\6437.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\6454.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\6476.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\6529.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\6531.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\6563.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\669.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\6818.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\6836.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\6848.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\6880.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\6925.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\696.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\7059.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\7067.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\7078.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\7113.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\7148.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\7178.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\7190.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\7226.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\7264.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\7278.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\730.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\7302.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\7312.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\7367.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\7402.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\7447.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\7505.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\7511.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\7517.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\7635.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\7780.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\7794.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\78.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\7800.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\7859.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\8014.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\8051.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\8063.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\8088.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\8095.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\8098.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\8108.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\8123.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\8226.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\8238.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\83.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\831.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\8312.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\8324.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\839.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\8419.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\8425.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\8465.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\8468.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\8580.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\8609.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\8629.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\8630.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\87.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\8747.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\8770.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\8797.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\8838.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\887.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\89.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\8975.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\909.wav
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned_combined_v2\911.wav

# %%
segment_dict = segment_audio_wrapper(audio_paths)

print(segment_dict.keys())

# %%
# 1040 | M | train-clean-100  | 15.70 | John Garvin
# 1992 | F | train-clean-100  | 12.29 | Michelle White
# 445  | M | train-clean-100  | 11.08 | Dave Foss
# 8014 | F | train-clean-100  | 14.42 | constatine

for key in list(segment_dict.keys()):
    if len(segment_dict[key]) < 1000:
        print(f"speaker {key}: {len(segment_dict[key])}")
        del segment_dict[key]

print(len(segment_dict.keys()))
# Out:
# 96

# %%
extract_features_wrapper(segment_dict, "mfcc_20_no_pitch_1000_rand_100_speakers.pickle")
