# %%
import os
import re
from collections import defaultdict
from pocketsphinx import AudioFile, get_model_path, Decoder
from pydub import AudioSegment, split_on_silence

# %%
def find_keyword_context(sentence, keyword):
    # Split the sentence into words
    words = sentence.lower().split()
    
    # Initialize an empty list to store the results
    context = []
    
    # Iterate over the words and check for the keyword
    for i in range(1, len(words) - 1):  # avoid first and last word for context
        if words[i] == keyword:
            # Get the word before and after the keyword
            before = words[i - 1]
            after = words[i + 1]
            # Add the context to the result list
            context.append((before, keyword, after))
    
    return context

def segment_word(input_wav, output_wav, ground_truth, target_word, buffer=0, sample_rate=1600):
    model_path = get_model_path()

    word_times = []

    config = {
        'verbose': False,
        'hmm': os.path.join(model_path, 'en-us'),  # Path to the acoustic model
        'lm': os.path.join(model_path, 'en-us.lm.bin'),  # Path to the language model
        'dict': os.path.join(model_path, 'cmudict-en-us.dict'),  # Path to the dictionary
        'frate': 100,
        'samprate': 16000
    }

    # Initialize the decoder
    decoder = Decoder(config)

    # Start decoding the audio file
    decoder.start_utt()
    
    # Read the audio file in binary mode and process it
    with open(input_wav, 'rb') as audio_file:
        while True:
            buf = audio_file.read(1024)
            if not buf:
                break
            decoder.process_raw(buf, False, False)

    decoder.end_utt()

    context = find_keyword_context(ground_truth, target_word)
    print(context)

    recognized_words = []
    context_counter = 1
    seg_list = [seg for seg in decoder.seg()]
    for index, seg in enumerate(seg_list):
        word = seg.word.split('(')[0]  # Get the word before the hypothesis index
        
        recognized_words.append(word)  # Collect all recognized words
        
        if word.lower() == target_word.lower():
            # print(seg_list[index-1].word.split('(')[0] == context[1][0], word, seg_list[index+1].word.split('(')[0] == context[1][2])
            # print(seg_list[index-1].word.split('(')[0], word, seg_list[index+1].word.split('(')[0])
            for context_idx in range(0, len(context)): # this loop 
                if (seg_list[index-1].word.split('(')[0] == context[context_idx][0]) or (seg_list[index+1].word.split('(')[0] == context[context_idx][2]):
                    # Append start and end times (in milliseconds)
                    start_time = int(seg_list[index-1].end_frame * (1000 / 100))  # Assuming 100 frames per second
                    end_time = int(seg_list[index+1].start_frame * (1000 / 100))
                    adjusted_start = max(0, start_time - buffer)  # One second before
                    adjusted_end = end_time + buffer
                    word_times.append((adjusted_start, adjusted_end))
    
    print("Recognized words:", ' '.join(recognized_words))

    # if not word_times:
    #     for index, seg in enumerate(seg_list):
    #         word = seg.word.split('(')[0]  # Get the word before the hypothesis index
    #         if index-1 >= 0:
    #              for context_idx in range(0, len(context)):
    #                 if (seg_list[index-1].word.split('(')[0] == context[context_idx][0]) and (seg_list[index+2].word.split('(')[0] == context[context_idx][2]):
    #                     start_time = int(seg_list[index-1].end_frame * (1000 / 100))  # Assuming 100 frames per second
    #                     end_time = int(seg_list[index+1].start_frame * (1000 / 100))
    #                     adjusted_start = max(0, start_time - buffer)  # One second before
    #                     adjusted_end = end_time + buffer
    #                     word_times.append((adjusted_start, adjusted_end))
    
    if not word_times:
        print(f"The word '{target_word}' was not found in the audio {input_wav}")
        return

    original_audio = AudioSegment.from_wav(input_wav)

    # Extract segments for each occurrence of the target word
    for i, (start, end) in enumerate(word_times):
        # Ensure the start and end times are within the audio length
        start = max(0, start)
        end = min(len(original_audio), end)
        
        # Extract the audio segment
        word_audio = original_audio[start:end]
        
        # Save the extracted segment using the original sample rate
        name_without_extension = os.path.splitext(output_wav)[0]
        output_file = f"{name_without_extension}_{i + 1}.wav"
        word_audio.export(output_file, format="wav")
        print(f"Extracted '{target_word}' to '{output_file}' from {start}ms to {end}ms.")
    
        # Save the extracted segment to the current directory
        # output_file = f"extracted_word_{i + 1}.wav"
        # word_audio.export(output_file, format="wav")
        # print(f"Extracted '{target_word}' to '{output_file}' from {start}ms to {end}ms.")

# %%
def count_word_occurrences(file_paths):
    word_count = defaultdict(lambda: [0, set()])  # Default dictionary to hold (count, set of identifiers)
    
    # Read each file and count words
    for file_path in file_paths:
        with open(file_path, 'r', encoding='utf-8') as file:
            for line in file:
                identifier, text = line.split(' ', 1)
                words = text.split()
                
                for word in words:
                    # Normalize words to lowercase for consistent counting
                    normalized_word = word.lower()
                    word_count[normalized_word][0] += 1  # Increment word count
                    word_count[normalized_word][1].add(identifier)  # Add identifier

    # Create a sorted list from the dictionary
    sorted_word_counts = [
        (count_info[0], word, list(count_info[1])) 
        for word, count_info in word_count.items()
    ]
    sorted_word_counts.sort(key=lambda x: x[0], reverse=True)  # Sort by count (descending)

    return sorted_word_counts

def count_speaker_occurrences(identifiers):
    speaker_count = defaultdict(int)  # Default dictionary to hold counts of each speaker

    # Count occurrences of each speaker
    for identifier in identifiers:
        speaker_number = identifier.split('-')[0]  # Extract speaker number
        speaker_count[speaker_number] += 1  # Increment the count for the speaker

    # Convert to a regular dictionary for better readability
    return dict(speaker_count)

def generate_path(filename, path_prefix):
    reader, chapter, trial = filename.split('-')
    return f"{path_prefix}/{reader}/{chapter}/{reader}-{chapter}-{trial}.wav"

def get_ground_truth(filename):
    path_prefix = 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/LibriSpeech/train-clean-100'
    speaker, chapter, sentence = filename.split("-")
    path_to_ground_truths = f"{path_prefix}/{speaker}/{chapter}/{speaker}-{chapter}.trans.txt"

    with open(path_to_ground_truths, 'r') as file:
        for line in file:
            # Split the line by the dash and get the last element (the last number)
            parts = line.split('-')
            last_number = parts[-1].strip().split()[0]  # Extract number and remove surrounding whitespace
            
            # If the last number matches the search number, extract and return the rest of the line
            if last_number == str(sentence):
                # Get the part after the last number (remove the number and dashes)
                remainder = ' '.join(parts[-1].strip().split()[1:])
                return(remainder.lower())

def word_extraction_wrapper(files_to_search, save_to_path, word):
    for file in files_to_search:
        _, _, _, _, _, _, _, speaker, chapter, filename = file.split('/')
        
        ground_truth = get_ground_truth(os.path.splitext(filename)[0])
        print(ground_truth)
        save_to = f"{save_to_path}/{word}_before_after/{speaker}/{filename}"
        segment_word(file, save_to, ground_truth, word)

# %%
# file_paths = [r"C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\LibriSpeech\train-clean-100\87\121553\87-121553.trans.txt"]

file_paths = [r"C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\LibriSpeech\train-clean-100\201\122255\201-122255.trans.txt",
              r"C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\LibriSpeech\train-clean-100
# (1, 'surface', ['311-124404-0006'])
# (1, 'faces', ['311-124404-0006'])
# (1, 'solid', ['311-124404-0006'])
# (1, 'select', ['311-124404-0006'])
# (1, 'chief', ['311-124404-0006'])
# (1, 'throwing', ['311-124404-0006'])
# (1, 'fearing', ['311-124404-0007'])
# (1, 'compense', ['311-124404-0007'])
# (1, 'discourse', ['311-124404-0007'])
# (1, 'expound', ['311-124404-0007'])
# (1, 'singly', ['311-124404-0007'])
# (1, 'opportunity', ['311-124404-0008'])
# (1, 'adding', ['311-124404-0008'])
# (1, 'proceeds', ['311-124404-0008'])
# (1, 'transmit', ['311-124404-0008'])
# (1, 'colored', ['311-124404-0009'])
# (1, 'transparent', ['311-124404-0009'])
# (1, 'luminous', ['311-124404-0009'])
# (1, 'spectator', ['311-124404-0009'])
# (1, 'cast', ['311-124404-0010'])
# (1, 'subjects', ['311-124404-0010'])
# (1, 'somewhat', ['311-124404-0010'])
# (1, 'express', ['311-124404-0010'])
# (1, 'judgment', ['311-124404-0010'])
# (1, 'freedom', ['311-124404-0010'])
# (1, 'necessitated', ['311-124404-0010'])
# (1, 'adopt', ['311-124404-0010'])
# (1, 'refute', ['311-124404-0010'])
# (1, 'disputes', ['311-124404-0011'])
# (1, 'create', ['311-124404-0011'])
# (1, 'somewhere', ['311-124404-0011'])
# (1, 'imaginary', ['311-124404-0011'])
# (1, 'agitate', ['311-124404-0012'])
# (1, 'confusedly', ['311-124404-0012'])
# (1, 'resulted', ['311-124404-0012'])
# (1, 'disordered', ['311-124404-0012'])
# (1, 'poets', ['311-124404-0012'])
# (1, 'feigned', ['311-124404-0012'])
# (1, 'lend', ['311-124404-0013'])
# (1, 'essayed', ['311-124404-0014'])
# (1, 'clearer', ['311-124404-0014'])
# (1, 'intelligible', ['311-124404-0014'])
# (1, 'forms', ['311-124404-0015'])
# (1, 'debated', ['311-124404-0015'])
# (1, 'schools', ['311-124404-0015'])
# (1, 'endeavored', ['311-124404-0016'])
# (1, 'demonstrate', ['311-124404-0016'])
# (1, 'worlds', ['311-124404-0017'])
# (1, 'showed', ['311-124404-0017'])
# (1, 'greatest', ['311-124404-0017'])
# (1, 'dispose', ['311-124404-0017'])
# (1, 'arrange', ['311-124404-0017'])
# (1, 'appearance', ['311-124404-0018'])
# (1, 'meantime', ['311-124404-0018'])
# (1, 'making', ['311-124404-0018'])
# (1, 'digression', ['311-124404-0018'])
# (1, 'stage', ['311-124404-0018'])
# (1, 'subject', ['311-124404-0018'])
# (1, 'traverses', ['311-124404-0020'])
# (1, 'immense', ['311-124404-0020'])
# (1, 'added', ['311-124404-0020'])
# (1, 'motions', ['311-124404-0020'])
# (1, 'alike', ['311-124404-0021'])
# (1, 'tending', ['311-124404-0022'])
# (1, 'both', ['311-124404-0023'])
# (1, 'east', ['311-124404-0023'])
# (1, 'west', ['311-124404-0023'])
# (1, 'tropics', ['311-124404-0023'])
# (1, 'fountains', ['311-124404-0023'])
# (1, 'rivers', ['311-124404-0023'])
# (1, 'naturally', ['311-124404-0023'])
# (1, 'metals', ['311-124404-0024'])
# (1, 'produced', ['311-124404-0024'])
# (1, 'mines', ['311-124404-0024'])
# (1, 'grow', ['311-124404-0024'])
# (1, 'fields', ['311-124404-0024'])
# (1, 'mixed', ['311-124404-0024'])
# (1, 'composite', ['311-124404-0024'])
# (1, 'generated', ['311-124404-0024'])
# (1, 'discoveries', ['311-124404-0024'])
# (1, 'alluded', ['311-124404-0024'])
# (1, 'fire', ['311-124404-0025'])
# (1, 'produces', ['311-124404-0025'])
# (1, 'spared', ['311-124404-0025'])
# (1, 'pertains', ['311-124404-0025'])
# (1, 'support', ['311-124404-0025'])
# (1, 'sometimes', ['311-124404-0025'])
# (1, 'induce', ['311-124404-0026'])
# (1, 'colors', ['311-124404-0026'])
# (1, 'diverse', ['311-124404-0026'])
# (1, 'reduces', ['311-124404-0026'])
# (1, 'liquid', ['311-124404-0026'])
# (1, 'hardens', ['311-124404-0026'])
# (1, 'consume', ['311-124404-0026'])
# (1, 'convert', ['311-124404-0026'])
# (1, 'smoke', ['311-124404-0026'])
# (1, 'transmutation', ['311-124404-0028'])
# (1, 'wonderful', ['311-124404-0028'])
# (1, 'describing', ['311-124404-0028'])
# (1, 'opinion', ['311-124404-0030'])
# (1, 'theologians', ['311-124404-0030'])
# (1, 'sustains', ['311-124404-0030'])
# (1, 'originally', ['311-124404-0030'])
# (1, 'beginning', ['311-124404-0031'])
# (1, 'provided', ['311-124404-0031'])
# (1, 'lent', ['311-124404-0031'])
# (1, 'wont', ['311-124404-0031'])
# (1, 'believed', ['311-124404-0032'])
# (1, 'discredit', ['311-124404-0032'])
# (1, 'miracle', ['311-124404-0032'])
# (1, 'creation', ['311-124404-0032'])
# (1, 'purely', ['311-124404-0032'])
# (1, 'material', ['311-124404-0032'])
# (1, 'description', ['311-124404-0033'])
# (1, 'inanimate', ['311-124404-0033'])
# (1, 'deducing', ['311-124404-0034'])
# (1, 'effects', ['311-124404-0034'])
# (1, 'satisfied', ['311-124404-0035'])
# (1, 'conformation', ['311-124404-0035'])
# (1, 'vegetative', ['311-124404-0036'])
# (1, 'sensitive', ['311-124404-0036'])
# (1, 'kindling', ['311-124404-0036'])
# (1, 'fires', ['311-124404-0036'])
# (1, 'hay', ['311-124404-0037'])
# (1, 'heaped', ['311-124404-0037'])
# (1, 'dry', ['311-124404-0037'])
# (1, 'fermentation', ['311-124404-0037'])
# (1, 'wines', ['311-124404-0037'])
# (1, 'run', ['311-124404-0037'])
# (1, 'fruit', ['311-124404-0037'])
# (1, 'examined', ['311-124404-0037'])
# (1, 'consequences', ['311-124404-0038'])
# (1, 'independently', ['311-124404-0038'])
# (1, 'consists', ['311-124404-0039'])
# (1, 'thinking', ['311-124404-0039'])
# (1, 'void', ['311-124404-0039'])
# (1, 'resemble', ['311-124404-0039'])
# (1, 'dependent', ['311-124404-0039'])
# (1, 'belong', ['311-124404-0039'])
# (1, 'afterwards', ['311-124404-0040'])
# (1, 'annexed', ['311-124404-0040'])
# (1, 'determining', ['311-124404-0041'])
# (1, 'getting', ['311-124404-0042'])
# (1, 'dissected', ['311-124404-0042'])
# (1, 'large', ['311-124404-0042'])
# (1, 'ventricles', ['311-124404-0043'])
# (1, 'correspond', ['311-124404-0043'])
# (1, 'ample', ['311-124404-0043'])
# (1, 'tubes', ['311-124404-0043'])
# (1, 'cava', ['311-124404-0043'])
# (1, 'receptacle', ['311-124404-0044'])
# (1, 'trunk', ['311-124404-0044'])
# (1, 'arteriosa', ['311-124404-0044'])
# (1, 'disperse', ['311-124404-0045'])
# (1, 'canals', ['311-124404-0046'])
# (1, 'size', ['311-124404-0046'])
# (1, 'larger', ['311-124404-0046'])
# (1, 'preceding', ['311-124404-0046'])
# (1, 'arteria', ['311-124404-0046'])
# (1, 'venosa', ['311-124404-0046'])
# (1, 'designated', ['311-124404-0046'])
# (1, 'divided', ['311-124404-0047'])
# (1, 'interlaced', ['311-124404-0047'])
# (1, 'tube', ['311-124404-0047'])
# (1, 'windpipe', ['311-124404-0047'])
# (1, 'breathe', ['311-124404-0047'])
# (1, 'issuing', ['311-124404-0047'])
# (1, 'sends', ['311-124404-0047'])
# (1, 'eleven', ['311-124404-0048'])
# (1, 'four', ['311-124404-0048'])
# (1, 'contains', ['311-124404-0049'])
# (1, 'ventricle', ['311-124404-0049'])
# (1, 'opposite', ['311-124404-0050'])
# (1, 'permit', ['311-124404-0050'])
# (1, 'preclude', ['311-124404-0051'])
# (1, 'suffer', ['311-124404-0051'])
# (1, 'reflux', ['311-124404-0052'])
# (1, 'orifice', ['311-124404-0052'])
# (1, 'oval', ['311-124404-0052'])
# (1, 'adequately', ['311-124404-0052'])
# (1, 'conveniently', ['311-124404-0053'])
# (1, 'observe', ['311-124404-0053'])
# (1, 'harder', ['311-124404-0053'])
# (1, 'firmer', ['311-124404-0053'])
# (1, 'texture', ['311-124404-0053'])
# (1, 'pouches', ['311-124404-0054'])
# (1, 'auricles', ['311-124404-0054'])
# (1, 'warmth', ['311-124404-0054'])
# (1, 'rapidly', ['311-124404-0055'])
# (1, 'dilate', ['311-124404-0055'])
# (1, 'liquors', ['311-124404-0055'])
# (1, 'highly', ['311-124404-0055'])
# (1, 'heated', ['311-124404-0055'])
# (1, 'vessel', ['311-124404-0055'])
# (1, 'wide', ['311-124404-0058'])
# (1, 'dilated', ['311-124404-0059'])
# (1, 'press', ['311-124404-0059'])
# (1, 'home', ['311-124404-0059'])
# (1, 'entrances', ['311-124404-0059'])
# (1, 'becoming', ['311-124404-0060'])
# (1, 'push', ['311-124404-0060'])
# (1, 'simultaneously', ['311-124404-0061'])
# (1, 'begins', ['311-124404-0061'])
# (1, 'anew', ['311-124404-0063'])
# (1, 'passage', ['311-124404-0063'])
# (1, 'expands', ['311-124404-0065'])
# (1, 'ignorant', ['311-124404-0065'])
# (1, 'mathematical', ['311-124404-0065'])
# (1, 'accustomed', ['311-124404-0065'])
# (1, 'distinguish', ['311-124404-0065'])
# (1, 'mere', ['311-124404-0066'])
# (1, 'verisimilitudes', ['311-124404-0066'])
# (1, 'examination', ['311-124404-0066'])
# (1, 'deny', ['311-124404-0066'])
# (1, 'explained', ['311-124404-0066'])
# (1, 'follows', ['311-124404-0066'])
# (1, 'fingers', ['311-124404-0067'])
# (1, 'counterweights', ['311-124404-0068'])
# (1, 'continually', ['311-124404-0068'])
# (1, 'exhausted', ['311-124404-0068'])
# (1, 'teach', ['311-124404-0069'])
# (1, 'passages', ['311-124404-0069'])
# (1, 'amounts', ['311-124404-0070'])
# (1, 'perpetual', ['311-124404-0070'])
# (1, 'circulation', ['311-124404-0070'])
# (1, 'abundant', ['311-124404-0070'])
# (1, 'surgeons', ['311-124404-0070'])
# (1, 'binding', ['311-124404-0070'])
# (1, 'moderate', ['311-124404-0070'])
# (1, 'straitness', ['311-124404-0070'])
# (1, 'copiously', ['311-124404-0071'])
# (1, 'quite', ['311-124404-0071'])
# (1, 'bind', ['311-124404-0071'])
# (1, 'moderately', ['311-124404-0072'])
# (1, 'straightened', ['311-124404-0072'])
# (1, 'situated', ['311-124404-0073'])
# (1, 'coverings', ['311-124404-0073'])
# (1, 'consistency', ['311-124404-0073'])
# (1, 'difficult', ['311-124404-0073'])
# (1, 'compress', ['311-124404-0073'])
# (1, 'tends', ['311-124404-0073'])
# (1, 'latter', ['311-124404-0074'])
# (1, 'escapes', ['311-124404-0074'])
# (1, 'single', ['311-124404-0075'])
# (1, 'quarter', ['311-124404-0076'])
# (1, 'evince', ['311-124404-0076'])
# (1, 'alleged', ['311-124404-0076'])
# (1, 'arise', ['311-124404-0077'])
# (1, 'warmer', ['311-124404-0078'])
# (1, 'attention', ['311-124404-0079'])
# (1, 'marked', ['311-124404-0079'])
# (1, 'neighborhood', ['311-124404-0079'])
# (1, 'shows', ['311-124404-0081'])
# (1, 'impelled', ['311-124404-0081'])
# (1, 'thinner', ['311-124404-0082'])
# (1, 'rarefies', ['311-124404-0082'])
# (1, 'higher', ['311-124404-0082'])
# (1, 'hot', ['311-124404-0083'])
# (1, 'glowing', ['311-124404-0083'])
# (1, 'iron', ['311-124404-0083'])
# (1, 'warming', ['311-124404-0083'])
# (1, 'children', ['311-124404-0084'])
# (1, 'womb', ['311-124404-0084'])
# (1, 'distilled', ['311-124404-0085'])
# (1, 'repassing', ['311-124404-0085'])
# (1, 'hundred', ['311-124404-0085'])
# (1, 'humors', ['311-124404-0086'])
# (1, 'remain', ['311-124404-0086'])
# (1, 'arrive', ['311-124404-0086'])
# (1, 'occupy', ['311-124404-0087'])
# (1, 'expelled', ['311-124404-0087'])
# (1, 'smallness', ['311-124404-0087'])
# (1, 'pores', ['311-124404-0087'])
# (1, 'perforated', ['311-124404-0088'])
# (1, 'serve', ['311-124404-0088'])
# (1, 'separate', ['311-124404-0088'])
# (1, 'grain', ['311-124404-0088'])
# (1, 'worthy', ['311-124404-0088'])
# (1, 'observation', ['311-124404-0088'])
# (1, 'generation', ['311-124404-0089'])
# (1, 'subtle', ['311-124404-0089'])
# (1, 'wind', ['311-124404-0089'])
# (1, 'pure', ['311-124404-0089'])
# (1, 'flame', ['311-124404-0089'])
# (1, 'ascending', ['311-124404-0090'])
# (1, 'penetrates', ['311-124404-0090'])
# (1, 'gives', ['311-124404-0090'])
# (1, 'penetrating', ['311-124404-0090'])
# (1, 'proceeding', ['311-124404-0091'])
# (1, 'carry', ['311-124404-0091'])
# (1, 'thither', ['311-124404-0091'])
# (1, 'direct', ['311-124404-0092'])
# (1, 'lines', ['311-124404-0092'])
# (1, 'rules', ['311-124404-0092'])
# (1, 'mechanics', ['311-124404-0092'])
# (1, 'weaker', ['311-124404-0093'])
# (1, 'stronger', ['311-124404-0093'])
# (1, 'matters', ['311-124404-0094'])
# (1, 'minuteness', ['311-124404-0094'])
# (1, 'treatise', ['311-124404-0094'])
# (1, 'publishing', ['311-124404-0094'])
# (1, 'fabric', ['311-124404-0094'])
# (1, 'heads', ['311-124404-0095'])
# (1, 'shortly', ['311-124404-0095'])
# (1, 'still', ['311-124404-0095'])
# (1, 'bite', ['311-124404-0095'])
# (1, 'longer', ['311-124404-0095'])
# (1, 'animated', ['311-124404-0095'])
# (1, 'changes', ['311-124404-0095'])
# (1, 'waking', ['311-124404-0096'])
# (1, 'sleep', ['311-124404-0096'])
# (1, 'dreams', ['311-124404-0096'])
# (1, 'sounds', ['311-124404-0096'])
# (1, 'odors', ['311-124404-0096'])
# (1, 'tastes', ['311-124404-0096'])
# (1, 'senses', ['311-124404-0096'])
# (1, 'hunger', ['311-124404-0096'])
# (1, 'thirst', ['311-124404-0097'])
# (1, 'affections', ['311-124404-0097'])
# (1, 'divers', ['311-124404-0097'])
# (1, 'common', ['311-124404-0097'])
# (1, 'sensus', ['311-124404-0097'])
# (1, 'communis', ['311-124404-0097'])
# (1, 'memory', ['311-124404-0097'])
# (1, 'retains', ['311-124404-0097'])
# (1, 'fantasy', ['311-124404-0098'])
# (1, 'distributing', ['311-124404-0098'])
# (1, 'acquainted', ['311-124404-0099'])
# (1, 'performed', ['311-124404-0099'])
# (1, 'automata', ['311-124404-0099'])
# (1, 'fabricated', ['311-124404-0099'])
# (1, 'few', ['311-124404-0099'])
# (1, 'compared', ['311-124404-0099'])
# (1, 'multitude', ['311-124404-0099'])
# (1, 'incomparably', ['311-124404-0100'])
# (1, 'admirable', ['311-124404-0101'])
# (1, 'invention', ['311-124404-0101'])
# (1, 'specially', ['311-124404-0101'])
# (1, 'stayed', ['311-124404-0101'])
# (1, 'resembling', ['311-124404-0101'])
# (1, 'outward', ['311-124404-0101'])
# (1, 'irrational', ['311-124404-0101'])
# (1, 'knowing', ['311-124404-0102'])
# (1, 'bearing', ['311-124404-0102'])
# (1, 'image', ['311-124404-0102'])
# (1, 'imitating', ['311-124404-0102'])
# (1, 'conceive', ['311-124404-0103'])
# (1, 'constructed', ['311-124404-0103'])
# (1, 'vocables', ['311-124404-0103'])
# (1, 'correspondent', ['311-124404-0103'])
# (1, 'example', ['311-124404-0104'])
# (1, 'touched', ['311-124404-0104'])
# (1, 'demand', ['311-124404-0104'])
# (1, 'hurt', ['311-124404-0104'])
# (1, 'appositely', ['311-124404-0105'])
# (1, 'lowest', ['311-124404-0105'])
# (1, 'grade', ['311-124404-0105'])
# (1, 'intellect', ['311-124404-0105'])
# (1, 'test', ['311-124404-0105'])
# (1, 'execute', ['311-124404-0105'])
# (1, 'perfection', ['311-124404-0105'])
# (1, 'impossible', ['311-124404-0106'])
# (1, 'diversity', ['311-124404-0106'])
# (1, 'dull', ['311-124404-0107'])
# (1, 'idiots', ['311-124404-0107'])
# (1, 'incapable', ['311-124404-0107'])
# (1, 'joining', ['311-124404-0107'])
# (1, 'thereby', ['311-124404-0107'])
# (1, 'constructing', ['311-124404-0107'])
# (1, 'declaration', ['311-124404-0107'])
# (1, 'speaking', ['311-124404-0108'])
# (1, 'habit', ['311-124404-0108'])
# (1, 'spontaneously', ['311-124404-0108'])
# (1, 'inventing', ['311-124404-0108'])
# (1, 'leisure', ['311-124404-0108'])
# (1, 'required', ['311-124404-0109'])
# (1, 'inequality', ['311-124404-0110'])
# (1, 'capacity', ['311-124404-0110'])
# (1, 'instructed', ['311-124404-0110'])
# (1, 'incredible', ['311-124404-0110'])
# (1, 'perfect', ['311-124404-0110'])
# (1, 'parrot', ['311-124404-0110'])
# (1, 'infant', ['311-124404-0111'])
# (1, 'crack', ['311-124404-0111'])
# (1, 'brained', ['311-124404-0111'])
# (1, 'ought', ['311-124404-0112'])
# (1, 'confound', ['311-124404-0112'])
# (1, 'speech', ['311-124404-0112'])
# (1, 'indicate', ['311-124404-0112'])
# (1, 'passions', ['311-124404-0112'])
# (1, 'imitated', ['311-124404-0112'])
# (1, 'manifested', ['311-124404-0112'])
# (1, 'ancients', ['311-124404-0112'])
# (1, 'understand', ['311-124404-0112'])
# (1, 'endowed', ['311-124404-0113'])
# (1, 'analogous', ['311-124404-0113'])
# (1, 'communicate', ['311-124404-0113'])
# (1, 'fellows', ['311-124404-0113'])
# (1, 'circumstance', ['311-124404-0114'])
# (1, 'surpass', ['311-124404-0115'])
# (1, 'acts', ['311-124404-0115'])
# (1, 'disposition', ['311-124404-0115'])
# (1, 'weights', ['311-124404-0115'])
# (1, 'reasonable', ['311-124404-0116'])
# (1, 'educed', ['311-124404-0116'])
# (1, 'spoken', ['311-124404-0117'])
# (1, 'lodged', ['311-124404-0117'])
# (1, 'pilot', ['311-124404-0117'])
# (1, 'ship', ['311-124404-0117'])
# (1, 'joined', ['311-124404-0118'])
# (1, 'united', ['311-124404-0118'])
# (1, 'order', ['311-124404-0118'])
# (1, 'sensations', ['311-124404-0118'])
# (1, 'appetites', ['311-124404-0118'])
# (1, 'constitute', ['311-124404-0118'])
# (1, 'real', ['311-124404-0118'])
# (1, 'powerful', ['311-124404-0119'])
# (1, 'feeble', ['311-124404-0119'])
# (1, 'astray', ['311-124404-0119'])
# (1, 'consequently', ['311-124404-0120'])
# (1, 'flies', ['311-124404-0120'])
# (1, 'ants', ['311-124404-0120'])
# (1, 'differ', ['311-124404-0120'])
# (1, 'comprehend', ['311-124404-0120'])
# (1, 'establish', ['311-124404-0120'])
# (1, 'destroying', ['311-124404-0121'])

# %%
for word in spoken_words:
    if word[1] == "that":
        filenames = word[2]

path_prefix  = "C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/cleaned"
save_to_path = "C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words"

files_to_search = [generate_path(filename, path_prefix) for filename in filenames]

word_extraction_wrapper(files_to_search, save_to_path, "that")
# Out:
# and of having been the first to teach that there are many small passages at the extremities of the arteries through which the blood received by them from the heart passes into the small branches of the veins
# [('teach', 'that', 'there')]
# Recognized words: <s> <sil> and as having been the first to teach <sil> that there are many small passages <sil> a teacher mix of the or east <sil> through which the blood <sil> perceived by them from the market <sil> passes into small branches of the things </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/311/311-124404-0069_1.wav' from 2090ms to 2250ms.
# of the same matter with that i had described and at first placed in it no rational soul nor any other principle in room of the vegetative or sensitive soul beyond kindling in the heart one of those fires without light
# [('with', 'that', 'i')]
# Recognized words: <s> of the same <sil> matter <sil> with that <sil> i had to scroll it <sil> at first place <sil> it no rational soul <sil> nor <sil> any other principal <sil> in a room of the vegetative <sil> were sensitive soul <sil> be on the kindling in the heart [NOISE] <sil> one of those fires without like </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/311/311-124404-0036_1.wav' from 1950ms to 2290ms.
# lowly in origin but so wealthy that if birth had conferred as much on them as fortune they would have had nothing left to desire nor should i have had reason to fear trouble like that in which i find myself now
# [('wealthy', 'that', 'if'), ('like', 'that', 'in')]
# Recognized words: <s> pull your origin but so well the good of <sil> birth had confirmed as much on the misfortune <sil> they would've had nothing left to desire [NOISE] nor should i have had reason to fear trouble like that in which i find myself know </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/201/201-127786-0021_1.wav' from 9900ms to 10210ms.
# there are other inns that thou knowest yet hereabouts
# [('inns', 'that', 'thou')]
# Recognized words: <s> there are other areas look on your stretcher about </s>
# The word 'that' was not found in the audio C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/cleaned/201/122255/201-122255-0044.wav
# hast thou had enough asked the tanner grimly holding his staff aloft ay marry and more than enough and thou dost own that i am the better man of the two yea truly and a murrain seize thee
# [('own', 'that', 'i')]
# Recognized words: <s> has gotten off <sil> as the tenor grueling holding his staff aloft <sil> ah i'm marianne more than enough <sil> <sil> and all pasta <sil> iowa better man of the two <sil> yeah age really <sil> an outdoor rink sees be </s>
# The word 'that' was not found in the audio C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/cleaned/201/122255/201-122255-0035.wav
# on all the bodies that are upon the earth since they are either colored or transparent or luminous and finally on man since he is the spectator of these objects
# [('bodies', 'that', 'are')]
# Recognized words: <s> on all the bodies that are <sil> on the earth <sil> since they are either colored <sil> or transparent <sil> or limits <sil> and fondly <sil> on man <sil> says he is the spectator of these objects </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/311/311-124404-0009_1.wav' from 1130ms to 1290ms.
# but since i had not as yet sufficient knowledge to enable me to treat of these in the same manner as of the rest that is to say by deducing effects from their causes and by showing
# [('rest', 'that', 'is')]
# Recognized words: <s> [NOISE] but since i had not as yet sufficient knowledge <sil> to win it'll be to treat of these in the same manner <sil> as the rest <sil> that is to say [NOISE] bye to dc effects from their causes <sil> and by showing </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/311/311-124404-0034_1.wav' from 7660ms to 7860ms.
# for i even expressly supposed that it possessed none of those forms or qualities which are so debated in the schools nor in general anything the knowledge of which is not so natural to our minds
# [('supposed', 'that', 'it')]
# Recognized words: <s> right even expressly supposed <sil> did possessed none of those forms are qualities <sil> which were so did they did the schools <sil> door general <sil> anything <sil> knowledge of which <sil> is not so natural to our minds </s>
# The word 'that' was not found in the audio C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/cleaned/311/124404/311-124404-0015.wav
# as the other things of which i had spoken but that it must be expressly created and that it is not sufficient that it be lodged in the human body exactly like a pilot in a ship unless perhaps to move its members
# [('but', 'that', 'it'), ('and', 'that', 'it'), ('sufficient', 'that', 'it')]
# Recognized words: <s> as the other things which i had spoken <sil> with that must be <sil> expressed we created <sil> and that it is not sufficient <sil> to <sil> be launched in the human <sil> body exactly like a pilot the ship [NOISE] <sil> was perhaps to move its members [NOISE] </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/311/311-124404-0117_1.wav' from 5670ms to 5830ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/311/311-124404-0117_2.wav' from 5670ms to 5830ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/311/311-124404-0117_3.wav' from 5670ms to 5830ms.
# it was said too that her name was luscinda and that at the betrothal some strange things had happened
# [('too', 'that', 'her'), ('and', 'that', 'at')]
# Recognized words: <s> he was said to [NOISE] put her name was descended [NOISE] and that <sil> at the bit troublesome strange things that happened </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/201/201-127786-0064_1.wav' from 3500ms to 3870ms.
# for marriages so unequal never brought happiness nor did they continue long to afford the enjoyment they began with all this that i have now repeated i said to him and much more which i cannot recollect but it had no effect in inducing him to forego his purpose
# [('this', 'that', 'i')]
# Recognized words: <s> four marriages so unequal never brought happiness <sil> nor did they continue long tool for the enjoyment they began <sil> all this that i have now repeated i sent him [NOISE] that much more which i can not recollect [NOISE] but it had no effect in inducing him to forgo his purpose </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/201/201-127786-0050_1.wav' from 7210ms to 7540ms.
# consists in thinking functions in which the animals void of reason may be said wholly to resemble us but among which i could not discover any of those that as dependent on thought alone belong to us as men
# [('those', 'that', 'as')]
# Recognized words: <s> consistently key <sil> functions which the animals void of recent [NOISE] <sil> babysit holy to resemblance <sil> but <sil> <sil> i'm on which <sil> i could not discovered <sil> any of those that <sil> as dependent on thought long and <sil> belong to us as men </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/311/311-124404-0039_1.wav' from 10410ms to 10760ms.
# of the two vessels from which they flow and thus prevent any more blood from coming down into the heart and becoming more and more rarefied they push open the six small valves that are in the orifices of the other two vessels through which they pass out
# [('valves', 'that', 'are')]
# Recognized words: <s> of <sil> the two vessels from which the flow <sil> and those present any more blood from coming down to the heart <sil> and becoming more <sil> and more rarefied [NOISE] they push open the six small files [NOISE] that are in it or faces of the <sil> other two vessels [NOISE] to which they pass up [NOISE] </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/311/311-124404-0060_1.wav' from 11310ms to 11450ms.
# but they must add with whom i had fled and that one so much beneath me and so unworthy of my consideration the instant i heard the notice i quitted the city with my servant who now began to show signs of wavering in his fidelity to me and the same night for fear of discovery
# [('and', 'that', 'one')]
# Recognized words: <s> [NOISE] but there was and with whom i had fled [NOISE] and that one's a much beneath me and so on worthy of my consideration <sil> [NOISE] pizza by her the notice like we did the city with my servant [NOISE] who now begin to show signs of we bring in its fidelity to me [NOISE] <sil> and the same night [NOISE] for fear of discovery </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/201/201-127786-0077_1.wav' from 2490ms to 2640ms.
# which is in the body may flow out of it in a very short time through a single artery that has been cut
# [('artery', 'that', 'has')]
# Recognized words: <s> which is in the body may flow out of it <sil> in a very short time through single or three that has been cut </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/311/311-124404-0075_1.wav' from 4060ms to 4180ms.
# for it may be that my ill fortune came of theirs in not having been nobly born it is true they are not so low that they have any reason to be ashamed of their condition
# [('be', 'that', 'my'), ('low', 'that', 'they')]
# Recognized words: <s> for it maybe that my ill fortune chemo there isn't that having been no we board <sil> it is true [NOISE] <sil> they are not so low they have any reason to be ashamed of their condition </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/201/201-127786-0022_1.wav' from 960ms to 1100ms.
# and this i say lest you should suppose that any but my lawful husband shall ever win anything of me if that
# [('suppose', 'that', 'any')]
# Recognized words: <s> and decisive lest you should says polls that <sil> any but my lawful has been shot ever wing anything to <sil> me <sil> if that </s>
# The word 'that' was not found in the audio C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/cleaned/201/127786/201-127786-0043.wav
# and begged him if he knew anything concerning her to tell it to her at once for if fortune had left her any blessing it was courage to bear whatever calamity might fall upon her as she felt sure that none could reach her capable of increasing in any degree what she endured already
# [('sure', 'that', 'none')]
# Recognized words: <s> and begin <sil> if he knew anything concerning her to tell it to work once [NOISE] for fortune had left during a blessing it was courage to bear would ever calamity might fall on her [NOISE] as she felt sure that no one could be church capable of increasing any degree which indoor already </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/201/201-127786-0047_1.wav' from 10600ms to 10810ms.
# muscles nerves arteries veins and other parts that are found in the body of each animal such persons will look upon this body as a machine made by the hands of god which is incomparably better arranged
# [('parts', 'that', 'are')]
# Recognized words: <s> muscles nerves <sil> are retains and other parts that are shattered the body <sil> of the channel <sil> such persons will look up on the spot as machine made <sil> by the hands of god [NOISE] <sil> which is <sil> you compare obligatory each </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/311/311-124404-0100_1.wav' from 2660ms to 2800ms.
# ascending in great abundance from the heart to the brain thence penetrates through the nerves into the muscles and gives motion to all the members so that to account for other parts of the blood which as most agitated and penetrating
# [('so', 'that', 'to')]
# Recognized words: <s> <sil> the sunday <sil> in korea but it's from the heart <sil> the brain [NOISE] that <sil> penetrates through the years <sil> into the muscles [NOISE] to give motions <sil> all <sil> the members <sil> show that to return for <sil> other parts of the blood which [NOISE] <sil> has most educated and an intriguing </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/311/311-124404-0090_1.wav' from 9820ms to 10060ms.
# true reasons from mere verisimilitudes should venture without examination to deny what has been said i wish it to be considered that the motion which i have now explained follows as necessarily
# [('considered', 'that', 'the')]
# Recognized words: <s> true recent <sil> from <sil> your <sil> your stability used <sil> should venture and <sil> <sil> <sil> was that examination <sil> to deny [NOISE] what has been said by which it to be considered <sil> the promotion <sil> which i have no exploiting that follows <sil> as necessarily </s>
# The word 'that' was not found in the audio C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/cleaned/311/124404/311-124404-0066.wav
# and could surpass us in all things on the contrary it rather proves that they are destitute of reason and that it is nature which acts in them according to the disposition of their organs thus it is seen that a clock composed only of wheels and weights
# [('proves', 'that', 'they'), ('and', 'that', 'it'), ('seen', 'that', 'a')]
# Recognized words: <s> it could surpass us [NOISE] in all things <sil> on the contrary [NOISE] it rather proves appeared destitute reason [NOISE] <sil> and that <sil> is nature which <sil> acts in them according to the disposition of their organs <sil> thus it is seen [NOISE] the clock compose only of wheels and weights </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/311/311-124404-0115_1.wav' from 6800ms to 7080ms.
# he laid aside the entreaties which he had employed at first and began to use violence but just heaven that seldom fails to watch over and aid good intentions so aided mine that with my slight strength and with little exertion
# [('heaven', 'that', 'seldom'), ('mine', 'that', 'with')]
# Recognized words: <s> <sil> he lay beside the and treaties <sil> which he is employed at first [NOISE] and began to use violence <sil> but <sil> just haven't [NOISE] but seldom fails to watch over any good intentions so we did mine that with my sleep strengthen the <sil> little exertion </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/201/201-127786-0078_1.wav' from 10970ms to 11110ms.
# that springing from the dewy grass hung aloft on quivering wings in the yellow sunlight pouring forth its song that fell like a falling star from the sky his luck led him away from the highway not far from the spot where arthur a bland was peeping this way and that through the leaves of the thickets
# [('song', 'that', 'fell'), ('and', 'that', 'through')]
# Recognized words: <s> that springing from the dewy grass ho loft on a quivering wings in the yellow some like pouring forth it's all a <sil> bell like falling star from the sky [NOISE] <sil> is look let him away from the highway [NOISE] not far from the spot where order of bland was puking this way and that through the leaves of the tickets </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/201/201-122255-0014_1.wav' from 13670ms to 13910ms.
# there is none that is more powerful in leading feeble minds astray from the straight path of virtue
# [('none', 'that', 'is')]
# Recognized words: <s> there's no that is more powerful <sil> in <sil> the <sil> feeble minds straight [NOISE] history <sil> has the virtue [NOISE] </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/311/311-124404-0119_1.wav' from 830ms to 980ms.
# but prevent its reflux nor do we need to seek any other reason for the number of these pellicles beyond this that the orifice of the venous artery being of an oval shape from the nature of its situation can be adequately closed with two
# [('this', 'that', 'the')]
# Recognized words: <s> but percent to three fourths <sil> nor do we need to seek <sil> any other reason for the numbers the spell it kills <sil> the on this <sil> that the orpheus of the famous art repeat of an oval shape from the nature that situation [NOISE] can be adequately close to us too </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/311/311-124404-0052_1.wav' from 8010ms to 8190ms.
# as this is not luscinda it is no human creature but a divine being the youth then took off the montera and shaking his head from side to side there broke loose and spread out a mass of hair that the beams of the sun might have envied
# [('hair', 'that', 'the')]
# Recognized words: <s> as the city's not <sil> assume that [NOISE] he's no human creature but the bombing being <sil> the youth <sil> then took off from ontario [NOISE] and shaking his head from side to side they're broke loose and spread out <sil> a massive hear about the beams of the song mature indeed </s>
# The word 'that' was not found in the audio C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/cleaned/201/127786/201-127786-0006.wav
# and which i thought was not different from the heat in hay that has been heaped together before it is dry or that which causes fermentation in new wines before they are run clear of the fruit for when i examined the kind of functions which might
# [('hay', 'that', 'has'), ('or', 'that', 'which')]
# Recognized words: <s> [NOISE] in which i thought was not different from the seat <sil> in heat it has been huge together before destroyed <sil> <sil> or that which causes fermentation in new ones before they are pro nuclear <sil> of the frick <sil> fort i examined the kind of functions which might </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/311/311-124404-0037_1.wav' from 6790ms to 7040ms.
# by this they knew that what had seemed a peasant was a lovely woman nay the most beautiful the eyes of two of them had ever beheld or even cardenio's if they had not seen and known luscinda
# [('knew', 'that', 'what')]
# Recognized words: <s> by this they knew that what had seemed a peasant was <sil> lovely woman <sil> made the most beautiful the eyes of two of them had ever been held <sil> or even garden males if they had not seen an illness and ah </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/201/201-127786-0007_1.wav' from 1100ms to 1310ms.
# indulging in faint and distant hopes of cherishing that life that i now abhor but while i was in the city uncertain what to do as i could not find don fernando i heard notice given by the public crier offering a great reward to anyone who should find me
# [('cherishing', 'that', 'life'), ('life', 'that', 'i')]
# Recognized words: <s> indulging in <sil> the dentist in hopes of cherishing not like <sil> that right now before <sil> but [SPEECH] while i was in the city on certain what to do as i could not find on fernando <sil> i heard notice given by the public are offering a great reward to anyone who should find me </s>
# The word 'that' was not found in the audio C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/cleaned/201/127786/201-127786-0075.wav
# who was indeed the one who had admitted him gained the street before daybreak but on taking leave of me he told me though not with as much earnestness and fervour as when he came that i might rest assured of his faith and of the sanctity and sincerity of his oaths
# [('came', 'that', 'i')]
# Recognized words: <s> who was indeed the one who would admit it to him <sil> again the street before daybreak <sil> but <sil> on taking a leap of me he told me [NOISE] <sil> though <sil> not with as much earnest us and for as when he came <sil> by my trusty short of his faith [NOISE] and of the sanctity <sil> and sincerity of his oath </s>
# The word 'that' was not found in the audio C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/cleaned/201/127786/201-127786-0057.wav
# i have ever remained firm in my original resolution to suppose no other principle than that of which i have recently availed myself in demonstrating the existence of god and of the soul
# [('than', 'that', 'of')]
# Recognized words: <s> <sil> i have ever read her <sil> in my original resolution <sil> to suppose know was a principal <sil> and that of which i have recently <sil> unveiled <sil> myself [NOISE] to demonstrate the existence of god [NOISE] and of the school </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/311/311-124404-0002_1.wav' from 5940ms to 6160ms.
# after an effort to restrain some tears that came to her eyes in a clear and steady voice began her story thus
# [('tears', 'that', 'came')]
# Recognized words: <s> after never to restrain some tears making her eyes and clearance that the boys [NOISE] began her story thoughts </s>
# The word 'that' was not found in the audio C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/cleaned/201/127786/201-127786-0020.wav
# and essayed to represent it in such a manner that to my mind there can be nothing clearer and more intelligible except what has been recently said regarding god and the soul
# [('manner', 'that', 'to')]
# Recognized words: <s> and <sil> see each represented <sil> in such an added that to my mind that there can be nothing clearer <sil> and more <sil> intelligible [NOISE] <sil> except <sil> what has been recently said regarding guard and soul </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/311/311-124404-0014_1.wav' from 2640ms to 2870ms.
# when it is considered that it is distilled by passing and repassing through the heart perhaps more than one or two hundred times in a day
# [('considered', 'that', 'it')]
# Recognized words: <s> would <sil> it is considered [NOISE] <sil> that it is distilled bypassing <sil> and re passing through the hard <sil> perhaps more than one or two hundred times in a day <sil> </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/311/311-124404-0085_1.wav' from 1800ms to 1970ms.
# but all my care and pains were unavailing for my master made the discovery that i was not a man and harboured the same base designs as my servant
# [('discovery', 'that', 'i')]
# Recognized words: <s> but <sil> all my kirin beings we're on a drilling for my master made the discovery that i was not a man [NOISE] and harbor the same base designs as my servant </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/201/201-127786-0081_1.wav' from 4290ms to 4400ms.
# on seeing this don fernando persuaded that luscinda had befooled slighted and trifled with him assailed her before she had recovered from her swoon and tried to stab her with the dagger that had been found and would have succeeded had not her parents and those who were present prevented him
# [('persuaded', 'that', 'luscinda'), ('dagger', 'that', 'had')]
# Recognized words: <s> that scene is [NOISE] dawn fernando persuaded that was in the head be fooled slightly [NOISE] and trifle with him <sil> the sale her before she recovered for swoon [NOISE] introduced ever with a dagger that and <sil> found [NOISE] and it succeeded and not her parents and those were present [NOISE] prevented him </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/201/201-127786-0069_1.wav' from 2710ms to 2880ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/201/201-127786-0069_2.wav' from 10560ms to 10740ms.
# accordingly quitting the path he went peeping this way and that through the underbrush spying now here and now there with all the wiles of a master of woodcraft and of one who had more than once donned a doublet of lincoln green
# [('and', 'that', 'through')]
# Recognized words: <s> accordingly <sil> <sil> quitting the best he went keeping this way and that through the underbrush [NOISE] spying now here in l there with paul piles of a master of witchcraft [NOISE] but of what would more than once told the public public agree </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/201/201-122255-0013_1.wav' from 3140ms to 3400ms.
# through my hands passed the accounts and returns of what was sown and reaped the oil mills the wine presses the count of the flocks and herds the beehives all in short that a rich farmer like my father has or can have i had under my care
# [('short', 'that', 'a')]
# Recognized words: <s> through my hands past the accounts and returns of all was alone and reads the oil mills the wind presses <sil> accountable <sil> law <sil> center it's [NOISE] the bee hives [NOISE] all in short the rich former like my father has work and have <sil> i had on your bike year </s>
# The word 'that' was not found in the audio C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/cleaned/201/127786/201-127786-0027.wav
# according to report had been present at the betrothal and that upon seeing her betrothed contrary to his expectation he had quitted the city in despair leaving behind him a letter declaring the wrong luscinda had done him and his intention of going where no one should ever see him again
# [('and', 'that', 'upon')]
# Recognized words: <s> according to report had been present at the patrol boat <sil> and that upon seeing her <sil> the truth contrary to the expectation <sil> he equated the city in despair <sil> leaving behind him a letter declaring the rules and the dog him <sil> and is intention of going where no one should ever see him again </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/201/201-127786-0071_1.wav' from 2910ms to 3060ms.
# quoth little john to himself what yon knave is after that he should go thus peeping and peering about i verily believe that yon scurvy varlet is no better than a thief and cometh here after our own and the good king's dun deer for
# [('after', 'that', 'he'), ('believe', 'that', 'yon')]
# Recognized words: <s> quote little jaunt to himself <sil> what's your name is after that he should go boss peeping in hearing about i barely believe that all mr be borrowed is no better than a thief <sil> and come with your after our own and the good used on gear <sil> for </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/201/201-122255-0016_1.wav' from 3090ms to 3250ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/201/201-122255-0016_2.wav' from 6670ms to 6960ms.
# that even if god had created more worlds there could have been none in which these laws were not observed thereafter i showed how the greatest part of the matter of this chaos must in accordance with these laws dispose and arrange itself in such a way
# []
# Recognized words: <s> the thing if god had created more worlds there could have been known in which these laws were not observed <sil> <sil> thereafter [NOISE] i showed how the greatest part of the matter [NOISE] <sil> of the scale smallest <sil> in accordance with the smallest <sil> disposing arrange itself in such a way </s>
# The word 'that' was not found in the audio C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/cleaned/311/124404/311-124404-0017.wav
# i came next to speak of the earth in particular and to show how even though i had expressly supposed that god had given no weight to the matter of which it is composed this should not prevent all its parts from tending exactly
# [('supposed', 'that', 'god')]
# Recognized words: <s> <sil> i came next to speak of the <sil> earth in particular <sil> [NOISE] <sil> and to show how <sil> even though i had expressed the suppose that god had given no wait <sil> to the matter <sil> of which is composed <sil> <sil> they should not present at all it's parts from attending <sil> exactly [NOISE] </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/311/311-124404-0022_1.wav' from 6760ms to 6910ms.
# are immediately rarefied and dilated by the heat they meet with in this way they cause the whole heart to expand and at the same time press home and shut the five small valves that are at the entrances
# [('valves', 'that', 'are')]
# Recognized words: <s> <sil> park immediately rarefied <sil> and dilated by the seat <sil> we met with <sil> it this way <sil> because the whole heart to expand <sil> at the same time press home and shut <sil> the five small files <sil> that are at the entrances </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/311/311-124404-0059_1.wav' from 12830ms to 12960ms.
# but also of the tales and episodes contained in it which are in a measure no less pleasing ingenious and truthful than the history itself which resuming its thread carded spun and wound relates that just as the curate was going to offer consolation to cardenio
# [('relates', 'that', 'just')]
# Recognized words: <s> also the tales of episodes continued which are [NOISE] in a measure no less pleasing ingenious and truthful <sil> than history itself [NOISE] which resuming it's the red [NOISE] card it's <sil> on n y entre plates that just as the jury was going to offer a consolation to carbon arrow </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/201/201-127786-0001_1.wav' from 10430ms to 10660ms.
# matter sufficient to compose one and were to agitate variously and confusedly the different parts of this matter so that there resulted a chaos as disordered as the poets ever feigned
# [('so', 'that', 'there')]
# Recognized words: <s> matter sufficient to compose <sil> on <sil> and it were to educate <sil> very sweet and confused with [NOISE] the different parts of this matter <sil> so that their purse all to chaos <sil> as disordered as the poets ever think </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/311/311-124404-0012_1.wav' from 8020ms to 8250ms.
# and that in children who cannot use them while in the womb
# [('and', 'that', 'in')]
# Recognized words: <s> and then children who cannot use them <sil> will do will need </s>
# The word 'that' was not found in the audio C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/cleaned/311/124404/311-124404-0084.wav
# i fear me though there is but poor chance of my seeing such a pleasant sight so saying he stretched himself at length upon the ground that he might not only see the sport the better but that he might enjoy the merry sight at his ease
# [('ground', 'that', 'he'), ('but', 'that', 'he')]
# Recognized words: <s> i fear me though there is but portraits of my seeing such a pleasant sight <sil> so say <sil> stretched itself up like up on the ground that he would <sil> always see the sport the better but that he might enjoy the mary site as disease </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/201/201-122255-0031_1.wav' from 7940ms to 8060ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/201/201-122255-0031_2.wav' from 7940ms to 8060ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/201/201-122255-0031_3.wav' from 10210ms to 10360ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/201/201-122255-0031_4.wav' from 10210ms to 10360ms.
# our thoughts to others for we may easily conceive a machine to be so constructed that it emits vocables and even that it emits some correspondent to the action upon it of external objects which cause a change in its organs
# [('constructed', 'that', 'it'), ('even', 'that', 'it')]
# Recognized words: <s> our thoughts dollars <sil> <sil> for we be easily can see the machine to be so constructed [NOISE] that it it's the vocals [NOISE] and even <sil> that it it's <sil> some correspondence <sil> to the action <sil> on it [NOISE] <sil> of external <sil> objects which cause a change its organs </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/311/311-124404-0103_1.wav' from 5520ms to 5790ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/311/311-124404-0103_2.wav' from 5520ms to 5790ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/311/311-124404-0103_3.wav' from 7870ms to 8180ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/311/311-124404-0103_4.wav' from 7870ms to 8180ms.
# i feel bound to tell what i would willingly keep secret if i could all this she who was now seen to be a lovely woman delivered without any hesitation with so much ease and in so sweet a voice that they were not less charmed by her intelligence than by her beauty
# [('voice', 'that', 'they')]
# Recognized words: <s> if you're bound to tell <sil> [SPEECH] what i would willingly keep secret if i could <sil> all this she who was now seem to be a lovely woman <sil> delivered without any hesitation <sil> with so much <sil> he isn't in so sweet of voice that they were not <sil> less charmed by her intelligence them by her beauty </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/201/201-127786-0018_1.wav' from 11710ms to 11860ms.
# i remember too how my maid heard those words in reproof of her audacity that she had not heard before and how i was forced to put a constraint on my tears and on the expression of my countenance not to give my parents cause to ask me why i was so melancholy
# [('audacity', 'that', 'she')]
# Recognized words: <s> i remember two <sil> probably made heard those words in her proof of her audacity to <sil> that she had not heard before [NOISE] and how i was forced to put a constraint on mike years [NOISE] and on the expression of my continents <sil> not to get my parents cause stress me <sil> why i was so melancholy </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/201/201-127786-0062_1.wav' from 4420ms to 4580ms.
# that there are no men so dull and stupid not even idiots as to be incapable of joining together different words and thereby constructing a declaration by which to make their thoughts understood
# []
# Recognized words: <s> but there are no men so goal and stupid but even if he gets <sil> us to be incapable of joined together different words [NOISE] and there by constructing a declaration [NOISE] <sil> by which to make their slots understood </s>
# The word 'that' was not found in the audio C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/cleaned/311/124404/311-124404-0107.wav
# is the true cause of the motion of the blood thus in the first place the difference that is observed between the blood which flows from the veins and that from the arteries can only arise from this
# [('difference', 'that', 'is'), ('and', 'that', 'from')]
# Recognized words: <s> used the true cause of the motion of the <sil> blood <sil> <sil> those <sil> in the first place <sil> the difference <sil> that is observed between the blood <sil> which flows <sil> from the things [NOISE] that <sil> are raised [NOISE] <sil> can only rise up from this </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/311/311-124404-0077_1.wav' from 6090ms to 6300ms.
# and all the different qualities of these heavens and stars so that i thought i had said enough respecting them to show that there is nothing observable in the heavens or stars of our system that must not or at least may not appear precisely alike in those of the system which i described
# [('so', 'that', 'i'), ('show', 'that', 'there'), ('system', 'that', 'must')]
# Recognized words: <s> and all the different qualities of the citizens of storage <sil> <sil> <sil> so that i thought <sil> i had said in the first putting them <sil> to show that there's nothing observable in the heavens wish bars or system <sil> that must not <sil> <sil> or at least <sil> may not [NOISE] <sil> appear precisely like <sil> in those of us to <sil> which i described <sil> </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/311/311-124404-0021_1.wav' from 3450ms to 3630ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/311/311-124404-0021_2.wav' from 6140ms to 6340ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/311/311-124404-0021_3.wav' from 9520ms to 9790ms.
# the opening very tight for it is manifest that the tie moderately straightened while adequate to hinder the blood already in the arm from returning towards the heart by the veins cannot on that account prevent new blood
# [('manifest', 'that', 'the'), ('on', 'that', 'account')]
# Recognized words: <s> the opening <sil> <sil> very tight <sil> <sil> <sil> for his manifesto to tell in poverty stricken <sil> well <sil> equipped into the blood already in the or <sil> from turning towards the heart of the fleet [NOISE] <sil> cannot on that account could you blood </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/311/311-124404-0072_1.wav' from 12600ms to 12760ms.
# fearing lest i should not be able to compense in my discourse all that was in my mind i resolved to expound singly though at considerable length my opinions regarding light then
# [('all', 'that', 'was')]
# Recognized words: <s> <sil> the request i should not be able to come pants <sil> in my discourse <sil> all that was in my mind <sil> <sil> i resolve to spam singly [NOISE] the wet considerable length [NOISE] <sil> my opinion regarding the white <sil> <sil> then </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/311/311-124404-0007_1.wav' from 4860ms to 5070ms.
# revived my hopes and i was better pleased not to have found don fernando than to find him married for it seemed to me that the door was not yet entirely shut upon relief in my case and i thought that perhaps heaven had put this impediment in the way of the second marriage
# [('me', 'that', 'the'), ('thought', 'that', 'perhaps')]
# Recognized words: <s> provide my hopes and i was better please not a found on fernando going to find a married for [NOISE] it seemed to me that the door was not yet and her we shut up on relief in my case that i thought that perhaps [NOISE] haven't had put this in <sil> the <sil> [SPEECH] in the way of the second marriage </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/201/201-127786-0073_1.wav' from 5930ms to 6060ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/201/201-127786-0073_2.wav' from 10180ms to 10370ms.
# be the only scruple you feel fairest dorothea for that is the name of this unhappy being see here i give you my hand to be yours and let heaven
# [('for', 'that', 'is')]
# Recognized words: <s> be the <sil> only scribble you feel for restore via <sil> <sil> for that <sil> is the name of this <sil> i'm happy being <sil> see your id be my hand to be yours i'm like heaven </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/201/201-127786-0044_1.wav' from 3210ms to 3490ms.
# so that its course amounts precisely to a perpetual circulation of this we have abundant proof in the ordinary experience of surgeons who by binding the arm with a tie of moderate straitness above the part where they open the vein
# [('so', 'that', 'its')]
# Recognized words: <s> so that its course and precisely to a <sil> perpetual circulation <sil> of these <sil> we have abundant proof <sil> in the ordinary experienced surgeons <sil> who <sil> by pointing the arm <sil> was the type of moderates treatments <sil> above the part <sil> where the open the plane [NOISE] </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/311/311-124404-0070_1.wav' from 410ms to 550ms.
# can number the hours and measure time more exactly than we with all our skin i had after this described the reasonable soul and shown that it could by no means be educed from the power of matter
# [('shown', 'that', 'it')]
# Recognized words: <s> never the hours [NOISE] and leisure time more exactly <sil> that we <sil> was all are skewed but <sil> <sil> <sil> <sil> ali had after this described as a reasonable salt been shown [NOISE] <sil> that it could by no means a deep you strum the power of matter </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/311/311-124404-0116_1.wav' from 12040ms to 12200ms.
# at the thought that perhaps his trusty right hand man was in some danger of his life so cautiously
# [('thought', 'that', 'perhaps')]
# Recognized words: <s> but all that perhaps his trusty right hand man was in some danger of his life [NOISE] so cautiously </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/201/201-122255-0029_1.wav' from 560ms to 750ms.
# and if attention be given it will be found that this difference is very marked only in the neighborhood of the heart
# [('found', 'that', 'this')]
# Recognized words: <s> it's attention be given <sil> it will be found that this difference does free market [NOISE] <sil> only in the neighborhood of the heart </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/311/311-124404-0079_1.wav' from 2580ms to 2760ms.
# which arranged in a manner exactly the opposite of the former readily permit the blood contained in this cavity to pass into the lungs but hinder that contained in the lungs from returning to this cavity and in like manner
# [('hinder', 'that', 'contained')]
# Recognized words: <s> which <sil> range in that reads actually the opposite of the former <sil> readily permits the blood contained <sil> in this cavity <sil> to pass into the ones <sil> that hinder that contained in law is <sil> from returning to this cavity [NOISE] <sil> and [NOISE] it'll like manner [NOISE] </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/311/311-124404-0050_1.wav' from 9060ms to 9270ms.
# and as the saying is old rusty christians but so rich that by their wealth and free handed way of life they are coming by degrees to be considered gentlefolk by birth and even by position
# [('rich', 'that', 'by')]
# Recognized words: <s> and as the saying is <sil> old rusty crichton stearns [NOISE] but so rich that by their wealth and free handed way of life they're coming by degrees to be considered gentle folks by birth [NOISE] <sil> and <sil> even by position </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/201/201-127786-0024_1.wav' from 4760ms to 4910ms.
# so that even although he had from the beginning given it no other form than that of chaos provided only he had established certain laws of nature and had lent it his concurrence to enable it to act as it is wont to do
# [('so', 'that', 'even'), ('than', 'that', 'of')]
# Recognized words: <s> [NOISE] so that the <sil> also <sil> he had from the b t be <sil> getting it <sil> no other for <sil> <sil> the vat of chaos <sil> provided only she had establish certain laws of nature [NOISE] <sil> and have blunted he's <sil> encouraged to enable it to act [NOISE] as it is what to do </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/311/311-124404-0031_1.wav' from 550ms to 710ms.
# and rectitude alone and bade me consider the disparity between don fernando and myself from which i might conclude that his intentions whatever he might say to the contrary had for their aim his own pleasure rather than my advantage
# [('conclude', 'that', 'his')]
# Recognized words: <s> and wrecked alone [NOISE] and beat me consider the disparity between don fernando and myself [NOISE] for which i might conclude that his intentions [NOISE] when every might say to the contrary [NOISE] had for their aim his own pleasure rather than my advantage </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/201/201-127786-0034_1.wav' from 6480ms to 6630ms.
# across the tanner's shoulders was slung his stout quarterstaff ever near enough to him to be gripped quickly and on his head was a cap of doubled cowhide so tough that it could hardly be cloven even by a broadsword now quoth arthur a bland to himself
# [('tough', 'that', 'it')]
# Recognized words: <s> across the tenor shoulders was long list of course that <sil> never hear about him to be gripped quickly <sil> and on his head was a cap of double kill hive so tough that it could hardly be called money and buy a broad sword <sil> know <sil> who <sil> are through [SPEECH] the bad to itself </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/201/201-122255-0011_1.wav' from 8240ms to 8390ms.
# in the most direct lines and that according to the rules of mechanics which are the same with those of nature when many objects tend at once to the same point
# [('and', 'that', 'according')]
# Recognized words: <s> in the most direct lights and that <sil> according to the rules of mechanics <sil> which are the same with those of nature [NOISE] <sil> what many objects to end at once <sil> same point <sil> </s>
# ...
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/311/311-124404-0005_2.wav' from 10030ms to 10170ms.
# it thence happens that their motion is the contrary of that of the heart and that when it expands they contract but lest those who are ignorant of the force of mathematical demonstrations and who are not accustomed to distinguish
# [('happens', 'that', 'their'), ('of', 'that', 'of'), ('and', 'that', 'when')]
# Recognized words: <s> events <sil> happens is that their motion <sil> is the contrary to that of the heart [NOISE] that when it expands as a contract <sil> will bless those who are ignorant of the force <sil> of mathematical demonstrations <sil> and we're not accustomed to distinguish </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/311/311-124404-0065_1.wav' from 1810ms to 1960ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/311/311-124404-0065_2.wav' from 3780ms to 4080ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/311/311-124404-0065_3.wav' from 5020ms to 5290ms.
# an affair of such notoriety in the city that it was the talk of every knot of idlers in the street he said that on the night of don fernando's betrothal with luscinda as soon as she had consented to be his bride by saying yes she was taken with a sudden fainting fit
# [('city', 'that', 'it'), ('said', 'that', 'on')]
# Recognized words: <s> the fear of such notoriety in the city <sil> but it was the top of every not the bible isn't the street <sil> he said that on the night of don fernando the trouble with those under the sooner she consented to be used bribe eight ink yes <sil> she was taken with a sudden thinking fit </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/201/201-127786-0067_1.wav' from 5880ms to 6080ms.
# we could have no means of knowing that they were in any respect of a different nature from these animals but if there were machines bearing the image of our bodies and capable of imitating our actions as far as it is morally possible
# [('knowing', 'that', 'they')]
# Recognized words: <s> we could have no means of knowing [NOISE] that they were in any respect of the different nature from caesar levels <sil> but if they were <sil> machines bearing the image of our bodies [NOISE] <sil> are capable of in taking our <sil> actions as far as it is morally possible </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/311/311-124404-0102_1.wav' from 2310ms to 2490ms.
# from coming forward through the arteries because these are situated below the veins and their coverings from their greater consistency are more difficult to compress and also that the blood which comes from the heart tends to pass through them
# [('also', 'that', 'the')]
# Recognized words: <s> from coming forward <sil> through the arteries <sil> because these are situated the low savings <sil> and they're covering stuff <sil> from their greater consistency <sil> or more difficult to compress <sil> [NOISE] <sil> it also claims that the blood <sil> which comes from the heart <sil> tends to pass threesome </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/311/311-124404-0073_1.wav' from 11220ms to 11330ms.
# for i know my good master would not have me wet to the skin so without more ado off he strode down the path that lay the way of his likings now there was no sign of any foul weather but
# [('path', 'that', 'lay')]
# Recognized words: <s> [NOISE] for i know my good master would not have anywhere to dispute <sil> so without more ado <sil> off he strode down the path the way the way it is like it's <sil> now there was no sign of a foul weather but </s>
# The word 'that' was not found in the audio C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/cleaned/201/122255/201-122255-0004.wav
# proceeding towards the brain it is not necessary to suppose any other cause than simply that the arteries which carry them thither proceed from the heart
# [('simply', 'that', 'the')]
# Recognized words: <s> she towards the brain <sil> is not necessary to suppose any other cause <sil> that simply [NOISE] that the arteries which carried him <sil> to their [NOISE] <sil> proceed from the heart </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/311/311-124404-0091_1.wav' from 6540ms to 6700ms.
# little john trod upon a stick which snapped under his foot whereupon hearing the noise the tanner turned quickly and caught sight of the yeoman seeing that the tanner had spied him out little john put a bold face upon the matter
# [('seeing', 'that', 'the')]
# Recognized words: <s> the john trod upon the stick which stood <sil> under his foot <sil> <sil> or pot during the noise the tenor true quickly and caught sight of the old [NOISE] <sil> scene at the tender it's quite well put on put a bold the sub on the matter </s>
# The word 'that' was not found in the audio C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/cleaned/201/122255/201-122255-0018.wav
# bided at the blue boar inn until the morrow now it was an ill piece of luck for little john that he left his duty for his pleasure and he paid a great score for it as we are all apt to do in the same case as you shall see
# [('john', 'that', 'he')]
# Recognized words: <s> why did that the blue born in little more <sil> now [NOISE] it wasn't a real piece of law <sil> for little john that he left his duty for his pleasure <sil> and he be a great score for it [NOISE] as we're all out to do is sing case as usual see </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/201/201-122255-0006_1.wav' from 5860ms to 6000ms.
# cause the blood to flow more copiously than it would have done without any ligature whereas quite the contrary would happen were they to bind it below that is between the hand and the opening or were to make the ligature above
# [('below', 'that', 'is')]
# Recognized words: <s> [NOISE] cause the blood to flow <sil> more copious lee <sil> that it would have done <sil> without any of the teacher <sil> rose quite the contrary it would have been <sil> with the turbine didn't blow <sil> that is <sil> between hand [NOISE] in the opening <sil> or were to make liter [NOISE] of both </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/311/311-124404-0071_1.wav' from 10090ms to 10360ms.
# it was said moreover that don fernando went away at once and that luscinda did not recover from her prostration until the next day when she told her parents how she was really the bride of that cardenio i have mentioned i learned besides that cardenio
# [('moreover', 'that', 'don'), ('and', 'that', 'luscinda'), ('of', 'that', 'cardenio'), ('besides', 'that', 'cardenio')]
# Recognized words: <s> he was said moreover that on fernando one away wants <sil> and that was and it did not work for her frustration until the next day [NOISE] when she told her parents how she was really the bride of that carbon arrow <sil> i've mentioned <sil> <sil> i learned besides the carbon arrow </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/201/201-127786-0070_1.wav' from 1260ms to 1480ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/201/201-127786-0070_2.wav' from 3550ms to 3690ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/201/201-127786-0070_3.wav' from 9530ms to 9740ms.
# but this is certain and an opinion commonly received among theologians that the action by which he now sustains it is the same with that by which he originally created it
# [('theologians', 'that', 'the'), ('with', 'that', 'by')]
# Recognized words: <s> [NOISE] but this is certainly <sil> an opinion commonly perceived among theologians [NOISE] <sil> that the <sil> action by which he no stains it <sil> is the same [NOISE] <sil> without <sil> by which he coverage know we created it </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/311/311-124404-0030_1.wav' from 5050ms to 5220ms.
# now news had been brought to robin hood how that little john instead of doing his bidding had passed by duty for pleasure and so had stopped overnight with merry company at the blue boar inn instead of going straight to ancaster
# [('how', 'that', 'little')]
# Recognized words: <s> now news had been brought to robin hood how that little john instead of doing his bidding had passed by duty for pleasure and so it stopped over like with gary company at the blue born in instead of going straight to a caster [NOISE] </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/201/201-122255-0024_1.wav' from 2910ms to 3200ms.
# for example if touched in a particular place it may demand what we wish to say to it if in another it may cry out that it is hurt and such like
# [('out', 'that', 'it')]
# Recognized words: <s> for example [NOISE] is touched the particular place it may depend [NOISE] what we wish to say to it <sil> is in another <sil> picnic right out <sil> that it does hurt [NOISE] and such like it </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/311/311-124404-0104_1.wav' from 8070ms to 8230ms.
# whereas the others being round are more conveniently closed with three besides i wish such persons to observe that the grand artery and the arterial vein are of much harder and firmer texture
# [('observe', 'that', 'the')]
# Recognized words: <s> <sil> or is it the other speed round <sil> <sil> or more conveniently close with his three <sil> besides <sil> <sil> i wish <sil> such persons to observe <sil> that the grand ordering it into your chair real thing <sil> worth much <sil> harder and for bird catcher </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/311/311-124404-0053_1.wav' from 8700ms to 8900ms.
# nature must produce them i remained satisfied with the supposition that god formed the body of man wholly like to one of ours as well in the external shape of the members as in the internal conformation of the organs
# [('supposition', 'that', 'god')]
# Recognized words: <s> the teacher <sil> was produced <sil> by remain satisfied <sil> with the supposition that god for the body of men <sil> holding like the one forty [NOISE] <sil> well [NOISE] in the external shape <sil> of the members as in the internal confirmation [NOISE] of the organs </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/311/311-124404-0035_1.wav' from 4780ms to 5000ms.
# the situation and shape of its counterweights and wheels but if it be asked how it happens that the blood in the veins flowing in this way continually into the heart is not exhausted
# [('happens', 'that', 'the')]
# Recognized words: <s> the situation <sil> in shape <sil> of its care for weeks <sil> and weeks <sil> but <sil> it could be as <sil> hell would have been so that the blood of the things <sil> flowing in this way continually into the heart <sil> <sil> is not exhausted </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/311/311-124404-0068_1.wav' from 6750ms to 6940ms.
# i should wish also that such persons were carefully shown the eleven pellicles which like so many small valves open and shut the four orifices that are in these two cavities viz
# [('also', 'that', 'such'), ('orifices', 'that', 'are')]
# Recognized words: <s> <sil> why should we should also know <sil> that such persons look carefully shown <sil> to the eleven [NOISE] <sil> only cubes <sil> which <sil> like so many small fouls <sil> open and shut <sil> for porsche says [NOISE] <sil> that are in these two cavities [NOISE] these </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/311/311-124404-0048_1.wav' from 1840ms to 1990ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/311/311-124404-0048_2.wav' from 10510ms to 10650ms.
# that though there are many animals which manifest more industry than we in certain of their actions the same animals are yet observed to show none at all in many others so that the circumstance that they do better
# [('so', 'that', 'the'), ('circumstance', 'that', 'they')]
# Recognized words: <s> that <sil> <sil> though there are many animals which manifest more <sil> industry that week in certain of their actions <sil> same animals for yet observed sure not all <sil> in many others <sil> <sil> so that the circumstance that they do better and </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/311/311-124404-0114_1.wav' from 11110ms to 11270ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/311/311-124404-0114_2.wav' from 12130ms to 12300ms.
# but that it is necessary for it to be joined and united more closely to the body in order to have sensations and appetites similar to ours and thus constitute a real man
# [('but', 'that', 'it')]
# Recognized words: <s> that is necessary for it to be joined <sil> united more closely to the body <sil> nor to have [NOISE] sensations and appetites <sil> similar to ours [NOISE] and us <sil> cause to tutor real men </s>
# The word 'that' was not found in the audio C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/cleaned/311/124404/311-124404-0118.wav
# and that on the bridegroom approaching to unlace the bosom of her dress to give her air
# [('and', 'that', 'on')]
# Recognized words: <s> and that <sil> on the bridegroom approaching two on least the bosom of her dress to give her hair </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/201/201-127786-0068_1.wav' from 480ms to 800ms.
# should not in this be equal to the most stupid infant of its kind or at least to one that was crack brained unless the soul of brutes
# [('one', 'that', 'was')]
# Recognized words: <s> should not <sil> in this be equals a little stupid in to that kind [NOISE] <sil> or <sil> use the one that was <sil> correct bring back almost sold <sil> for its </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/311/311-124404-0111_1.wav' from 4970ms to 5130ms.
# which flow forth from the left cavity of the heart and tend towards the brain the weaker and less agitated parts must necessarily be driven aside from that point by the stronger which alone in this way reach it
# [('from', 'that', 'point')]
# Recognized words: <s> which flow for us law is cathy of the heart [NOISE] beat and forced to bring <sil> the weaker and less educated parts must necessarily be driven it's like from that point [NOISE] the stronger <sil> which alone in this way [NOISE] reach it </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/311/311-124404-0093_1.wav' from 8600ms to 8840ms.

# %% [markdown]
# ### Tests
