# %%
import os
from pocketsphinx import AudioFile, get_model_path, Decoder
from pydub import AudioSegment
from collections import defaultdict

# %%
def extract_word_audio(input_wav, output_wav, target_word="that", extra_time=10):
    # Set up paths for the models
    model_path = get_model_path()
    
    # Create a list to hold the start and end times of the target word
    word_times = []

    # Create a decoder with the appropriate configuration
    config = {
        'verbose': False,
        'hmm': os.path.join(model_path, 'en-us'),  # Path to the acoustic model
        'lm': os.path.join(model_path, 'en-us.lm.bin'),  # Path to the language model
        'dict': os.path.join(model_path, 'cmudict-en-us.dict'),  # Path to the dictionary
        'frate': 100,
        'samprate': 16000
    }
    
    # Initialize the decoder
    decoder = Decoder(config)

    # Start decoding the audio file
    decoder.start_utt()
    
    # Read the audio file in binary mode and process it
    with open(input_wav, 'rb') as audio_file:
        while True:
            buf = audio_file.read(1024)
            if not buf:
                break
            decoder.process_raw(buf, False, False)

    decoder.end_utt()

    # Check for the target word in the recognized segments
    # recognized_words = []
    # for seg in decoder.seg():
    #     word = seg.word.split('(')[0]  # Get the word before the hypothesis index
    #     recognized_words.append(word)  # Collect all recognized words
    #     # Check if the segment matches the target word
    #     if word.lower() == target_word.lower():
    #         # Append start and end times (in milliseconds)
    #         start_time = int(seg.start_frame * (1000 / 100))  # Assuming 100 frames per second
    #         end_time = int(seg.end_frame * (1000 / 100))      # Adjust frame rate if necessary
    #         # Adjust start and end times for extra recording
    #         adjusted_start = max(0, start_time - extra_time)  # One second before
    #         adjusted_end = end_time + extra_time               # One second after
    #         word_times.append((adjusted_start, adjusted_end))
    
    recognized_words = []
    seg_list = [seg for seg in decoder.seg()]
    for index, seg in enumerate(seg_list):
        
        word = seg.word.split('(')[0]  # Get the word before the hypothesis index
        
        recognized_words.append(word)  # Collect all recognized words
        if word.lower() == target_word.lower():
            # Append start and end times (in milliseconds)
            start_time = int(seg_list[index-1].end_frame * (1000 / 100))  # Assuming 100 frames per second
            end_time = int(seg_list[index+1].start_frame * (1000 / 100))
            adjusted_start = max(0, start_time - extra_time)  # One second before
            adjusted_end = end_time + extra_time
            word_times.append((adjusted_start, adjusted_end))

    # Print recognized words
    print("Recognized words:", ' '.join(recognized_words))

    # Check if the word was found
    if not word_times:
        print(f"The word '{target_word}' was not found in the audio {input_wav}.")
        return

    # Load the original audio file
    original_audio = AudioSegment.from_wav(input_wav)

    # Extract segments for each occurrence of the target word
    for i, (start, end) in enumerate(word_times):
        # Ensure the start and end times are within the audio length
        start = max(0, start)
        end = min(len(original_audio), end)
        
        # Extract the audio segment
        word_audio = original_audio[start:end]
        
        # Save the extracted segment using the original sample rate
        name_without_extension = os.path.splitext(output_wav)[0]
        output_file = f"{name_without_extension}_{i + 1}.wav"
        word_audio.export(output_file, format="wav")
        print(f"Extracted '{target_word}' to '{output_file}' from {start}ms to {end}ms.")

# %%
def count_word_occurrences(file_paths):
    word_count = defaultdict(lambda: [0, set()])  # Default dictionary to hold (count, set of identifiers)
    
    # Read each file and count words
    for file_path in file_paths:
        with open(file_path, 'r', encoding='utf-8') as file:
            for line in file:
                identifier, text = line.split(' ', 1)
                words = text.split()
                
                for word in words:
                    # Normalize words to lowercase for consistent counting
                    normalized_word = word.lower()
                    word_count[normalized_word][0] += 1  # Increment word count
                    word_count[normalized_word][1].add(identifier)  # Add identifier

    # Create a sorted list from the dictionary
    sorted_word_counts = [
        (count_info[0], word, list(count_info[1])) 
        for word, count_info in word_count.items()
    ]
    sorted_word_counts.sort(key=lambda x: x[0], reverse=True)  # Sort by count (descending)

    return sorted_word_counts

def count_speaker_occurrences(identifiers):
    speaker_count = defaultdict(int)  # Default dictionary to hold counts of each speaker

    # Count occurrences of each speaker
    for identifier in identifiers:
        speaker_number = identifier.split('-')[0]  # Extract speaker number
        speaker_count[speaker_number] += 1  # Increment the count for the speaker

    # Convert to a regular dictionary for better readability
    return dict(speaker_count)

def generate_path(filename, path_prefix):
    reader, chapter, trial = filename.split('-')
    return f"{path_prefix}/{reader}/{chapter}/{reader}-{chapter}-{trial}.wav"


def word_extraction_wrapper(files_to_search, save_to_path, word, time_padding=10):
    for file in files_to_search:
        _, _, _, _, _, _, _, speaker, chapter, file_name = file.split('/')

        save_to = f"{save_to_path}/{word}_before_after/{speaker}/{file_name}"
        extract_word_audio(file, save_to, word, time_padding)

# %%
# Example usage:
# file_paths = [r'C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\LibriSpeech\train-clean-100\19\198\19-198.trans.txt', 
#               r'C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\LibriSpeech\train-clean-100\19\227\19-227.trans.txt',
#               r'C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\LibriSpeech\train-clean-100\26\495\26-495.trans.txt',
#               r'C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\LibriSpeech\train-clean-100\26\496\26-496.trans.txt']  # List of your txt files

# file_paths = [r"C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\LibriSpeech\train-clean-100\27\123349\27-123349.trans.txt",
#               r"C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\LibriSpeech\train-clean-100\27\124992\27-124992.trans.txt"]

# file_paths = [r"C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\LibriSpeech\train-clean-100\39\121914\39-121914.trans.txt",
#               r"C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\LibriSpeech\train-clean-100\39\121915\39-121915.trans.txt",
#               r"C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\LibriSpeech\train-clean-100\39\121916\39-121916.trans.txt"]

# file_paths = [r"C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\LibriSpeech\train-clean-100\40\222\40-222.trans.txt",
#               r"C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\LibriSpeech\train-clean-100\40\121026\40-121026.trans.txt"]

# file_paths = [r"C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\LibriSpeech\train-clean-100\87\121553\87-121553.trans.txt"]

# file_paths = [r"C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\LibriSpeech\train-clean-100\201\122255\201-122255.trans.txt",
#               r"C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\LibriSpeech\train-clean-100\201\127786\201-127786.trans.txt"]

# file_paths = [r"C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\LibriSpeech\train-clean-100\311\124404\311-124404.trans.txt"]

# file_paths = [r"C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\LibriSpeech\train-clean-100\201\122255\201-122255.trans.txt",
#               r"C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\LibriSpeech\train-clean-100\201\127786\201-127786.trans.txt",
#               r"C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\LibriSpeech\train-clean-100\311\124404\311-124404.trans.txt",
#               r"C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\LibriSpeech\train-clean-100\87\121553\87-121553.trans.txt"]

# file_paths = [r"C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\LibriSpeech\train-clean-100\1069\133699\1069-133699.trans.txt",
#               r"C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\LibriSpeech\train-clean-100\1069\133709\1069-133709.trans.txt"]
file_paths = [r"C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\LibriSpeech\train-clean-100\3240\131231\3240-131231.trans.txt",
              r"C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\LibriSpeech\train-clean-100\3240\131232\3240-131232.trans.txt",
              r"C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\LibriSpeech\train-clean-100\4297\13006\4297-13006.trans.txt",
              r"C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\LibriSpeech\train-clean-100\4297\13009\4297-13009.trans.txt",
              r"C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\LibriSpeech\train-clean-100\7800\283478\7800-283478.trans.txt",
              r"C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\LibriSpeech\train-clean-100\7800\283492\7800-283492.trans.txt",
              r"C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\LibriSpeech\train-clean-100\7800\283493\7800-283493.trans.txt",]


spoken_words = count_word_occurrences(file_paths)

for word in spoken_words:
    print(word)
# Out:
# (614, 'the', ['4297-13009-0023', '4297-13009-0004', '7800-283492-0001', '4297-13006-0032', '7800-283492-0013', '3240-131231-0016', '4297-13006-0017', '7800-283478-0013', '3240-131231-0066', '7800-283493-0019', '7800-283493-0027', '3240-131232-0002', '7800-283478-0000', '4297-13009-0009', '4297-13006-0000', '4297-13009-0024', '4297-13009-0014', '7800-283492-0038', '7800-283492-0039', '7800-283478-0022', '3240-131231-0033', '3240-131231-0011', '4297-13009-0063', '4297-13009-0016', '4297-13009-0035', '3240-131231-0006', '4297-13006-0014', '4297-13009-0049', '7800-283478-0003', '3240-131231-0030', '7800-283493-0036', '7800-283493-0007', '3240-131232-0011', '3240-131231-0003', '4297-13009-0001', '7800-283493-0011', '7800-283478-0006', '4297-13009-0050', '7800-283478-0026',
# (1, 'husky', ['7800-283478-0028'])
# (1, 'wants', ['7800-283478-0028'])
# (1, 'coaxed', ['7800-283478-0028'])
# (1, 'crowd', ['7800-283478-0029'])
# (1, 'stands', ['7800-283478-0029'])
# (1, 'tune', ['7800-283478-0029'])
# (1, 'heaving', ['7800-283478-0029'])
# (1, 'baseball', ['7800-283478-0029'])
# (1, 'practice', ['7800-283478-0029'])
# (1, 'ashamed', ['7800-283478-0029'])
# (1, 'balls', ['7800-283478-0029'])
# (1, 'missed', ['7800-283478-0029'])
# (1, 'mark', ['7800-283478-0029'])
# (1, 'dodging', ['7800-283478-0030'])
# (1, "bull's", ['7800-283478-0030'])
# (1, 'circle', ['7800-283478-0030'])
# (1, 'left', ['7800-283478-0030'])
# (1, 'smash', ['7800-283478-0030'])
# (1, 'snowball', ['7800-283478-0030'])
# (1, 'sting', ['7800-283478-0030'])
# (1, 'catches', ['7800-283478-0030'])
# (1, 'keeps', ['7800-283478-0031'])
# (1, 'burning', ['7800-283478-0031'])
# (1, 'hot', ['7800-283478-0031'])
# (1, 'iron', ['7800-283478-0031'])
# (1, 'coal', ['7800-283478-0031'])
# (1, 'ammunition', ['7800-283478-0031'])
# (1, 'tackled', ['7800-283478-0031'])
# (1, "will's", ['7800-283478-0031'])
# (1, 'complained', ['7800-283478-0031'])
# (1, 'photography', ['7800-283478-0032'])
# (1, 'liable', ['7800-283478-0032'])
# (1, 'forgetting', ['7800-283478-0032'])
# (1, 'kicking', ['7800-283478-0032'])
# (1, 'yard', ['7800-283478-0032'])
# (1, 'waiting', ['7800-283478-0032'])
# (1, 'forgetful', ['7800-283478-0032'])
# (1, 'thinks', ['7800-283478-0033'])
# (1, 'heaps', ['7800-283478-0033'])
# (1, 'chum', ['7800-283478-0033'])
# (1, 'bargain', ['7800-283478-0033'])
# (1, 'hurry', ['7800-283478-0033'])
# (1, "d'ye", ['7800-283478-0034'])
# (1, 'brilliant', ['7800-283478-0034'])
# (1, 'chapter', ['7800-283492-0000'])
# (1, 'sixteen', ['7800-283492-0000'])
# (1, 'jar', ['7800-283492-0000'])
# (1, 'contained', ['7800-283492-0000'])
# (1, 'brief', ['7800-283492-0000'])
# (1, 'communication', ['7800-283492-0000'])
# (1, 'lumberman', ['7800-283492-0000'])
# (1, 'burst', ['7800-283492-0000'])
# (1, 'lumberjacks', ['7800-283492-0001'])
# (1, 'accused', ['7800-283492-0001'])
# (1, 'loggers', ['7800-283492-0001'])
# (1, 'crime', ['7800-283492-0001'])
# (1, 'projecting', ['7800-283492-0001'])
# (1, 'view', ['7800-283492-0001'])
# (1, 'wounded', ['7800-283492-0002'])
# (1, 'interest', ['7800-283492-0002'])
# (1, 'shanties', ['7800-283492-0002'])
# (1, 'winter', ['7800-283492-0002'])
# (1, 'setting', ['7800-283492-0002'])
# (1, 'grasped', ['7800-283492-0003'])
# (1, 'hints', ['7800-283492-0004'])
# (1, 'portended', ['7800-283492-0004'])
# (1, 'nasty', ['7800-283492-0004'])
# (1, 'temper', ['7800-283492-0004'])
# (1, 'tear', ['7800-283492-0004'])
# (1, 'china', ['7800-283492-0004'])
# (1, 'shop', ['7800-283492-0004'])
# (1, 'tumble', ['7800-283492-0005'])
# (1, 'cried', ['7800-283492-0005'])
# (1, 'slang', ['7800-283492-0005'])
# (1, 'unusually', ['7800-283492-0005'])
# (1, 'habit', ['7800-283492-0005'])
# (1, 'buildings', ['7800-283492-0006'])
# (1, 'disliked', ['7800-283492-0006'])
# (1, 'threaten', ['7800-283492-0007'])
# (1, 'hit', ['7800-283492-0007'])
# (1, 'wanted', ['7800-283492-0007'])
# (1, 'whoever', ['7800-283492-0008'])
# (1, 'hoot', ['7800-283492-0008'])
# (1, 'hurt', ['7800-283492-0008'])
# (1, 'disappeared', ['7800-283492-0008'])
# (1, 'alongside', ['7800-283492-0008'])
# (1, 'evidently', ['7800-283492-0009'])
# (1, 'limped', ['7800-283492-0009'])
# (1, 'chair', ['7800-283492-0009'])
# (1, 'doorway', ['7800-283492-0009'])
# (1, 'hearing', ['7800-283492-0009'])
# (1, 'voices', ['7800-283492-0009'])
# (1, 'outside', ['7800-283492-0009'])
# (1, 'news', ['7800-283492-0009'])
# (1, 'startling', ['7800-283492-0009'])
# (1, 'food', ['7800-283492-0010'])
# (1, 'walked', ['7800-283492-0010'])
# (1, 'mink', ['7800-283492-0010'])
# (1, 'coward', ['7800-283492-0013'])
# (1, 'clenching', ['7800-283492-0013'])
# (1, 'fists', ['7800-283492-0013'])
# (1, 'overhear', ['7800-283492-0014'])
# (1, 'boasting', ['7800-283492-0014'])
# (1, "you've", ['7800-283492-0015'])
# (1, 'guessing', ['7800-283492-0015'])
# (1, 'tongue', ['7800-283492-0016'])
# (1, 'shield', ['7800-283492-0016'])
# (1, 'rascal', ['7800-283492-0016'])
# (1, 'hesitate', ['7800-283492-0016'])
# (1, 'comprehension', ['7800-283492-0016'])
# (1, 'match', ['7800-283492-0017'])
# (1, 'pals', ['7800-283492-0017'])
# (1, 'agreed', ['7800-283492-0017'])
# (1, 'lit', ['7800-283492-0017'])
# (1, 'mused', ['7800-283492-0018'])
# (1, 'huh', ['7800-283492-0018'])
# (1, 'remonstrated', ['7800-283492-0018'])
# (1, 'hung', ['7800-283492-0019'])
# (1, 'losing', ['7800-283492-0019'])
# (1, 'streak', ['7800-283492-0020'])
# (1, 'ted', ['7800-283492-0020'])
# (1, 'accommodating', ['7800-283492-0021'])
# (1, 'knowledge', ['7800-283492-0021'])
# (1, 'concerned', ['7800-283492-0021'])
# (1, 'loved', ['7800-283492-0021'])
# (1, 'folk', ['7800-283492-0021'])
# (1, 'suspect', ['7800-283492-0021'])
# (1, 'presence', ['7800-283492-0021'])
# (1, 'learn', ['7800-283492-0021'])
# (1, 'habits', ['7800-283492-0021'])
# (1, 'enjoying', ['7800-283492-0022'])
# (1, 'limit', ['7800-283492-0022'])
# (1, 'showing', ['7800-283492-0022'])
# (1, 'decided', ['7800-283492-0022'])
# (1, 'walking', ['7800-283492-0022'])
# (1, 'crook', ['7800-283492-0022'])
# (1, 'nervousness', ['7800-283492-0023'])
# (1, 'following', ['7800-283492-0023'])
# (1, 'advent', ['7800-283492-0023'])
# (1, 'drudgery', ['7800-283492-0024'])
# (1, 'torture', ['7800-283492-0024'])
# (1, 'charge', ['7800-283492-0024'])
# (1, 'cooking', ['7800-283492-0024'])
# (1, 'learned', ['7800-283492-0024'])
# (1, 'manage', ['7800-283492-0024'])
# (1, 'splendidly', ['7800-283492-0024'])
# (1, 'suit', ['7800-283492-0025'])
# (1, 'regretted', ['7800-283492-0025'])
# (1, 'extended', ['7800-283492-0025'])
# (1, 'distress', ['7800-283492-0025'])
# (1, 'companions', ['7800-283492-0026'])
# (1, 'grateful', ['7800-283492-0026'])
# (1, 'possibly', ['7800-283492-0026'])
# (1, 'dastardly', ['7800-283492-0026'])
# (1, 'deed', ['7800-283492-0026'])
# (1, 'attempted', ['7800-283492-0027'])
# (1, 'logging', ['7800-283492-0027'])
# (1, 'worried', ['7800-283492-0027'])
# (1, "boy's", ['7800-283492-0027'])
# (1, 'puzzling', ['7800-283492-0027'])
# (1, 'brain', ['7800-283492-0027'])
# (1, 'reward', ['7800-283492-0028'])
# (1, 'hundred', ['7800-283492-0028'])
# (1, 'dollars', ['7800-283492-0028'])
# (1, 'noon', ['7800-283492-0028'])
# (1, 'laying', ['7800-283492-0028'])
# (1, 'firewood', ['7800-283492-0028'])
# (1, 'snowfall', ['7800-283492-0029'])
# (1, 'hours', ['7800-283492-0029'])
# (1, 'hazard', ['7800-283492-0029'])
# (1, 'handy', ['7800-283492-0029'])
# (1, 'heap', ['7800-283492-0029'])
# (1, 'dampness', ['7800-283492-0030'])
# (1, 'notice', ['7800-283492-0030'])
# (1, 'shines', ['7800-283492-0030'])
# (1, 'hazy', ['7800-283492-0030'])
# (1, 'curtain', ['7800-283492-0030'])
# (1, 'fortunately', ['7800-283492-0031'])
# (1, 'threw', ['7800-283492-0031'])
# (1, 'armful', ['7800-283492-0031'])
# (1, 'fuel', ['7800-283492-0031'])
# (1, 'huge', ['7800-283492-0031'])
# (1, 'managed', ['7800-283492-0032'])
# (1, 'tote', ['7800-283492-0032'])
# (1, 'carcass', ['7800-283492-0032'])
# (1, 'pride', ['7800-283492-0032'])
# (1, 'hanging', ['7800-283492-0032'])
# (1, 'style', ['7800-283492-0032'])
# (1, 'limb', ['7800-283492-0032'])
# (1, 'downward', ['7800-283492-0032'])
# (1, 'suppressing', ['7800-283492-0033'])
# (1, 'twinge', ['7800-283492-0033'])
# (1, 'jealousy', ['7800-283492-0033'])
# (1, 'bag', ['7800-283492-0033'])
# (1, 'wild', ['7800-283492-0033'])
# (1, 'accumulating', ['7800-283492-0033'])
# (1, 'gets', ['7800-283492-0034'])
# (1, 'railroads', ['7800-283492-0034'])
# (1, 'offering', ['7800-283492-0034'])
# (1, 'ahead', ['7800-283492-0034'])
# (1, 'discovered', ['7800-283492-0035'])
# (1, 'comical', ['7800-283492-0035'])
# (1, 'squirrels', ['7800-283492-0035'])
# (1, 'amused', ['7800-283492-0035'])
# (1, 'explained', ['7800-283492-0035'])
# (1, 'hoped', ['7800-283492-0035'])
# (1, 'mouse', ['7800-283492-0035'])
# (1, 'snap', ['7800-283492-0035'])
# (1, 'fine', ['7800-283492-0036'])
# (1, 'speaking', ['7800-283492-0036'])
# (1, 'angels', ['7800-283492-0036'])
# (1, 'wings', ['7800-283492-0036'])
# (1, 'breath', ['7800-283492-0037'])
# (1, 'excitement', ['7800-283492-0037'])
# (1, 'expressed', ['7800-283492-0037'])
# (1, 'sticking', ['7800-283492-0038'])
# (1, 'whopper', ['7800-283492-0038'])
# (1, 'gasped', ['7800-283492-0038'])
# (1, 'tre', ['7800-283492-0038'])
# (1, 'mendous', ['7800-283492-0038'])
# (1, 'involuntarily', ['7800-283492-0039'])
# (1, 'stretching', ['7800-283492-0039'])
# (1, 'wide', ['7800-283492-0039'])
# (1, 'cows', ['7800-283492-0039'])
# (1, 'antlers', ['7800-283492-0039'])
# (1, 'asserted', ['7800-283492-0039'])
# (1, 'determination', ['7800-283492-0039'])
# (1, 'shrilled', ['7800-283492-0040'])
# (1, 'echoed', ['7800-283493-0000'])
# (1, 'lighting', ['7800-283493-0000'])
# (1, 'energy', ['7800-283493-0000'])
# (1, 'longed', ['7800-283493-0001'])
# (1, 'meet', ['7800-283493-0001'])
# (1, 'camera', ['7800-283493-0001'])
# (1, 'picturing', ['7800-283493-0001'])
# (1, "he'd", ['7800-283493-0001'])
# (1, 'beaut', ['7800-283493-0001'])
# (1, 'monster', ['7800-283493-0001'])
# (1, 'related', ['7800-283493-0002'])
# (1, 'snaps', ['7800-283493-0002'])
# (1, 'funny', ['7800-283493-0002'])
# (1, 'playing', ['7800-283493-0002'])
# (1, 'hoping', ['7800-283493-0002'])
# (1, 'whack', ['7800-283493-0002'])
# (1, 'whiffing', ['7800-283493-0002'])
# (1, 'standing', ['7800-283493-0003'])
# (1, 'scared', ['7800-283493-0003'])
# (1, 'school', ['7800-283493-0004'])
# (1, 'kept', ['7800-283493-0004'])
# (1, 'nerve', ['7800-283493-0004'])
# (1, 'shoot', ['7800-283493-0004'])
# (1, 'turns', ['7800-283493-0005'])
# (1, 'pose', ['7800-283493-0005'])
# (1, 'focus', ['7800-283493-0005'])
# (1, 'roll', ['7800-283493-0005'])
# (1, 'discover', ['7800-283493-0005'])
# (1, 'labor', ['7800-283493-0005'])
# (1, 'resulted', ['7800-283493-0005'])
# (1, 'pleaded', ['7800-283493-0006'])
# (1, 'nest', ['7800-283493-0006'])
# (1, 'trunk', ['7800-283493-0006'])
# (1, 'stag', ['7800-283493-0007'])
# (1, 'indignant', ['7800-283493-0007'])
# (1, 'photographer', ['7800-283493-0007'])
# (1, 'vanished', ['7800-283493-0007'])
# (1, 'startled', ['7800-283493-0008'])
# (1, 'animal', ['7800-283493-0008'])
# (1, 'worked', ['7800-283493-0008'])
# (1, 'overtime', ['7800-283493-0008'])
# (1, 'strayed', ['7800-283493-0008'])
# (1, 'reappeared', ['7800-283493-0009'])
# (1, 'guns', ['7800-283493-0009'])
# (1, 'vows', ['7800-283493-0010'])
# (1, 'terribly', ['7800-283493-0010'])
# (1, 'boast', ['7800-283493-0010'])
# (1, 'owning', ['7800-283493-0010'])
# (1, 'favor', ['7800-283493-0011'])
# (1, 'suggested', ['7800-283493-0011'])
# (1, 'frisk', ['7800-283493-0012'])
# (1, 'sight', ['7800-283493-0012'])
# (1, 'frighten', ['7800-283493-0012'])
# (1, 'bushy', ['7800-283493-0012'])
# (1, 'tails', ['7800-283493-0012'])
# (1, 'showed', ['7800-283493-0013'])
# (1, 'dreaming', ['7800-283493-0013'])
# (1, 'pointing', ['7800-283493-0013'])
# (1, 'marks', ['7800-283493-0013'])
# (1, 'plainly', ['7800-283493-0013'])
# (1, 'inch', ['7800-283493-0013'])
# (1, 'previous', ['7800-283493-0013'])
# (1, 'forerunner', ['7800-283493-0014'])
# (1, 'stared', ['7800-283493-0014'])
# (1, 'monstrous', ['7800-283493-0014'])
# (1, 'order', ['7800-283493-0014'])
# (1, 'giant', ['7800-283493-0015'])
# (1, 'lamented', ['7800-283493-0015'])
# (1, 'step', ['7800-283493-0016'])
# (1, 'gun', ['7800-283493-0016'])
# (1, 'buckshot', ['7800-283493-0016'])
# (1, 'shell', ['7800-283493-0016'])
# (1, 'easy', ['7800-283493-0017'])
# (1, 'cruel', ['7800-283493-0017'])
# (1, 'clapped', ['7800-283493-0017'])
# (1, 'shoulder', ['7800-283493-0017'])
# (1, 'hinder', ['7800-283493-0017'])
# (1, 'couple', ['7800-283493-0017'])
# (1, 'chap', ['7800-283493-0017'])
# (1, 'eager', ['7800-283493-0017'])
# (1, 'count', ['7800-283493-0018'])
# (1, 'sprained', ['7800-283493-0018'])
# (1, 'ankle', ['7800-283493-0018'])
# (1, 'walk', ['7800-283493-0018'])
# (1, 'goes', ['7800-283493-0018'])
# (1, 'dare', ['7800-283493-0018'])
# (1, 'reply', ['7800-283493-0019'])
# (1, 'alone', ['7800-283493-0019'])
# (1, 'follow', ['7800-283493-0019'])
# (1, 'crack', ['7800-283493-0019'])
# (1, 'bring', ['7800-283493-0020'])
# (1, 'secretly', ['7800-283493-0020'])
# (1, 'chafing', ['7800-283493-0020'])
# (1, 'quarter', ['7800-283493-0021'])
# (1, 'signal', ['7800-283493-0021'])
# (1, 'eventually', ['7800-283493-0021'])
# (1, 'rushing', ['7800-283493-0022'])
# (1, 'crazy', ['7800-283493-0022'])
# (1, 'badly', ['7800-283493-0022'])
# (1, 'frightened', ['7800-283493-0022'])
# (1, 'lunch', ['7800-283493-0023'])
# (1, 'stop', ['7800-283493-0023'])
# (1, 'quickly', ['7800-283493-0023'])
# (1, 'loftily', ['7800-283493-0023'])
# (1, 'weigh', ['7800-283493-0025'])
# (1, 'thank', ['7800-283493-0025'])
# (1, 'womanish', ['7800-283493-0025'])
# (1, 'fuss', ['7800-283493-0025'])
# (1, 'wandering', ['7800-283493-0025'])
# (1, 'understood', ['7800-283493-0026'])
# (1, 'repeat', ['7800-283493-0026'])
# (1, 'experiences', ['7800-283493-0026'])
# (1, 'provided', ['7800-283493-0026'])
# (1, 'hunger', ['7800-283493-0026'])
# (1, 'bitter', ['7800-283493-0026'])
# (1, 'chanced', ['7800-283493-0027'])
# (1, 'midday', ['7800-283493-0027'])
# (1, 'working', ['7800-283493-0027'])
# (1, 'developing', ['7800-283493-0027'])
# (1, 'plenty', ['7800-283493-0027'])
# (1, 'hurrying', ['7800-283493-0028'])
# (1, 'fast', ['7800-283493-0028'])
# (1, 'redeemed', ['7800-283493-0028'])
# (1, 'shape', ['7800-283493-0028'])
# (1, 'supper', ['7800-283493-0028'])
# (1, 'delayed', ['7800-283493-0028'])
# (1, 'boxes', ['7800-283493-0029'])
# (1, 'safety', ['7800-283493-0029'])
# (1, 'coats', ['7800-283493-0029'])
# (1, 'stepping', ['7800-283493-0029'])
# (1, 'holding', ['7800-283493-0029'])
# (1, 'dripping', ['7800-283493-0029'])
# (1, 'peep', ['7800-283493-0029'])
# (1, 'vowed', ['7800-283493-0030'])
# (1, 'buck', ['7800-283493-0030'])
# (1, 'proud', ['7800-283493-0030'])
# (1, 'eating', ['7800-283493-0031'])
# (1, 'cram', ['7800-283493-0031'])
# (1, 'bite', ['7800-283493-0031'])
# (1, 'proclaimed', ['7800-283493-0031'])
# (1, 'rifle', ['7800-283493-0031'])
# (1, 'buckle', ['7800-283493-0031'])
# (1, 'webbed', ['7800-283493-0031'])
# (1, 'belt', ['7800-283493-0031'])
# (1, 'cartridges', ['7800-283493-0031'])
# (1, 'wear', ['7800-283493-0032'])
# (1, 'sweaters', ['7800-283493-0032'])
# (1, 'woolen', ['7800-283493-0032'])
# (1, 'gloves', ['7800-283493-0032'])
# (1, 'cautioned', ['7800-283493-0032'])
# (1, 'wise', ['7800-283493-0032'])
# (1, 'pair', ['7800-283493-0032'])
# (1, 'warned', ['7800-283493-0032'])
# (1, 'carelessness', ['7800-283493-0032'])
# (1, 'pushed', ['7800-283493-0032'])
# (1, 'outdoors', ['7800-283493-0032'])
# (1, 'mar', ['7800-283493-0033'])
# (1, 'holiday', ['7800-283493-0033'])
# (1, 'earnestly', ['7800-283493-0033'])
# (1, 'goodness', ['7800-283493-0033'])
# (1, 'sake', ['7800-283493-0033'])
# (1, 'worry', ['7800-283493-0033'])
# (1, 'babes', ['7800-283493-0034'])
# (1, 'eyeteeth', ['7800-283493-0034'])
# (1, 'level', ['7800-283493-0034'])
# (1, 'ourselves', ['7800-283493-0035'])
# (1, 'concluded', ['7800-283493-0035'])
# (1, 'shook', ['7800-283493-0035'])
# (1, 'gravely', ['7800-283493-0035'])
# (1, 'individual', ['7800-283493-0035'])
# (1, 'rough', ['7800-283493-0036'])
# (1, 'road', ['7800-283493-0036'])
# (1, 'everything', ['7800-283493-0036'])
# (1, 'grunted', ['7800-283493-0036'])
# (1, 'pack', ['7800-283493-0037'])
# (1, 'truck', ['7800-283493-0037'])

# %%
for word in spoken_words:
    if word[1] == "that":
        filenames = word[2]


path_prefix = "C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/cleaned"
# path_prefix = "C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/as_wav"

files_to_search = [generate_path(filename, path_prefix) for filename in filenames]

save_to_path = f"C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words"

# please note word_extraction_wrapper will save to path/{word}_uncleaned/path/file 
word_extraction_wrapper(files_to_search, save_to_path, "that")
# Out:
# Recognized words: <s> well if you ask me my opinion i'm happy to admit that i didn't like the looks of a <sil> few of those lumberjack to <sil> <sil> that nobody is accused any of <sil> the loggers of the crime <sil> remarked frank <sil> and then that <sil> had projecting from the opening at <sil> the door came a little further into <sil> you </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/7800/7800-283492-0001_1.wav' from 3000ms to 3160ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/7800/7800-283492-0001_2.wav' from 6750ms to 6910ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/7800/7800-283492-0001_3.wav' from 11330ms to 11710ms.
# Recognized words: <s> <sil> he started pretty hard at first getting caught and fat <sil> think it means <sil> but when you come right down to facts i guess it was just as well that it happened to him <sil> ah <sil> that's a quick thing to say [NOISE] <sil> rehman straight to the bluff </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/7800/7800-283492-0018_1.wav' from 8390ms to 8560ms.
# Recognized words: <s> if he might be fine against her <sil> <sil> i don't think they did because you'd ask your father such questions that <sil> you want to believe that it is the chief object of my life to do the best i can for my children <sil> i am sure if he is </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/4297/4297-13006-0032_1.wav' from 5360ms to 5690ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/4297/4297-13006-0032_2.wav' from 7090ms to 7270ms.
# Recognized words: <s> that <sil> according to those that are <sil> december eighteen ninety two <sil> upon always going to the team daddy to <sil> the yellow plowed appeared over packer born germany <sil> <sil> from this club foot range will bring [NOISE] in which were hundreds of muscles </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/3240/3240-131232-0024_1.wav' from 250ms to 710ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/3240/3240-131232-0024_2.wav' from 1810ms to 2100ms.
# Recognized words: <s> <sil> and mr ward and it felt himself down to extinction addition to such matters from uninsured feeling that he could not in that direction it <sil> that's an enduring objection <sil> <sil> <sil> in this way lopez said carried this point with mr wharton </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/4297/4297-13006-0015_1.wav' from 5560ms to 5700ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/4297/4297-13006-0015_2.wav' from 6550ms to 6750ms.
# Recognized words: <s> that he did love that girl <sil> as well perhaps as he was capable of loving anyone <sil> <sil> that he had found out in any particular system mr ford needs money before he had about himself to love her <sil> <sil> as soon as mrs roby had gathered up her knitting </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/4297/4297-13006-0017_1.wav' from 110ms to 290ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/4297/4297-13006-0017_2.wav' from 850ms to 1010ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/4297/4297-13006-0017_3.wav' from 5210ms to 5560ms.
# Recognized words: <s> <sil> no needed that <sil> <sil> you need to reply <sil> because i'd be willing to start after that most alone and follow him for a week if i thought i could get a fair crack at him in the end <sil> and it's a tall glass </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/7800/7800-283493-0019_1.wav' from 950ms to 1490ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/7800/7800-283493-0019_2.wav' from 4780ms to 5030ms.
# Recognized words: <s> the three soon reach the cabin <sil> a chance that just end the call to the midday meal came <sil> where was too busy working at his developing tank to sit down with the rest <sil> plenty of time and i get through with this <sil> he told them </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/7800/7800-283493-0027_1.wav' from 2890ms to 3200ms.
# Recognized words: <s> so then that the turtle in the piece about all those remain of four different origins <sil> from different worlds perhaps <sil> have entered region of suspension over this earth <sil> walking near each other <sil> long duration </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/3240/3240-131232-0002_1.wav' from 950ms to 1140ms.
# Recognized words: <s> that <sil> according to testimony taken before magistrates <sil> off all occurred february nineteenth <sil> the team thirty <sil> year feared for <sil> india <sil> of many tissues of various sizes <sil> some loophole in fresh and others <sil> <sil> mutilated and cuter fine </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/3240/3240-131231-0064_1.wav' from 450ms to 940ms.
# Recognized words: <s> if it is only because mr lopez has a foreign aid <sil> it isn't only that <sil> no one knows anything about him <sil> or where to inquiry can <sil> <sil> <sil> i think you should inquire pop pop <sil> and be quite certain that for you pronounce such a sentence against me <sil> </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/4297/4297-13006-0039_1.wav' from 4020ms to 4390ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/4297/4297-13006-0039_2.wav' from 12090ms to 12210ms.
# Recognized words: <s> neither at dinner <sil> on that evening in manchester square <sil> nor after dinner <sil> as long as this really remains in the house <sil> was a word said about lopez by mr wharton <sil> <sil> [NOISE] he remained longer than usual with his spot left port wine in the dining room </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/4297/4297-13006-0000_1.wav' from 1620ms to 1870ms.
# Recognized words: <s> one of the heels of the other <sil> <sil> each assuring me not only that the whole stability theater price depends on my giving a certain office to him <sil> <sil> actually telling me to my face that i had promised it to him <sil> the old steaks and laughed </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/4297/4297-13009-0009_1.wav' from 3800ms to 3980ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/4297/4297-13009-0009_2.wav' from 9720ms to 9890ms.
# Recognized words: <s> whether it is more dishonest <sil> and leather struggles were not make like it's disgraceful to the structures <sil> as anything to to stand now <sil> [NOISE] <sil> you can't alter the men <sil> in you must use them <sil> the younger kids sat down inside of it to generate patriotism of each </s>
# The word 'that' was not found in the audio C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/cleaned/4297/13009/4297-13009-0014.wav.
# Recognized words: <s> and at first it seemed that one special bench in a house of commons would remain on occupied <sil> <sil> but after a day or two <sil> [NOISE] <sil> on one of which mr dubbing it didn't seem fitting to speed of the gang way <sil> <sil> that gentleman return to the place usually held that the prime minister's rival <sil> </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/4297/4297-13009-0024_1.wav' from 1220ms to 1350ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/4297/4297-13009-0024_2.wav' from 11710ms to 11950ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/4297/4297-13009-0024_3.wav' from 13830ms to 13990ms.
# Recognized words: <s> sticking out of his head <sil> <sil> all want our whopper he gasped as he drew near the spot where they stood <sil> what's that <sil> demanded frank wondering what was coming out <sil> and such extreme end is horns to <sil> continue to build </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/7800/7800-283492-0038_1.wav' from 8030ms to 8550ms.
# Recognized words: <s> <sil> he was as convinced as ever <sil> <sil> but unless there was much to conceal <sil> they would not be so much concealment <sil> <sil> <sil> that a feeling began to grow up on him already <sil> that his daughter had a motive pleading with him which he would not ultimately be able to resist </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/4297/4297-13006-0043_1.wav' from 7420ms to 7700ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/4297/4297-13006-0043_2.wav' from 10800ms to 10970ms.
# Recognized words: <s> and that said that she'd cooperation sure which had first asked <sil> was accorded to him <sil> it may be a question whether on the whole the duchess did not work harder than he did <sil> </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/4297/4297-13009-0063_1.wav' from 420ms to 610ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/4297/4297-13009-0063_2.wav' from 790ms to 930ms.
# Recognized words: <s> i'd like to emphasize on to <sil> i am permit to see because i'm still primitive <sil> or intelligent <sil> or in the state of knowledge as much </s>
# The word 'that' was not found in the audio C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/cleaned/3240/131231/3240-131231-0002.wav.
# Recognized words: <s> said that at the first proposition to follicle issue ministry [NOISE] the newspaper said hardly know whether to assist or to oppose the scheme <sil> there was no doubt in the minds of all these editors of contributors [NOISE] <sil> to the teaching of a tradition that coalitions of this kind of thing generally feeble <sil> </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/4297/4297-13009-0016_1.wav' from 550ms to 760ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/4297/4297-13009-0016_2.wav' from 13070ms to 13220ms.
# Recognized words: <s> many instances of wrong so we're seeing the fall from the sky </s>
# The word 'that' was not found in the audio C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/cleaned/3240/131231/3240-131231-0006.wav.
# Recognized words: <s> country from bonds at which the air can't you can find <sil> <sil> of course such turn of character is subject to certain dangers of itself <sil> <sil> there is no doubt about the dangers <sil> the chances are that one i see her crate session teller but i think about her </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/4297/4297-13009-0049_1.wav' from 11550ms to 11700ms.
# Recognized words: <s> <sil> you look at something he had a nice and <sil> said that everyone could see <sil> it was a stone <sil> there could be no doubt about that <sil> with some of the snow still in hearing too it's science <sil> laugh read the side of this added saying this </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/7800/7800-283478-0003_1.wav' from 2710ms to 2840ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/7800/7800-283478-0003_2.wav' from 6310ms to 6800ms.
# Recognized words: <s> of the british museum <sil> bristling with exclusion is some <sil> rights and some of these <sil> issues <sil> which had been sent to him alive <sil> were very young minerals <sil> he says <sil> on reading it and so it seems to me most probably only a practical joke </s>
# The word 'that' was not found in the audio C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/cleaned/3240/131231/3240-131231-0030.wav.
# Recognized words: <s> that you declared <sil> it's only a quarter courses until i can develop this them <sil> you shall see for yourself whether i noticed that from a bull means <sil> he was told by the indignant photographer <sil> as the latter broke away and banished inside the cabin </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/7800/7800-283493-0007_1.wav' from 60ms to 420ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/7800/7800-283493-0007_2.wav' from 7500ms to 7900ms.
# Recognized words: <s> the would harmonize with the aid of fish is that follows it from the stationery stores <sil> and of course <sil> with other day or two <sil> is inadequate to account for to be <sil> to hear cheese of the fall of frogs <sil> that never has a fault had polls been reported </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/3240/3240-131232-0011_1.wav' from 2370ms to 2560ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/3240/3240-131232-0011_2.wav' from 12340ms to 12510ms.
# Recognized words: <s> <sil> because he's a stranger in a foreigner <sil> which you have wished me to tell him that he might come <sil> yes but talk <sil> <sil> he was sitting on a sofa and strength back a little from her as she made history of al </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/4297/4297-13006-0020_1.wav' from 4250ms to 4410ms.
# Recognized words: <s> because it was felt on all sides <sil> to <sil> start and it could not join a new composite party without hyped makes <sil> <sil> <sil> and the same greece has shown in regards to lurk drummond <sil> who remained in <sil> the colonies <sil> keeping the office to which she had been late be transferred under mr dobson he </s>
# The word 'that' was not found in the audio C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/cleaned/4297/13009/4297-13009-0001.wav.
# Recognized words: <s> explain the other <sil> has no more than surprised <sil> i shall lead to see your father and make a complaint at the chief of police declined to back me up the irs the fuel you <sil> as to that mr she's i will tell my father <sil> all about it as soon as he comes home school the bank </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/7800/7800-283478-0006_1.wav' from 11040ms to 11320ms.
# Recognized words: <s> <sil> that like snow falling last night was in our favor for the tracks will show up well <sil> suggested jerry <sil> <sil> here's the place <sil> frank told them the short time afterward <sil> you can see the tree with all women over there </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/7800/7800-283493-0011_1.wav' from 340ms to 660ms.
# Recognized words: <s> <sil> <sil> they talk to other as they sounded in the direction of their homes <sil> <sil> it happens that will mountains house was the first taking two <sil> as the postman came out of my gates <sil> will commented <sil> on if you got a coffee looks the leather ease been expecting for some days [NOISE] </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/7800/7800-283478-0026_1.wav' from 4880ms to 5120ms.
# Recognized words: <s> these data had me me me me you're lying to me being gored degree of damnation you please <sil> but <sil> in a matter of her fault occurred at memphis tennessee <sil> hookers and strong significance is </s>
# The word 'that' was not found in the audio C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/cleaned/3240/131232/3240-131232-0027.wav.
# Recognized words: <s> i would not wish that they should be opportunity for such ask you <sil> <sil> if there's been intimacy between you <sil> <sil> <sil> such information should come naturally <sil> as a thing of course <sil> you've made him no promise <sil> i'll help op pa <sil> </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/4297/4297-13006-0029_1.wav' from 990ms to 1160ms.
# Recognized words: <s> that her anger about <sil> the ropes was achieved <sil> <sil> i've done as you asked about a friend of yours <sil> he said <sil> <sil> this occurred just before the final and protected list of the new man had appeared in all the newspapers <sil> <sil> what friend </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/4297/4297-13009-0052_1.wav' from 200ms to 400ms.
# Recognized words: <s> the fact is <sil> sick bro peak <sil> <sil> that we've tested to two men so long that we don't know how to suppose in you one else big enough to to other places <sil> <sil> mug wouldn't have to add <sil> [NOISE] <sil> the house doesn't care about not <sil> <sil> i always thought it should be wilson </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/4297/4297-13009-0028_1.wav' from 2310ms to 2470ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/4297/4297-13009-0028_2.wav' from 4270ms to 4400ms.
# Recognized words: <s> <sil> yes i do <sil> he said we couldn't go is lord lieutenant <sil> he said the daring to narrow was going to ireland <sil> well yes <sil> i don't know the be interested by all the ins and outs of it </s>
# The word 'that' was not found in the audio C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/cleaned/4297/13009/4297-13009-0054.wav.
# Recognized words: <s> for myself i did singer stayed out as an independent member [NOISE] <sil> the topic he said that he thought i was down to make myself useful <sil> to <sil> i told the dude from the beginning <sil> said traveler <sil> <sil> that i do think that i can get any service to him </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/4297/4297-13009-0030_1.wav' from 4710ms to 4870ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/4297/4297-13009-0030_2.wav' from 11390ms to 11570ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/4297/4297-13009-0030_3.wav' from 12080ms to 12250ms.
# Recognized words: <s> final precipitation by atmospheric disturbance <sil> with kale <sil> or that hail storms too when large or phenomenal of suspension of long duration <sil> <sil> that it is highly an acceptable that the barely larger ones could become so great <sil> only in small intimate clouds </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/3240/3240-131232-0003_1.wav' from 4110ms to 4370ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/3240/3240-131232-0003_2.wav' from 9310ms to 9540ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/3240/3240-131232-0003_3.wav' from 10890ms to 11060ms.
# Recognized words: <s> something else apart from the three main interest is a phenomenon that looks like what one might call <sil> an alternating series of falls of fish is <sil> where the significance maybe </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/3240/3240-131231-0050_1.wav' from 3720ms to 3900ms.
# Recognized words: <s> there are other data that are so more to do though falls with issues <sil> <sil> science goes up </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/3240/3240-131232-0015_1.wav' from 1170ms to 1380ms.
# Recognized words: <s> but none were found on routes or any other elevation above ground <sil> and <sil> numbers seem to fall <sil> <sil> <sil> <sil> if you prefer to believe that this makes it always been there <sil> for a beat up on the ground in the first place <sil> that was only that something occurred because special attention to them </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/3240/3240-131232-0030_1.wav' from 7780ms to 7970ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/3240/3240-131232-0030_2.wav' from 11930ms to 12210ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/3240/3240-131232-0030_3.wav' from 12540ms to 12730ms.
# Recognized words: <s> she treated over her injury <sil> and his heart was that within him <sil> <sil> when he got the kid text her <sil> <sil> having her as he did with all his hard [NOISE] <sil> with the heart that was never to monsters <sil> <sil> <sil> and she was unhappy he was miserable <sil> </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/4297/4297-13009-0038_1.wav' from 2890ms to 3250ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/4297/4297-13009-0038_2.wav' from 9440ms to 9600ms.
# Recognized words: <s> to which he objected only on to score of time <sil> you must eat her dinner somewhere <sil> she <sil> had <sil> [NOISE] <sil> and you need only coming just before we sit down <sil> and go into your honor him if you please without coming upstairs at all <sil> <sil> i can at any rate to that part of it for you </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/4297/4297-13009-0065_1.wav' from 14030ms to 14270ms.
# Recognized words: <s> i get caught then it keeps on running like a hot iron <sil> would be surprised if there was a pizza callers <sil> and that tall <sil> enough to fix that alot of an issue now way before they tackled last <sil> seems to me will slow on time coming out again <sil> and clean jerry </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/7800/7800-283478-0031_1.wav' from 5780ms to 6030ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/7800/7800-283478-0031_2.wav' from 7440ms to 7620ms.
# Recognized words: <s> you had to be shown very little so is to suit and tie ins and none of them are granted in the least that they had expanded helping hand sport one in distress <sil> and you might <sil> was opening up to teddy </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/7800/7800-283492-0025_1.wav' from 5590ms to 5840ms.
# Recognized words: <s> <sil> i'm done eating <sil> announced <sil> not <sil> couldn't grab another bite down after seeing that picture <sil> jerry proclaimed <sil> as he darted over to the corner where his rifle stood <sil> and began to buckle on the web page belts filled with cartridges </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/7800/7800-283493-0031_1.wav' from 5320ms to 5570ms.
# Recognized words: <s> an illustrious person each <sil> <sil> matter affected our duke [NOISE] <sil> only insofar that he could not get out of his mind <sil> that strange education from his own wife <sil> <sil> that she should've even trained to hit <sil> he would say to itself </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/4297/4297-13009-0036_1.wav' from 5270ms to 5450ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/4297/4297-13009-0036_2.wav' from 7050ms to 7320ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/4297/4297-13009-0036_3.wav' from 10720ms to 10930ms.
# Recognized words: <s> i'm sure that is all you can expect from us <sil> but the measly shank friend <sil> objected got in touch with league [NOISE] <sil> when it was any measure of broke the window <sil> added jerry filled with righteous indignation <sil> you only got frank would you side headed your way <sil> </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/7800/7800-283478-0008_1.wav' from 630ms to 860ms.
# Recognized words: <s> the meaning to a man's words exactly opposite to that which never told <sil> today <sil> <sil> or if he does lying doing so he does not know that the lights <sil> <sil> mr adler it on back to his old office at the treasury <sil> </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/4297/4297-13009-0032_1.wav' from 2840ms to 3040ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/4297/4297-13009-0032_2.wav' from 7830ms to 7990ms.
# Recognized words: <s> the two murders people you know sometimes <sil> he's an irishman himself <sil> <sil> that's just the reason why they shed <sil> <sil> he must put up with that of course <sil> i wonder whether she like <sil> telling <sil> the people to spend money which they always liked </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/4297/4297-13009-0057_1.wav' from 9420ms to 9660ms.
# Recognized words: <s> as something that strikes my attention here is that these prongs or describe is almost white <sil> <sil> i'm afraid there's no escape for us <sil> we shall have to get to civilization upon this earth <sil> some new worlds <sil> places with whey protein them </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/3240/3240-131231-0020_1.wav' from 800ms to 960ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/3240/3240-131231-0020_2.wav' from 2210ms to 2460ms.
# Recognized words: <s> injuries had perhaps already been done <sil> <sil> it may be that some slight soil had already marked <sil> pure white of the girls natural character <sil> <sil> they sell <sil> this thing was is yet to win palpable to be visible to ordinary ice </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/4297/4297-13006-0008_1.wav' from 4090ms to 4240ms.
# Recognized words: <s> he's always so much taken up with that <sil> photography it is that any old time he's liable to remember something and go to work at it [NOISE] for getting all about his chums you may be taking their heels in the backyard waiting for him <sil> all i don't think he's quite that <sil> gets all <sil> blacks think </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/7800/7800-283478-0032_1.wav' from 2200ms to 2440ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/7800/7800-283478-0032_2.wav' from 3550ms to 3790ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/7800/7800-283478-0032_3.wav' from 13600ms to 13940ms.
# Recognized words: <s> in the first place <sil> <sil> he founded the snails had appeared after the rain <sil> that <sil> astonished roster to jump to the conclusion that they had follow up <sil> he met one person who said that he'd seen as nails <sil> all <sil> <sil> <sil> this was his error <sil> says the investigator </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/3240/3240-131232-0021_1.wav' from 4750ms to 5170ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/3240/3240-131232-0021_2.wav' from 7840ms to 8040ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/3240/3240-131232-0021_3.wav' from 11070ms to 11230ms.
# Recognized words: <s> and if unconscious bit not therefore less actually <sil> made themselves indispensable <sil> <sil> either to deciding politics or to that <sil> cannot prevent solves all together for the responsibility of managing them <sil> <sil> when a period come such as that now reached </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/4297/4297-13009-0019_1.wav' from 7110ms to 7560ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/4297/4297-13009-0019_2.wav' from 13550ms to 13820ms.
# Recognized words: <s> in this letter is said that the largest issues were five inches long <sil> and that these did not survive the fall <sil> <sil> <sil> <sil> <sil> report to the british association </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/3240/3240-131231-0041_1.wav' from 1860ms to 2030ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/3240/3240-131231-0041_2.wav' from 4680ms to 4880ms.
# Recognized words: <s> a barn and offers were carried completely away <sil> and i'm the worst nor barn <sil> door any portion of wider had since been found <sil> <sil> after that <sil> which would be a little strong were not for steady improvement in your digestion said i know because we go along </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/3240/3240-131231-0075_1.wav' from 9050ms to 9570ms.
# Recognized words: <s> and so i told the dude <sil> he had no idea that it should be one of your mic and <sil> i think he's right there <sil> said ro p. <sil> <sil> there ought to be something like a fair decision <sil> to <sil> individuals like it contained <sil> but the party would be dissatisfied </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/4297/4297-13009-0029_1.wav' from 2650ms to 2820ms.
# Recognized words: <s> in which were thousands of fish is <sil> for five inches wall <sil> some of which covered russa poses [NOISE] in some of which remained ten minutes in the air <sil> by way of contrast we offer our own acceptance <sil> that the bottom of the super geographical pond <sil> had dropped it </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/3240/3240-131231-0044_1.wav' from 12130ms to 12350ms.
# Recognized words: <s> mr macpherson and mr brodie <sil> the host of others would amount to mr da benny <sil> [NOISE] <sil> are prepared as they declared the first <sil> to end their assistance to the deep <sil> <sil> they had consulted mr dalton eon the subject <sil> and mr company told them that their duty lane that direction </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/4297/4297-13009-0005_1.wav' from 14070ms to 14250ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/4297/4297-13009-0005_2.wav' from 15040ms to 15270ms.
# Recognized words: <s> in the amiable accommodation to the crucifixion it'll get <sil> i think <sil> <sil> but so impressed are we with it that i'm that <sil> though there have been many reports of small throngs of fallen from the sky </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/3240/3240-131231-0048_1.wav' from 6560ms to 6830ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/3240/3240-131231-0048_2.wav' from 6970ms to 7340ms.
# Recognized words: <s> to be told at the same half hour by two men to that'd make promises to each of them inconsistent with each other <sil> <sil> were that to me and <sil> <sil> mr bachelor and mr brodie <sil> am assured that they're inseparable since the work was stuck on <sil> </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/4297/4297-13009-0010_1.wav' from 7400ms to 7550ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/4297/4297-13009-0010_2.wav' from 12200ms to 12440ms.
# Recognized words: <s> <sil> it does seem as though you've met with nothing but success so far <sil> frank admitted <sil> i hope it gets that ties the bellows offering <sil> some are lacking tell [NOISE] he hasn't any collection on benny and we've got some time ahead of us still <sil> i go anywhere is will now <sil> asked <sil> laugh </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/7800/7800-283492-0034_1.wav' from 5680ms to 5940ms.
# Recognized words: <s> <sil> <sil> when it was first known that the duke of our young to consent to to make the attempt <sil> they had both on one side and the other <sil> been allowed in his case <sil> going so far as to say he was the <sil> only man in england could do the work </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/4297/4297-13009-0021_1.wav' from 1660ms to 1860ms.
# Recognized words: <s> region of the nervous to this risk reputation <sil> of course <sil> however <sil> region that by the fox and variation of all things <sil> must at times be susceptible <sil> <sil> <sil> but afterward <sil> are hers to go by cricket <sil> </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/3240/3240-131231-0047_1.wav' from 5540ms to 5920ms.
# Recognized words: <s> begin the small area <sil> about sixty by thirty yards <sil> <sil> before perjuring a heavy rain that was accompanied by thunder </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/3240/3240-131231-0069_1.wav' from 6270ms to 6440ms.
# Recognized words: <s> not a cabinet <sil> no <sil> not in the cabinet that is not by any means usual that he should be <sil> <sil> <sil> that this commotion and i am glad <sil> <sil> bush cheney us <sil> i hope they want their him or anything of that kind </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/4297/4297-13009-0056_1.wav' from 3910ms to 4240ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/4297/4297-13009-0056_2.wav' from 5610ms to 5760ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/4297/4297-13009-0056_3.wav' from 7780ms to 7970ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/4297/4297-13009-0056_4.wav' from 13400ms to 13670ms.
# Recognized words: <s> but no wondering whether the missile that it struck in there had also been loaded in a way <sil> we're sorry mr chase that your window was broken <sil> said frank steadily <sil> it was an accident [NOISE] <sil> i give you my word about that </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/7800/7800-283478-0004_1.wav' from 1570ms to 1740ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/7800/7800-283478-0004_2.wav' from 6450ms to 6650ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/7800/7800-283478-0004_3.wav' from 11990ms to 12400ms.
# Recognized words: <s> <sil> you are a good girl <sil> you were always a good girl <sil> <sil> [NOISE] that i think the law to hear me <sil> <sil> <sil> any state still with his hands in his trousers pockets looking at her <sil> </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/4297/4297-13006-0037_1.wav' from 4310ms to 4610ms.
# Recognized words: <s> did you ever hear this man speak of his father <sil> <sil> i don't know that every kid <sil> or his mother <sil> or his family <sil> don't you think that is suspicious </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/4297/4297-13006-0028_1.wav' from 4020ms to 4200ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/4297/4297-13006-0028_2.wav' from 9070ms to 9260ms.
# Recognized words: <s> <sil> oh well i noticed the lack of dodging being done <sil> commented frank <sil> <sil> and only for that all of us who i didn't need more bull's eye is <sil> chances are that and you have the circle around his left eye at this match he got <sil> there jerry <sil> <sil> hides no bottom sting like fun when it catches you there </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/7800/7800-283478-0030_1.wav' from 4720ms to 4980ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/7800/7800-283478-0030_2.wav' from 8320ms to 8540ms.
# Recognized words: <s> the one man in parliament <sil> modest enough not to consider is tough to be fit for any place that can be offered to him <sil> what their intent <sil> he does not like the idea of crossing the channel so often <sil> <sil> i sympathize with him <sil> and seventy s. is to be secretary for ireland <sil> </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/4297/4297-13009-0055_1.wav' from 4620ms to 4780ms.
# Recognized words: <s> over there <sil> <sil> <sil> he comes back with two forwards every week doesn't he <sil> not <sil> like that i believe <sil> <sil> <sil> i shall miss her if she has to stay away long <sil> i know you don't like her <sil> i do like her </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/4297/4297-13009-0058_1.wav' from 6290ms to 6590ms.
# Recognized words: <s> <sil> he's he's got a bad attack of britain's and <sil> yet he says he was trying to get away down east on some very important business <sil> <sil> between you and me <sil> you never will be able to do it for days a week season that doubled up <sil> on if you see like it <sil> will <sil> shrink told them <sil> no way out here for you </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/7800/7800-283478-0027_1.wav' from 10910ms to 11230ms.
# Recognized words: <s> and don't i hope that first picture turned out but <sil> it was a remarkable pose is <sil> only the focus was right <sil> he started for the cabin door as though anxious to develop his world of film and discover what successes labour had resulted in </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/7800/7800-283493-0005_1.wav' from 1170ms to 1430ms.
# Recognized words: <s> evidently teddy had heard enough <sil> he must've lived from his chair to the doorway upon hearing strange voices outside <sil> perhaps it's <sil> acted that the others got news and some startling character <sil> and did not tell all of his chums about what he had seen </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/7800/7800-283492-0009_1.wav' from 8510ms to 8780ms.
# Recognized words: <s> but as always sought positively to prove forty does prove something that was conceived job <sil> or suspected <sil> in advance <sil> as i suspected <sil> says is correspondent <sil> <sil> i found that the sales were up for familiar when species <sil> that they had been up on the ground </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/3240/3240-131232-0020_1.wav' from 3640ms to 3790ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/3240/3240-131232-0020_2.wav' from 11370ms to 11520ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/3240/3240-131232-0020_3.wav' from 14280ms to 14470ms.
# Recognized words: <s> were there some especially for the place near europe <sil> has arisen especially sandy placed <sil> designed to three years were nation would of course <sil> be that all small frogs calling from the sky in your <sil> car from med center of from getting <sil> <sil> to start with </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/3240/3240-131231-0001_1.wav' from 8570ms to 8740ms.
# Recognized words: <s> then i think of our hurricane that occurred in the state of mississippi <sil> weeks or months before mail and eighty ninety four <sil> <sil> know <sil> i don't look for <sil> an inevitably find it <sil> <sil> or that things can go up so high in hurricanes that to stay up indefinitely </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/3240/3240-131232-0000_1.wav' from 1460ms to 1620ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/3240/3240-131232-0000_2.wav' from 11290ms to 11550ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/3240/3240-131232-0000_3.wav' from 13710ms to 13890ms.
# Recognized words: <s> that had been a great question <sil> cause for the fact that prime minister <sil> was in the house of lords <sil> and what office should delete your old <sil> <sil> mr monk had consented to take <sil> the exchequer <sil> </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/4297/4297-13009-0026_1.wav' from 350ms to 650ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/4297/4297-13009-0026_2.wav' from 3010ms to 3170ms.
# Recognized words: <s> bowling credibility so we have to choose from <sil> i give first place to an ocean of the whirlwind pounds and o'connor region </s>
# The word 'that' was not found in the audio C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/cleaned/3240/131231/3240-131231-0081.wav.
# Recognized words: <s> but by no visible lightning <sil> <sil> to see is close to ending <sil> but if you try to think of these issues having describe the trajectory a whirlwind from the ocean <sil> consider this remarkable didn't <sil> <sil> that </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/3240/3240-131231-0070_1.wav' from 11440ms to 11910ms.
# Recognized words: <s> disregarding surreal significance <sil> for mechanical one intelligent recalls a reflex <sil> is that the fish assuming you did not fall from the sky <sil> that they were found on the ground after torrential rains <sil> because strange had overflow to <sil> me had been received it </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/3240/3240-131231-0057_1.wav' from 6250ms to 6460ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/3240/3240-131231-0057_2.wav' from 9270ms to 9460ms.
# Recognized words: <s> and i think that makes it very long time ago <sil> but silver bridge was the tits eldest <sil> son <sil> <sil> but what does it matter <sil> if she began a career in the time is george the fourth what is it you are </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/4297/4297-13009-0045_1.wav' from 640ms to 810ms.
# Recognized words: <s> <sil> you're not the county added that the old frank told them <sil> you remember <sil> that i sprained her ankle yesterday in a long walk would lay me out <sil> if anybody goes it will have to be you to <sil> jerry looked at <sil> last <sil> i dare you <sil> he said </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/7800/7800-283493-0018_1.wav' from 1370ms to 1670ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/7800/7800-283493-0018_2.wav' from 4220ms to 4420ms.
# Recognized words: <s> the most strange thing which ever struck me was that the fish did not fall cultures culture <sil> were here and there <sil> but they fell on the straight line not more than make you begin breath </s>
# ...
# Recognized words: <s> that <sil> during a heavy shower to like thirty to sixty <sil> you heard a peculiar sounded his feet <sil> and looking down saw us make wine is it stung by a fall <sil> [NOISE] <sil> getting kinda like <sil> <sil> greece make <sil> about a foot long </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/3240/3240-131232-0026_1.wav' from 160ms to 600ms.
# Recognized words: <s> <sil> and i think it happened so near our camp that we managed to tell <sil> the whole car <sil> is to the cabin <sil> <sil> and black book <sil> with pride in his eyes <sil> toward a deer that was hanging in real sports man's dial from a limb heads downward <sil> </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/7800/7800-283492-0032_1.wav' from 2660ms to 2830ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/7800/7800-283492-0032_2.wav' from 9030ms to 9230ms.
# Recognized words: <s> i will of course i will <sil> <sil> and he began the process of thinking about it immediately <sil> before the door was closed behind her <sil> <sil> but what was there to think about <sil> [NOISE] <sil> <sil> nothing that she had said altered in the least his idea about the man </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/4297/4297-13006-0042_1.wav' from 12030ms to 12170ms.
# Recognized words: <s> but the one well what happened next <sil> <sil> <sil> all i looked up to see what it mean that we're sound and dairy was <sil> just defending him looking straight at me <sil> i was nearly scared to death at first <sil> for he looked nearly as big as a pond </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/7800/7800-283493-0003_1.wav' from 5590ms to 6040ms.
# Recognized words: <s> but i have no discipline to pulls a twenty two leads me to be three <sil> one in france and one in tahiti <sil> <sil> also <sil> a fish and scotland <sil> <sil> when the phenomenon of the evidence [NOISE] <sil> to make sure seems to me to be typical of the products of the world </s>
# The word 'that' was not found in the audio C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/cleaned/3240/131231/3240-131231-0012.wav.
# Recognized words: <s> but why did they come to me with their mouths open <sil> like dogs scraping the bottom <sil> <sil> it is not to be so <sil> <sil> of course men were always anxious for office as they are now <sil> <sil> well yes we for that before today i think </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/4297/4297-13009-0012_1.wav' from 12380ms to 12690ms.
# Recognized words: <s> is it fair to you to pay the bill <sil> <sil> when to let anybody <sil> now i've heard for settling a count myself and not having any trouble about it <sil> frank told his objecting to arms <sil> <sil> decided that enough but none of the business to spend a little expense like that </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/7800/7800-283478-0009_1.wav' from 11680ms to 11900ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/7800/7800-283478-0009_2.wav' from 14450ms to 14860ms.
# Recognized words: <s> <sil> the sooner that window pane is a place that actually pleased <sil> that to not <sil> with that he turned his back upon the group and hurried <sil> to re enter his house <sil> is though fearful asked some of the spectators nine endeavour to shave him out of accepting paid an instant party </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/7800/7800-283478-0012_1.wav' from 740ms to 1030ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/7800/7800-283478-0012_2.wav' from 2140ms to 2390ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/7800/7800-283478-0012_3.wav' from 3780ms to 4040ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/7800/7800-283478-0012_4.wav' from 5060ms to 5400ms.
# Recognized words: <s> frank however <sil> i understood what a blizzard meant up there in maine <sil> in and then in one or two himself and would not care to repeat certain experiences that had come his way <sil> the mass well provided against hunger and bitter cold </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/7800/7800-283493-0026_1.wav' from 9000ms to 9210ms.
# Recognized words: <s> or if her tastes lie in that direction <sil> average man <sil> <sil> and only warden had <sil> dallas thought about these things [NOISE] <sil> and she sincerely believe that she had found a good man named ferdinand of pets </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/4297/4297-13006-0013_1.wav' from 1470ms to 1690ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/4297/4297-13006-0013_2.wav' from 8470ms to 8630ms.
# Recognized words: <s> <sil> if we're going to get in many affairs like the one we just had that the leisure and as crowd <sil> the latter smart <sil> it stands to reason we want it to not seminar he can <sil> <sil> buy baseball i'm in that practice and i'm ashamed to say that three out of <sil> four balls i've fired missed the mark </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/7800/7800-283478-0029_1.wav' from 3180ms to 3430ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/7800/7800-283478-0029_2.wav' from 10690ms to 10960ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/7800/7800-283478-0029_3.wav' from 12520ms to 12740ms.
# Recognized words: <s> it hopes of living strong so calm here <sil> from some world's <sil> every living thing upon this earth may ancestral a [NOISE] have come from <sil> some world's <sil> <sil> i find that i have another note on a specific ricky </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/3240/3240-131231-0022_1.wav' from 10760ms to 10910ms.
# Recognized words: <s> <sil> drinks now that he did not look does please <sil> i'm glad missed eventually as such an opinion about what champ is <sil> earmarked <sil> for him and everyone in you as well as me <sil> when he said that </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/7800/7800-283478-0021_1.wav' from 910ms to 1390ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/7800/7800-283478-0021_2.wav' from 10650ms to 10990ms.
# Recognized words: <s> as to what the greatest hurricanes in the history of ireland <sil> some fish were found <sil> as far as fifteen yards from the edge of the lake <sil> <sil> have another <sil> this is a good one to the exclusion us <sil> fall of fish and parents <sil> <sil> said in neighboring pondered been blown dry </s>
# The word 'that' was not found in the audio C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/cleaned/3240/131231/3240-131231-0023.wav.
# Recognized words: <s> that ten minutes later <sil> another full of fishes occurred on the same <sil> narrow strip of land <sil> <sil> even arguing the whirlwind a standstill actually <sil> it is charges tangentially <sil> <sil> were the fishes came from it does not seem single ball </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/3240/3240-131231-0035_1.wav' from 520ms to 810ms.
# Recognized words: <s> to just to me something of of migratory nature <sil> but that snakes in the united states do not my grade in the month of january <sil> if ever <sil> <sil> has to falls were fluttering swing the insects from the sky <sil> prevailing notions of swarming would seem explanatory enough </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/3240/3240-131232-0037_1.wav' from 3150ms to 3350ms.
# Recognized words: <s> it isn't <sil> often have to suffer for the guilty <sil> some of the bystanders a display tragic and it's just a case that frank was entirely innocent <sil> of the whole transaction <sil> but the mind they're acting on the principle that <sil> a bird in the hand is worth two in the bush </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/7800/7800-283478-0010_1.wav' from 6010ms to 6210ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/7800/7800-283478-0010_2.wav' from 12150ms to 12470ms.
# Recognized words: <s> <sil> he's the only party around that we know of who would be mean enough to try to set buildings on fire <sil> just to get even with a man he disliked <sil> the observed </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/7800/7800-283492-0006_1.wav' from 2040ms to 2240ms.
# Recognized words: <s> it won't weigh heavy <sil> but if you do need it you'll thank me for it <sil> glass and jerry may have considered frank <sil> a bit <sil> too old woman ish making all that fuss over just going off <sil> on the little chase after wandering those </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/7800/7800-283493-0025_1.wav' from 9180ms to 9430ms.
# Recognized words: <s> she had ever right to treat her cause before judgment should be given <sil> <sil> and she was not slow twitch or herself <sil> even as his interview went on to [NOISE] touch her love for the man was strong enough to entitled her to assure her father <sil> that her happiness depended <sil> on his reversal of the sentence </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/4297/4297-13006-0035_1.wav' from 12410ms to 12580ms.
# Recognized words: <s> in the streets of memphis january fifteen between seventy seven <sil> why <sil> the sensible <sil> that's a common sense that has been against us from the <sil> first <sil> <sil> it is not said whether the snakes were unknown species are not </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/3240/3240-131232-0031_1.wav' from 7330ms to 7530ms.
# Recognized words: <s> the tissues and cells have fallen by pupils <sil> <sil> that these issues were not on the ground in the first place <sil> we be sure objections to the whirlwind explanation of hard to date <sil> <sil> that the fella no such distribution as one could attribute to the discharge a whirlwind </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/3240/3240-131231-0034_1.wav' from 3760ms to 3940ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/3240/3240-131231-0034_2.wav' from 11560ms to 11780ms.
# Recognized words: <s> he was beginning to get over the nervousness that had showed itself there all day and <sil> following his advent in the new care </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/7800/7800-283492-0023_1.wav' from 2510ms to 2780ms.
# Recognized words: <s> ari pronounced <sil> <sil> you know capacitors to you <sil> she said <sil> and i <sil> promise you that i will not disobey you <sil> </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/4297/4297-13006-0036_1.wav' from 6690ms to 6860ms.
# Recognized words: <s> an engaged owner to send a man a rounded wants to go home of the mines are <sil> so as to replace the twelve by twenty pain at last <sil> i expect that a good many orders like that frank before the days over <sil> marks <sil> the dealer laughingly </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/7800/7800-283478-0015_1.wav' from 8490ms to 8740ms.
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/7800/7800-283478-0015_2.wav' from 9840ms to 10120ms.
# Recognized words: <s> to start with <sil> i do not deny it positively <sil> the conventional explanation of opening <sil> <sil> i think that there may have been such occurrences <sil> i omit many notes and i have upon indistinguishable <sil> so </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/3240/3240-131231-0010_1.wav' from 7230ms to 7380ms.
# Recognized words: <s> <sil> we take it all back at jerry found <sil> after this willow not that you know a bull moose come on you or about dear <sil> every time <sil> that's going to be a price picture alright <sil> those last words from frank made will very proud </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/7800/7800-283493-0030_1.wav' from 4110ms to 4290ms.
# Recognized words: <s> but there is some question of species <sil> i think <sil> myself <sil> <sil> that they were minnows i'm stuck all blacks <sil> <sil> some person's <sil> thinking them to be seek issues <sil> place i'm in salt water according to mr roberts </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/3240/3240-131231-0038_1.wav' from 4470ms to 4610ms.
# Recognized words: <s> all instances i had to contribute a full small throngs work post world wins <sil> only one definitely and enterprise or places the world would <sil> <sil> <sil> <sil> also <sil> as has been said before <sil> upon going up would be quite as interesting as bronx coming at all </s>
# The word 'that' was not found in the audio C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/cleaned/3240/131231/3240-131231-0017.wav.
# Recognized words: <s> other than that poses to <sil> <sil> <sil> have been lost <sil> because orthodoxy does not look favorably upon such reports <sil> <sil> the monthly with the review record several falls of issues in the united states </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/3240/3240-131231-0027_1.wav' from 580ms to 770ms.
# Recognized words: <s> the fall of small throngs near birmingham <sil> england <sil> june thirtieth <sil> between any two <sil> <sil> is attributed to us pacific whirlwind <sil> <sil> but not a word as to any special pond that had contributed </s>
# Extracted 'that' to 'C:/Computer Science Programs/Fall_2024/EE502_BioMed/project/data/extracted_words/that_before_after/3240/3240-131231-0019_1.wav' from 11850ms to 12010ms.

# %%
input = r'C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\as_wav\87\121553\87-121553-0008.wav'
extract_word_audio(input, "./", "that", 10)
# Out:
# Recognized words: <s> when it was created was his mind to plead with such a living get a jade <sil> had in his mother heard a prophetic <sil> as soon as he espouses were completed between him and the face of holy followed <sil> with a with mutual safety dowry to other </s>
# The word 'that' was not found in the audio C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\as_wav\87\121553\87-121553-0008.wav.
